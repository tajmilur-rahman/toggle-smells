# %% [markdown]
# # Old Dead code

# %%
import os
import glob
import re
import pandas as pd


switch = glob.glob('/Users/govardhanrathamsetty/Desktop/ToggleSmell-Chromium/All versions//**/*_switches.cc', recursive=True)
feature = glob.glob('/Users/govardhanrathamsetty/Desktop/ToggleSmell-Chromium/All versions//**/*_features.cc', recursive=True)

cc_files = switch + feature

toggle_list = []

for cc_file in cc_files:
       with open(cc_file, 'r') as file:
                file_contents = file.read()
                toggle_list.append(file_contents)

toggle_list = list(filter(None, toggle_list))
toggle_patterns = [r'const char k.*\]']
found_toggles = []
final_toggle_list = []

for toggles in toggle_list:
    for pattern in toggle_patterns:
        matches = re.findall(pattern,toggles)
        found_toggles.extend(matches)
found_toggles = list(filter(None, found_toggles))

for k_toggles in found_toggles:
    final_toggle_list.extend(re.findall(r'\b[kK]\w*\b',k_toggles))

def dead(final_toggle_list):
        dead_test_files = glob.glob('/Users/govardhanrathamsetty/Desktop/ToggleSmell-Chromium/All versions/**/*.cc', recursive=True)
        dead_list1=[]
        dead_list2= []
        dead_list3=[]
        dead=[]

        for dead in dead_test_files:
            if 'switch' not in dead:
                if 'feature' not in dead:
                    with open(dead, 'rb') as file:  
                        try:
                            content = file.read().decode('utf-8')  
                            dead_list1.append(content)
                        except UnicodeDecodeError:
                            pass

        reg = [r'\(.*\b[k]\w*\b.*]',r'^const char k.*\]', r'^k.*\]', r'\(\b[k]\w*\b', r'\(\b[k]\w*\b.*]' , r'\{\b[k]\w*\b' , r'\{\b[k]\w*\b.*]',r'\::k.*',r'\:Feature k.*']

        for dead in dead_list1:
            for r in reg:
                matches = re.findall(r, dead)
                dead_list2.extend(matches)

        dead_list= [re.findall(r'\b[kK]\w*\b', i) for i in dead_list2]

        dead_list = [j for i in dead_list for j in i]

        for i in list(set(dead_list)):
            if i not in list(set(final_toggle_list)):
                dead_list3.append(i)

        print((len(list(set(dead_list))),len(list(set(dead_list3)))))  #3151 off 3454 toggles were seen in .cc files


#mixed(final_toggle_list)
dead(final_toggle_list)
# Out:
# (80460, 77309)

# %%
import os
import glob
import re
import pandas as pd


switch = glob.glob('/Users/govardhanrathamsetty/Desktop/ToggleSmell-Chromium/All versions//**/*_switches.cc', recursive=True)
feature = glob.glob('/Users/govardhanrathamsetty/Desktop/ToggleSmell-Chromium/All versions//**/*_features.cc', recursive=True)

cc_files = switch + feature

toggle_list = []

for cc_file in cc_files:
       with open(cc_file, 'r') as file:
                file_contents = file.read()
                toggle_list.append(file_contents)

toggle_list = list(filter(None, toggle_list))
toggle_patterns = [r'const char k.*\]', r'\(k[A-Z].*']
found_toggles = []
final_toggle_list = []

for toggles in toggle_list:
    for pattern in toggle_patterns:
        matches = re.findall(pattern,toggles)
        found_toggles.extend(matches)
found_toggles = list(filter(None, found_toggles))

for k_toggles in found_toggles:
    final_toggle_list.extend(re.findall(r'\b[kK]\w*\b',k_toggles))

def dead(final_toggle_list):
        dead_test_files = glob.glob('/Users/govardhanrathamsetty/Desktop/ToggleSmell-Chromium/All versions/**/*.cc', recursive=True)
        dead_list1=[]
        dead_list2= []
        dead_list3=[]
        dead=[]

        for dead in dead_test_files:
            if 'switch' not in dead:
                if 'feature' not in dead:
                    with open(dead, 'rb') as file:  
                        try:
                            content = file.read().decode('utf-8')  
                            dead_list1.append(content)
                        except UnicodeDecodeError:
                            pass

        reg = [r'switches\::k.*?\)', r'\s*bool k.*?\;', r'\s*if\s*\(k.*\)']

        for dead in dead_list1:
            for r in reg:
                matches = re.findall(r, dead)
                dead_list2.extend(matches)

        dead_list= [re.findall(r'\b[k]\w*\b', i) for i in dead_list2]

        dead_list = [j for i in dead_list for j in i]

        for i in list(set(dead_list)):
            if i not in list(set(final_toggle_list)):
                dead_list3.append(i)

        print((len(list(set(dead_list))),len(list(set(dead_list3)))))  #3151 off 3454 toggles were seen in .cc files


#mixed(final_toggle_list)
dead(final_toggle_list)
# Out:
# (5069, 2311)

# %%
c = '''if (kFeatureToggleEnabled) {
  // Feature-specific code
  //'''

m=re.findall(r'\s*if\s*\(k.*\)', c)

re.findall(r'k.*',m[0])
# Out:
# ['kFeatureToggleEnabled)']

# %%
#New

# %% [markdown]
# # Dead in 50th version

# %%
import os
import glob
import re
import pandas as pd

switch = glob.glob('/Users/govardhanrathamsetty/Desktop/ToggleSmell-Chromium/All versions/**/chromium 50.0.2624.0/**/*_switches.cc', recursive=True)
feature = glob.glob('/Users/govardhanrathamsetty/Desktop/ToggleSmell-Chromium/All versions/**/chromium 50.0.2624.0/**/*_features.cc', recursive=True)

cc_files = switch + feature

toggle_list = []

for cc_file in cc_files:
       with open(cc_file, 'r') as file:
                file_contents = file.read()
                toggle_list.append(file_contents)

toggle_list = list(filter(None, toggle_list))
toggle_patterns = [r'const char k[A-Z].*', r'\(k[A-Z].*']
found_toggles = []
final_toggle_list = []

for toggles in toggle_list:
    for pattern in toggle_patterns:
        matches = re.findall(pattern,toggles)
        found_toggles.extend(matches)
found_toggles = list(filter(None, found_toggles))

for k_toggles in found_toggles:
    final_toggle_list.extend(re.findall(r'\b[kK]\w*\b',k_toggles))

togglevariable_list=[]

x=['enable', 'disable']
for i in list(set(final_toggle_list)):
    for j in x:
        if j in i.lower():
            togglevariable_list.append(i)


def dead(togglevariable_list):
        dead_test_files = glob.glob('/Users/govardhanrathamsetty/Desktop/ToggleSmell-Chromium/All versions/**/chromium 50.0.2624.0/**/*.cc', recursive=True)
        dead_list1=[]
        dead_list2= []
        dead_list3=[]
        dead_list4=[]

        for dead in dead_test_files:
            if 'switch' not in dead:
                if 'feature' not in dead:
                    with open(dead, 'rb') as file:  
                        try:
                            content = file.read().decode('utf-8')  
                            dead_list1.append(content)
                        except UnicodeDecodeError:
                            pass

        reg = [r'switches\::k[A-Z].*?\)', r'\s*if\s*\(k[A-Z].*\)']

        for dead in dead_list1:
            for r in reg:
                matches = re.findall(r, dead)
                dead_list2.extend(matches)

        dead_list= [re.findall(r'\b[k]\w*\b', i) for i in dead_list2]

        dead_list = [j for i in dead_list for j in i if len(j)>10]
        
        x=['enable', 'disable']
        for i in dead_list:
            for j in x:
                if j in i.lower():
                    dead_list4.append(i)

        for i in list(set(dead_list4)):
            if len(i)>10 and i not in list(set(togglevariable_list)):
                dead_list3.append(i)

        print((len(list(set(dead_list4))),len(list(set(dead_list3)))))  #3151 off 3454 toggles were seen in .cc files
        print(list(set(dead_list3)))

#mixed(final_toggle_list)
dead(togglevariable_list)
# Out:
# (460, 31)
# ['kEnableMainFrameBeforeActivation', 'kEnablePropertyTreeVerification', 'kEnableProximityDetection', 'kDisableCompositedAntialiasing', 'kEnableHarfBuzzRenderText', 'kDisableMainFrameBeforeActivation', 'kEnableTouchIcon', 'kEnableAppWindowControls', 'kEnableExtensionActionRedesign', 'kEnableEmbeddedExtensionOptions', 'kDisableDirectWriteForUI', 'kDisableCache', 'kEnableDataReductionProxyCarrierTest', 'kEnableBeginFrameScheduling', 'kEnableScriptsRequireAction', 'kEnableDataReductionProxyLoFiPreview', 'kDisableCompositorPropertyTrees', 'kDisableThreadedAnimation', 'kEnableSandbox', 'kEnableGpuBenchmarking', 'kEnableAppsShowOnFirstPaint', 'kEnableExperimentalExtensionApis', 'kEnableCrxHashCheck', 'kDisableDirectWrite', 'kEnableBluetoothLowEnergyDiscovery', 'kDisableCachedPictureRaster', 'kEnableBLEAdvertising', 'kReenableAutoupdates', 'kEnableMojoSerialService', 'kEnableMultiprocess', 'kDisableDataReductionProxyDev']

# %%
togglevariable_list
# Out:
# ['kEnableLongpressDragSelection',
#  'kEnableAndroidSpellChecker',
#  'kEnableAudioDebugRecordingsFromExtension',
#  'kEnableThumbnailRetargeting',
#  'kDisableClearBrowsingDataCounters',
#  'kDisableWebAudio',
#  'kDisableSyncTypes',
#  'kEnableExtensionActivityLogging',
#  'kEnableDeviceDiscoveryNotifications',
#  'kEnableSyncAppList',
#  'kDisableOverlayScrollbar',
#  'kEnableOfferStoreUnmaskedWalletCards',
#  'kEnableNaClNonSfiMode',
#  'kEnableImeMenu',
#  'kDisableDomainReliability',
#  'kDisableNewKoreanIme',
#  'kDisableSettingsWindow',
#  'kEnableGpuRasterization',
#  'kDisableDeviceDisabling',
#  'kDisableGLSLTranslator',
#  'kDisableMediaThreadForMediaPlayback',
#  'kDisablePushApiBackgroundMode',
#  'kEnableFillOnAccountSelect',
#  'kDisableWakeOnWifi',
#  'kDisableAcceleratedVideoDecode',
#  'kDisableSaveCardBubble',
#  'kEnableVirtualizedTime',
#  'kDisableLoginAnimations',
#  'kDisableBootAnimation',
#  'kEnableSingleClickAutofill',
#  'kEnableNewAppListMixer',
#  'kDisableBackgroundNetworking',
#  'kEnablePluginPlaceholderTesting',
#  'kEnableReaderModeToolbarIcon',
#  'kEnableAlternativeServices',
#  'kDisableDemoMode',
#  'kDisableLCDText',
#  'kAshEnableTouchView',
#  'kDisableExtensionsFileAccessCheck',
#  'kDisableManagerForSyncSignin',
#  'kEnableExperimentalWebPlatformFeatures',
#  'kEnableAccelerated2DCanvas',
#  'kDisableFlash3d',
#  'kDisablePermissionsAPI',
#  'kSyncEnableGetUpdateAvoidance',
#  'kEnableVtune',
#  'kEnableCredentialManagerAPI',
#  'kEnableMacViewsDialogs',
#  'kEnableMediaThreadForMediaPlayback',
#  'kDisableNativeGpuMemoryBuffers',
#  'kDisableAddToShelf',
#  'kEnableNewBookmarkApps',
#  'kUIDisablePartialSwap',
#  'kDisablePinch',
#  'kEnableGpuClientTracing',
#  'kEnableChildAccountDetection',
#  'kEnableShowSavedCopySecondary',
#  'kDisableGLExtensions',
#  'kDisableTouchFeedback',
#  'kDisableMergeKeyCharEvents',
#  'kDisableMediaSource',
#  'kDisableSmartVirtualKeyboard',
#  'kDisableDataSaverPrompt',
#  'kDisableBackingStoreLimit',
#  'kSbDisableAutoUpdate',
#  'kEnableAccessibilityTabSwitcher',
#  'kDisableCompositorAnimationTimelines',
#  'kDisableHangMonitor',
#  'kDisableGestureRequirementForMediaPlayback',
#  'kDisableSeccompFilterSandbox',
#  'kDisableNewZIPUnpacker',
#  'kEnableHostedAppsInWindows',
#  'kEnableWebBluetooth',
#  'kDisableAppContainer',
#  'kDisableMediaSuspend',
#  'kEnablePixelOutputInTests',
#  'kEnableGLPathRendering',
#  'kEnableMemoryBenchmarking',
#  'kDisableQuic',
#  'kEnableInputImeAPI',
#  'kEnableMultilingualSpellChecker',
#  'kDisableContextualSearch',
#  'kEnableLowResTiling',
#  'kDisableGpuProcessCrashLimit',
#  'kEnableOfflineAutoReloadVisibleOnly',
#  'kDisableTouchDragDrop',
#  'kEnableWebRtcStunOrigin',
#  'kDisablePermissionsBlacklist',
#  'kDisablePhysicalKeyboardAutocorrect',
#  'kEnableNTPPopularSites',
#  'kDisableEncryptedMedia',
#  'kProfilerTimingDisabledValue',
#  'kDisableGaiaServices',
#  'kDisableRendererBackgrounding',
#  'kDisableDisplayList2dCanvas',
#  'kAshEnableMirroredScreen',
#  'kEnableNetBenchmarking',
#  'kEnableLocalFileAccesses',
#  'kDisableCoreAnimationPlugins',
#  'kEnableAccessorySuggestionView',
#  'kDisableLegacyIntermediateWindow',
#  'kEnableIOSFeatures',
#  'kEnableCreditCardScan',
#  'kDisableSurfaces',
#  'kHistoryEnableGroupByDomain',
#  'kEnableMessageCenterAlwaysScrollUpUponNotificationRemoval',
#  'kEnableMergeKeyCharEvents',
#  'kEnableHungRendererInfoBar',
#  'kEnableGPUDebugging',
#  'kPrerenderModeSwitchValueDisabled',
#  'kEnableTabAudioMuting',
#  'kDisableGLErrorLimit',
#  'kDebugEnableFrameToggle',
#  'kEnableExtensionActivityLogTesting',
#  'kEnableContextualSearch',
#  'kDisableHostedAppShimCreation',
#  'kDisableNewTaskManager',
#  'kDisableAndroidCompositorAnimationTimelines',
#  'kEnableSiteEngagementAppBanner',
#  'kDisableAppInfoDialogMac',
#  'kEnableInbandTextTracks',
#  'kDisableSpeechAPI',
#  'kDisableIOSFeatures',
#  'kAshDisableScreenOrientationLock',
#  'kDisableInputView',
#  'kEnableAppList',
#  'kDisableExperimentalWebGL',
#  'kDisableJavaScriptHarmonyShipping',
#  'kEnableTouchpadThreeFingerClick',
#  'kDisableRendererAccessibility',
#  'kAshEnableFullscreenAppList',
#  'kDisableComponentUpdate',
#  'kEnableGPUServiceLoggingGPU',
#  'kAshEnableUnifiedDesktop',
#  'kDisablePrintPreview',
#  'kDisableOfflineAutoReloadVisibleOnly',
#  'kEnableAdaptiveSelectionHandleOrientation',
#  'kDisableNewKioskUI',
#  'kDisableLowResTiling',
#  'kEnableSettingsWindow',
#  'kEnableUserMediaScreenCapturing',
#  'kEnableStaleWhileRevalidate',
#  'kDisableRGBA4444Textures',
#  'kEnableFontAntialiasing',
#  'kEnableMaterialDesignHistory',
#  'kEnableShowSavedCopyPrimary',
#  'kDisableComponentExtensionsWithBackgroundPages',
#  'kEnableWebNotificationCustomLayouts',
#  'kEnableUnifiedMediaPipeline',
#  'kEnableLRUSnapshotCache',
#  'kEnableExclusiveAudio',
#  'kDisableGpuProgramCache',
#  'kDisableIOSWKWebView',
#  'kDisablePreconnect',
#  'kEnableOfferUploadCreditCards',
#  'kEnablePrintPreviewRegisterPromos',
#  'kDisableGpuRasterization',
#  'kDisableDomainBlockingFor3DAPIs',
#  'kDisableScreenOrientationLock',
#  'kEnableDriveSearchInChromeLauncher',
#  'kDisablePresentationAPI',
#  'kEnableSpeechDispatcher',
#  'kDisableInfoBars',
#  'kDisableMultilingualSpellChecker',
#  'kEnableThreadedTextureMailboxes',
#  'kEnableHardwareOverlays',
#  'kEnableTcpFastOpen',
#  'kDisableVolumeAdjustSound',
#  'kDisableAboutInSettings',
#  'kEnablePowerOverlay',
#  'kEnableSmoothScrolling',
#  'kEnableOfflineAutoReload',
#  'kEnableGPUServiceLogging',
#  'kDisablePullToRefreshEffect',
#  'kDisableFlashStage3d',
#  'kEnableRequestTabletSite',
#  'kEnableSiteEngagementService',
#  'kEnableFullFormAutofillIOS',
#  'kDisableHIDDetectionOnOOBE',
#  'kDisableNotifications',
#  'kDisableSmoothScrolling',
#  'kDisableMtpWriteSupport',
#  'kEnableGpuMemoryBufferVideoFrames',
#  'kDisableSetuidSandbox',
#  'kSyncDisableRollback',
#  'kEnableScrollPrediction',
#  'kUIDisableCompositorAnimationTimelines',
#  'kDisableHideInactiveStackedTabCloseButtons',
#  'kEnableBookmarkUndo',
#  'kDisableTimeZoneTrackingOption',
#  'kEnableSubscribeUniformExtension',
#  'kDisableGpuSandbox',
#  'kDisableMaterialDesignDownloads',
#  'kEnableProfiling',
#  'kDisablePolicyKeyVerification',
#  'kAshDisableStableOverviewOrder',
#  'kEnterpriseEnableForcedReEnrollment',
#  'kEnableExperimentalCanvasFeatures',
#  'kDisableFillOnAccountSelect',
#  'kDisableSync',
#  'kDisableGestureEditing',
#  'kEnablePasswordGeneration',
#  'kAshEnableStableOverviewOrder',
#  'kDisableGpuVsync',
#  'kEnableFillOnAccountSelectNoHighlighting',
#  'kDisableMojoChannel',
#  'kEnableFirstRunUITransitions',
#  'kEnableClearBrowsingDataCounters',
#  'kDisableDropSyncCredential',
#  'kDisableUsbKeyboardDetect',
#  'kEnableCrashReporterForTesting',
#  'kEnableGPUServiceTracing',
#  'kEnableSlimmingPaintV2',
#  'kEnableDropSyncCredential',
#  'kEnableCmaMediaPipeline',
#  'kDisableChildAccountDetection',
#  'kDisableSyncAppList',
#  'kEnableManagerForSyncSignin',
#  'kEnableBlinkFeatures',
#  'kDisablePanelFitting',
#  'kDisablePopupBlocking',
#  'kEnableUseZoomForDSF',
#  'kDisableAcceleratedJpegDecoding',
#  'kDisableV8IdleTasks',
#  'kDisableRTCSmoothnessAlgorithm',
#  'kDisableTabEviction',
#  'kWindowAnimationsDisabled',
#  'kEnableNonValidatingReloadOnRefreshContent',
#  'kDisableBackgroundTimerThrottling',
#  'kDisableWin32kRendererLockDown',
#  'kEnableLogging',
#  'kDisableLRUSnapshotCache',
#  'kAudioModemEnableInaudibleBroadcast',
#  'kDisableDinosaurEasterEgg',
#  'kDisableRemoteFonts',
#  'kEnableZeroCopy',
#  'kEnableIOSWKWebView',
#  'kDisableInputImeAPI',
#  'kDisableCastStreamingHWEncoding',
#  'kDisableIconNtp',
#  'kUIEnableZeroCopy',
#  'kDisableLowEndDeviceMode',
#  'kDisableBlinkFeatures',
#  'kDisableWebSecurity',
#  'kDisableNewProfileManagement',
#  'kDisableAcceleratedMjpegDecode',
#  'kEnableExperimentalAppList',
#  'kEnableTouchDragDrop',
#  'kDisableAutoHidingToolbarThreshold',
#  'kDisableGestureTyping',
#  'kEnableExtensionAssetsSharing',
#  'kEnableGpuMemoryBufferCompositorResources',
#  'kEnableScreenshotTestingWithMode',
#  'kEnableAddToShelf',
#  'kDisableGpuCompositing',
#  'kEnablePreciseMemoryInfo',
#  'kDisableSingleClickAutofill',
#  'kDisableHistogramCustomizer',
#  'kEnableFloatingVirtualKeyboard',
#  'kDisableIOSPasswordSuggestions',
#  'kDisableKillAfterBadIPC',
#  'kPrerenderFromOmniboxSwitchValueDisabled',
#  'kEnableMediaSuspend',
#  'kDisableFileSystem',
#  'kAshEnableSystemSounds',
#  'kPrerenderFromOmniboxSwitchValueEnabled',
#  'kDisableFullFormAutofillIOS',
#  'kDisableComponentCloudPolicy',
#  'kEnableSkiaBenchmarking',
#  'kEnableStatsTable',
#  'kEnableNetworkPortalNotification',
#  'kEnablePreferCompositingToLCDText',
#  'kDisableDownloadNotification',
#  'kEnableSpellingFeedbackFieldTrial',
#  'kEnableDomainReliability',
#  'kEnableTabEviction',
#  'kDisableDefaultApps',
#  'kDisableConfirmation',
#  'kEnableNetworkInformation',
#  'kDisableRollbackOption',
#  'kDisableExtensionsHttpThrottling',
#  'kEnableFeatures',
#  'kDisableAccelerated2dCanvas',
#  'kEnablePartialRaster',
#  'kDisableSiteEngagementService',
#  'kDisableGpuMemoryBufferVideoFrames',
#  'kDisableMinimizeOnSecondLauncherItemClick',
#  'kEnableTransparentVisuals',
#  'kSpeculativeResourcePrefetchingDisabled',
#  'kEnableIconNtp',
#  'kEnableTabSwitcher',
#  'kAshDisableMaximizeModeWindowBackdrop',
#  'kEnableDomDistiller',
#  'kDisableXTocken',
#  'kDisableLogging',
#  'kEnableWebGLDraftExtensions',
#  'kEnablePNaClSubzero',
#  'kEnableRGBA4444Textures',
#  'kDisableWebRtcHWEncoding',
#  'kDisableMacViewsNativeAppWindows',
#  'kDisablePepper3d',
#  'kTouchEventsDisabled',
#  'kDisableExperimentalAppList',
#  'kDisableGpu',
#  'kEnableSandboxLogging',
#  'kSbDisableDownloadProtection',
#  'kSyncEnableClearDataOnPassphraseEncryption',
#  'kEnableAcceleratedVpxDecode',
#  'kEnableSessionCrashedBubble',
#  'kDisableTranslateNewUX',
#  'kDisableVirtualKeyboardOverscroll',
#  'kEnableAggressiveDOMStorageFlushing',
#  'kDisableOfficeEditingComponentApp',
#  'kDisableOutOfProcessPac',
#  'kDisableOfferStoreUnmaskedWalletCards',
#  'kEnableWaylandServer',
#  'kDisableMacOverlays',
#  'kDisableLocalStorage',
#  'kEnablePotentiallyAnnoyingSecurityFeatures',
#  'kDisableThreadedCompositing',
#  'kEnableDataSaverPrompt',
#  'kDisable3DAPIs',
#  'kEnableMojoShellConnection',
#  'kEnableTracing',
#  'kAshEnableMagnifierKeyScroller',
#  'kEnableMacViewsNativeAppWindows',
#  'kAudioModemEnableAudibleBroadcast',
#  'kEnableLowEndDeviceMode',
#  'kDisableTabSwitcher',
#  'kEnableTracingOutput',
#  'kDisableDistanceFieldText',
#  'kEnableMaterialDesignDownloads',
#  'kEnableCloudPrintXps',
#  'kDisableGpuDriverBugWorkarounds',
#  'kEnableAVFoundation',
#  'kEnableSpatialNavigation',
#  'kEnableAffiliationBasedMatching',
#  'kDisableSimplifiedFullscreenUI',
#  'kDisableAppWindowCycling',
#  'kDisableCreditCardScan',
#  'kEnableExperimentalInputViewFeatures',
#  'kDisableShaderNameHashing',
#  'kDisableHostedAppsInWindows',
#  'kEnableLCDText',
#  'kEnableLinkDisambiguationPopup',
#  'kEnablePhysicalKeyboardAutocorrect',
#  'kEnableAppContainer',
#  'kDisableNewChannelSwitcherUI',
#  'kDisableOverscrollEdgeEffect',
#  'kEnableIOSHandoffToOtherDevices',
#  'kDisableSessionCrashedBubble',
#  'kDisableNetworkPortalNotification',
#  'kEnableViewport',
#  'kDisableClientSidePhishingDetection',
#  'kEnableDistanceFieldText',
#  'kDisableViewsRectBasedTargeting',
#  'kDisableGLDrawingForTests',
#  'kDisableWebNotificationCustomLayouts',
#  'kAshDisableTouchExplorationMode',
#  'kDisableSavePasswordBubble',
#  'kEnableLeakDetection',
#  'kEnableNativeNotifications',
#  'kDisableIpv4',
#  'kEnableUnsafeES3APIs',
#  'kDisablePasswordManagerReauthentication',
#  'kAshEnableSoftwareMirroring',
#  'kDisableSoftwareRasterizer',
#  'kEnablePinch',
#  'kDisableOfferUploadCreditCards',
#  'kEnableMacViewsAppList',
#  'kEnableProfileShortcutManager',
#  'kDisablePluginsDiscovery',
#  'kEnableVideoPlayerChromecastSupport',
#  'kEnableSaveCardBubble',
#  'kEnableNaClDebug',
#  'kDisableFieldTrialTestingConfig',
#  'kEnablePermissionsBlacklist',
#  'kDisableDatabases',
#  'kDisableNewAppListMixer',
#  'kEnableArc',
#  'kDisableZeroBrowsersOpenForTests',
#  'kEnableTabSwitcherInDocumentMode',
#  'kEnableCrashReporter',
#  'kEnableNaCl',
#  'kEnableSupervisedUserManagedBookmarksFolder',
#  'kDisablePanels',
#  'kEnableTranslateNewUX',
#  'kEnableSavePasswordBubble',
#  'kEnableStrictMixedContentChecking',
#  'kDisableAccessorySuggestionView',
#  'kEnableAppWindowCycling',
#  'kDisableIOSWebResources',
#  'kEnableSuggestionsWithSubstringMatch',
#  'kDisableGpuWatchdog',
#  'kEnableKioskMode',
#  'kEnableFastUnload',
#  'kEnablePepperTesting',
#  'kEnableStrictPowerfulFeatureRestrictions',
#  'kEnableAccountConsistency',
#  'kUIEnableRGBA4444Textures',
#  'kPrerenderModeSwitchValueEnabled',
#  'kEnablePrecache',
#  'kDisableExtensions',
#  'kDisablePnaclCrashThrottling',
#  'kEnableIOSFastWebScrollViewInsets',
#  'kEnableMaterialDesignExtensions',
#  'kDisableNTPPopularSites',
#  'kDisableMethodCheck',
#  'kEnableRendererMojoChannel',
#  'kEnablePasswordSeparatedSigninFlow',
#  'kEnableCloudPrintProxy',
#  'kDisableAffiliationBasedMatching',
#  'kEnable2dCanvasClipAntialiasing',
#  'kEnableWebAppFrame',
#  'kEnableNewProfileManagement',
#  'kDisablePasswordSeparatedSigninFlow',
#  'kDisablePageVisibility',
#  'kSyncDisableBackup',
#  'kEnableGPUClientLogging',
#  'kDisableDwmComposition',
#  'kDisableDirectNPAPIRequests',
#  'kDisableNamespaceSandbox',
#  'kEnableShareGroupAsyncTextureUpload',
#  'kDisableAppListDismissOnBlur',
#  'kDisableCaptivePortalBypassProxy',
#  'kEnableSimplifiedFullscreenUI',
#  'kEnableNTPSearchEngineCountryDetection',
#  'kDisableTranslate',
#  'kDisableVaapiAcceleratedVideoEncode',
#  'kDisableOfflinePages',
#  'kEnableMaterialDesignPolicyPage',
#  'kDisableDriveSearchInChromeLauncher',
#  'kDisableWebRtcEncryption',
#  'kAshDisableSystemSounds',
#  'kEnableWin32kLockDownMimeTypes',
#  'kDnsPrefetchDisable',
#  'kEnableSiteEngagementEvictionPolicy',
#  'kEnableOverlayScrollbar',
#  'kDisableTouchAdjustment',
#  'kEnableNTPFavicons',
#  'kAshEnableTouchViewTesting',
#  'kEnablePrefixedEncryptedMedia',
#  'kDisableGpuEarlyInit',
#  'kDisablePasswordGeneration',
#  'kDisableIOSPasswordGeneration',
#  'kDisableOfflineAutoReload',
#  'kEnableQueryExtraction',
#  'kDisableAsyncDns',
#  'kDisableDeviceDiscoveryNotifications',
#  'kDisableNTPFavicons',
#  'kEnableEmbeddedSearchAPI',
#  'kEnableAppsFileAssociations',
#  'kEnableIOSPasswordGeneration',
#  'kEnableWebRtcHWH264Encoding',
#  'kTouchEventsEnabled',
#  'kEnableQuic',
#  'kEnableUserAlternateProtocolPorts',
#  'kEnableWebVR',
#  'kSpeculativeResourcePrefetchingEnabled',
#  'kEnableDevToolsExperiments',
#  'kDisableIOSFastWebScrollViewInsets',
#  'kDisable2dCanvasAntialiasing',
#  'kSyncDisableDeferredStartup',
#  'kEnablePanels',
#  'kEnableBenchmarking',
#  'kEnableNativeGpuMemoryBuffers',
#  'kDisableXSSAuditor',
#  'kDisableZeroCopy',
#  'kEnableThreadedCompositing',
#  'kEnableImageColorProfiles',
#  'kEnableHostedMode',
#  'kDisableIpv6',
#  'kDisableQuicPortSelection',
#  'kDisableSharedWorkers',
#  'kDisableAccountConsistency',
#  'kEnableCenteredAppList',
#  'kEnablePushApiBackgroundMode',
#  'kEnableConsumerManagement',
#  'kDisableRemoteCoreAnimation',
#  'kDisableFeatures',
#  'kDisableThreadedScrolling',
#  'kDisableNewBookmarkApps',
#  'kEnableSyncArticles',
#  'kDisableGpuMemoryBufferCompositorResources',
#  'kEnableOfflinePages',
#  'kDisableDisplayColorCalibration',
#  'kEnableGPUCommandLogging',
#  'kEnableHeapProfiling',
#  'kEnableExperimentalHotwordHardware',
#  'kDisableDelayAgnosticAec',
#  'kEnableVirtualKeyboard',
#  'kDisableGpuShaderDiskCache',
#  'kEnableRefreshTokenAnnotationRequest',
#  'kDisableD3D11',
#  'kDisableSigninScopedDeviceId',
#  'kEnableAppInfoDialogMac',
#  'kDisableBreakpad',
#  'kDisableVoiceInput',
#  'kDisableWebRtcHWDecoding',
#  'kEnableWifiCredentialSync',
#  'kEnableBrowserSideNavigation',
#  'kDisableBundledPpapiFlash',
#  'kEnableNavigationTracing',
#  'kDisableReadingFromCanvas',
#  'kEnableDisplayList2dCanvas',
#  'kEnableQuicPortSelection',
#  'kDisablePreferCompositingToLCDText',
#  'kDisableCloudImport',
#  'kDisablePromptOnRepost',
#  'kEnableWebGLImageChromium',
#  'kEnableWebRtcDtls12',
#  'kSbDisableExtensionBlacklist',
#  'kDisableShowSavedCopy']

# %% [markdown]
# # Dead in all files, with feature patterns included

# %%
import os
import glob
import re
import pandas as pd


switch = glob.glob('/Users/govardhanrathamsetty/Desktop/ToggleSmell-Chromium/All versions/**/*_switches.cc', recursive=True)
feature = glob.glob('/Users/govardhanrathamsetty/Desktop/ToggleSmell-Chromium/All versions/**/*_features.cc', recursive=True)

cc_files = switch + feature

toggle_list = []

for cc_file in cc_files:
       with open(cc_file, 'r') as file:
                file_contents = file.read()
                toggle_list.append(file_contents)

toggle_list = list(filter(None, toggle_list))
toggle_patterns = [r'const char k[A-Z].*', r'\::Feature k[A-Z].*', r'\s*k[A-Z].*']
found_toggles = []
final_toggle_list = []

for toggles in toggle_list:
    for pattern in toggle_patterns:
        matches = re.findall(pattern,toggles)
        found_toggles.extend(matches)
found_toggles = list(filter(None, found_toggles))

for k_toggles in found_toggles:
    final_toggle_list.extend(re.findall(r'\b[kK]\w*\b',k_toggles))

togglevariable_list=[]

x=['enable', 'disable']
for i in list(set(final_toggle_list)):
    for j in x:
        if j in i.lower():
            togglevariable_list.append(i)


def dead(togglevariable_list):
        dead_test_files = glob.glob('/Users/govardhanrathamsetty/Desktop/ToggleSmell-Chromium/All versions/**/*.cc', recursive=True)
        dead_list1=[]
        dead_list2= []
        dead_list3=[]
        dead_list4=[]

        for dead in dead_test_files:
            if 'switch' not in dead:
                if 'feature' not in dead:
                    with open(dead, 'rb') as file:  
                        try:
                            content = file.read().decode('utf-8')  
                            dead_list1.append(content)
                        except UnicodeDecodeError:
                            pass

        reg = [r'switches\::k[A-Z].*?\)', r'\s*if\s*\(k[A-Z].*\)', r'\s*\(k[A-Z]' ]

        for dead in dead_list1:
            for r in reg:
                matches = re.findall(r, dead)
                dead_list2.extend(matches)

        dead_list= [re.findall(r'\b[k]\w*\b', i) for i in dead_list2]

        dead_list = [j for i in dead_list for j in i if len(j)>10]
        
        x=['enable', 'disable']
        for i in dead_list:
            for j in x:
                if j in i.lower():
                    dead_list4.append(i)

        for i in list(set(dead_list4)):
            if len(i)>10 and i not in list(set(togglevariable_list)):
                dead_list3.append(i)

        print((len(list(set(dead_list4))),len(list(set(dead_list3)))))  #3151 off 3454 toggles were seen in .cc files
        print(list(set(dead_list3)))

#mixed(final_toggle_list)
dead(togglevariable_list)
# Out:
# (1448, 92)
# ['kEnableCeee', 'kEnableKeywordBasedElision', 'kWhatCanYouDoChipEnabled', 'kEnableVizDevTools', 'kUIEnableLayerLists', 'kEnableWidevine', 'kDisable4444Textures', 'kEnableDataReductionProxyCarrierTest', 'kEnableDataReductionProxyLoFiPreview', 'kUserAgentClientHintDisable', 'kDisableAppInfo', 'kEnableSandbox', 'kDisableDesktopCaptureAudio', 'kWhatsTheWeatherChipEnabled', 'kDisableCachedPictureRaster', 'kSendAnEmailChipEnabled', 'kEnableMultiprocess', 'kEnableCompactNavigation', 'kEnablePropertyTreeVerification', 'kDisableChromeTracingComputation', 'kDisableHarfBuzzRenderText', 'kEnableLayerLists', 'kDisableMainFrameBeforeActivation', 'kDisableEasyUnlock', 'kDisableBrowserTaskScheduler', 'kEnableReporting', 'kChromeFrameQuickEnable', 'kEnableU2fHidTest', 'kDisableBeginFrameScheduling', 'kDisableHeadlessMode', 'kDisableStats', 'kEnableChromeTracingComputation', 'kDisableMainFrameBeforeDraw', 'kDisablePinchVirtualViewport', 'kReenableAutoupdates', 'kEnableMojoSerialService', 'kEnableCheckerImaging', 'kEnableCastStreamingReceiver', 'kEnableDataReductionProxyLitePage', 'kQueryTilesEnableTrending', 'kEnableFfCeee', 'kPortEnabled', 'kEnableTouchIcon', 'kEnableExtensionActionRedesign', 'kDisableCompositorTouchHitTesting', 'kEnableWebsocketOverHttp2', 'kSetAReminderChipEnabled', 'kDisableCheckerImaging', 'kDisableDirectWriteForUI', 'kDisableLayerTreeHostMemoryPressure', 'kEnableTopControlsPositionCalculation', 'kDisableCompositorPropertyTrees', 'kEnableAudioServiceSandbox', 'kEnableAppView', 'kImBoredChipEnabled', 'kDisableDesktopCapturePickerNewUI', 'kDisableSoftwareVideoDecoders', 'kEnableDeJelly', 'kEnableBluetoothLowEnergyDiscovery', 'kDisableFrameRateLimit', 'kEnableBLEAdvertising', 'kWhatsOnMyCalendarChipEnabled', 'kEnablePinchInCompositor', 'kPlayMusicChipEnabled', 'kDisableDataReductionProxyDev', 'kDisableFontSubpixelPositioning', 'kEnableMainFrameBeforeActivation', 'kEnableProximityDetection', 'kEnableBrowserTaskScheduler', 'kEnableTileCompression', 'kEnableMapImage', 'kEnableHarfBuzzRenderText', 'kEnableGPURasterization', 'kDisableTabForDesktopShare', 'kDisableGpuLpac', 'kEnableEmbeddedExtensionOptions', 'kDisableGpuAppContainer', 'kDisableCache', 'kEnableBitstreamConverter', 'kEnableClippedImageScaling', 'kEnableScriptsRequireAction', 'kEnableSurfaceSynchronization', 'kWhatsOnMyScreenChipEnabled', 'kOpenFilesChipEnabled', 'kDisableColorEstimator', 'kEnableGpuAppContainer', 'kEnableCrxHashCheck', 'kEnableDownloadDB', 'kEnableStats', 'kEnablePinchVirtualViewport', 'kInitialDnsPrefetchListEnabled', 'kDisableYuv420Biplanar']

# %%
len(list(set(togglevariable_list)))
# Out:
# 1815

# %%
togglevariable_list
# Out:
# ['kEnableConsumerKiosk',
#  'kEnableRegionBasedColumns',
#  'kEnableDeviceDiscoveryNotifications',
#  'kDisableNewKoreanIme',
#  'kDisableFiltersOverIPC',
#  'kEnableOverwritingPlaceholderUsernames',
#  'kAshDisablePerAppLauncher',
#  'kDisableDirectComposition',
#  'kAmbientModeGeoPhotosEnabled',
#  'kUIDisablePartialSwap',
#  'kAutofillEnableVirtualCard',
#  'kEnableV8IdleNotificationAfterCommit',
#  'kEnableShowSavedCopySecondary',
#  'kDisableSdchPersistence',
#  'kEnableSlimmingPaint',
#  'kDisableCompositorAnimationTimelines',
#  'kEnableVulkan',
#  'kEnableOnly',
#  'kEnablePolicyKeyVerification',
#  'kDisableSystemFontCheck',
#  'kEnableCloudPrint',
#  'kDisableSyncExtensions',
#  'kEnableOneCopy',
#  'kEnableClearHevcForTesting',
#  'kDebugEnableFrameToggle',
#  'kDisableAndroidCompositorAnimationTimelines',
#  'kEnableExactMatchForNonLatinLocale',
#  'kDisableSpeechAPI',
#  'kEnableAriaElementReflection',
#  'kAshEnableOak',
#  'kDisableNewKioskUI',
#  'kEnableAudibleNotifications',
#  'kDisableFullscreenLowPowerMode',
#  'kEnableMessagesWebPush',
#  'kAutofillEnablePaymentsInteractionsOnAuthError',
#  'kDisableBackgroundMode',
#  'kEnableExperimentalAccessibilitySwitchAccessText',
#  'kEnableSyncCredentialCaching',
#  'kDisableSmoothScrolling',
#  'kDisableExtensionsResourceWhitelist',
#  'kEnableGpuMemoryBufferVideoFrames',
#  'kDisableSiteIsolationTrials',
#  'kDisableCarbonInterposing',
#  'kDisableAcceleratedPlugins',
#  'kUIDisableCompositorAnimationTimelines',
#  'kDisableAcceleratedLayers',
#  'kEnableTranslate',
#  'kDisableSyncSessionsV2',
#  'kEnablePasswordGeneration',
#  'kDisableOopRasterization',
#  'kDisableNativeCups',
#  'kDisableSimpleCache',
#  'kEnableAssistantSearch',
#  'kDisableAuthNegotiateCnameLookup',
#  'kTouchOptimizedUIDisabled',
#  'kAshDisableLoginDimAndBlur',
#  'kDisableSyncPriorityPreferences',
#  'kWebComponentsV0Enabled',
#  'kAshDisableUIScaling',
#  'kEnabledForBrowserProcess',
#  'kDisableDelegatedRenderer',
#  'kEnableInteractiveAutocomplete',
#  'kEnableInstantExtendedAPI',
#  'kEnableNetworkPortalNotification',
#  'kEnableThirdPartyKeyboardWorkaround',
#  'kDisableSpdy31',
#  'kForceDisableVariationIds',
#  'kEnableZeroSuggestEtherNoSerp',
#  'kSpeculativeResourcePrefetchingDisabled',
#  'kImageFetchingEnabled',
#  'kEnableHeapProfilingModeNative',
#  'kEnableContentPrefetch',
#  'kOnSchoolDeviceEnabled',
#  'kEnableAcceleratedVpxDecode',
#  'kDisableMacOverlays',
#  'kEnableInternalMediaSession',
#  'kEnableLowEndDeviceMode',
#  'kEnableTracingOutput',
#  'kPpapiFlashFieldTrialEnableByDefault',
#  'kDisableGpuDriverBugWorkarounds',
#  'kEnableSyncSessions',
#  'kEnableAffiliationBasedMatching',
#  'kDisableAndroidPasswordLink',
#  'kEnablePerfetto',
#  'kEnablePhysicalKeyboardAutocorrect',
#  'kEnableDistanceFieldText',
#  'kEnableUnsafeES3APIs',
#  'kAutofillEnablePasswordInfoBarAccountIndicationFooter',
#  'kEnableCriticalPersistedTabData',
#  'kDisableCloudPolicyOnSignin',
#  'kEnableStubPortalledWifi',
#  'kDisableAudioSupportForDesktopShare',
#  'kEnableOverlayScrollbar',
#  'kDisableThreadedHTMLParser',
#  'kEnablePrefixedEncryptedMedia',
#  'kDisableOfflineAutoReload',
#  'kFileManagerEnableSharing',
#  'kFilesAppDisableMyFilesNavigation',
#  'kAshDisablePanelFitting',
#  'kEnableEmbeddedSearchAPI',
#  'kEnableVideoFullscreen',
#  'kSyncEnableUSSDeviceInfo',
#  'kEnableDirectCompositionVideoOverlays',
#  'kWebViewEnableModernCookieSameSite',
#  'kAshEnableTouchViewTouchFeedback',
#  'kSpeculativeResourcePrefetchingEnabled',
#  'kDisableNewMDInputView',
#  'kEnableRoundedWindowCorners',
#  'kEnableCompositingForFixedPosition',
#  'kOverrideEnabledCdmInterfaceVersion',
#  'kArcDisableGmsCoreCache',
#  'kEnableAggregatedMlAppRanking',
#  'kEnableRefreshTokenAnnotationRequest',
#  'kDisableMachineCertRequest',
#  'kEnableAppsGridGapFeature',
#  'kDisablePreferCompositingToLCDText',
#  'kEnableMemoryInfo',
#  'kEnableSyncFavicons',
#  'kEnableExperimentalAccessibilityChromeVoxSubNodeLanguageSwitching',
#  'kEnableApplicationCache',
#  'kAmbientModeRssPhotosEnabled',
#  'kEnableGeolocation',
#  'kEnableWebRtcAecRecordings',
#  'kEnableExperimentalAccessibilityChromeVoxTutorial',
#  'kEnablePluginPlaceholderTesting',
#  'kEnableVtune',
#  'kEnableMacViewsDialogs',
#  'kEnableIframeBasedSignin',
#  'kEnableZeroSuggestEtherSerp',
#  'kOmniboxAggressiveHistoryURLDisabled',
#  'kEnableVirtualKeyboardOverscroll',
#  'kAshEnableDockedWindows',
#  'kDisableMediaSuspend',
#  'kEnableWebRtcTcpServerSocket',
#  'kEnableInputImeAPI',
#  'kAllowDisableMouseAcceleration',
#  'kArcDisablePlayAutoInstall',
#  'kEnableCaptivePortalRandomUrl',
#  'kDisableANGLEFeatures',
#  'kEnableOfflineCacheAccess',
#  'kDisableSSL3',
#  'kHistoryEnableGroupByDomain',
#  'kEnableTabAudioMuting',
#  'kDisableGLErrorLimit',
#  'kDisableZipArchiverUnpacker',
#  'kDisableInfobarForProtectedMediaIdentifier',
#  'kEnableWebViewVariations',
#  'kDisableJavaScriptHarmonyShipping',
#  'kAshEnableFullscreenAppList',
#  'kDisableCast',
#  'kEnableStaleWhileRevalidate',
#  'kEnableNativeCups',
#  'kDisableVrShell',
#  'kDisableComponentExtensionsWithBackgroundPages',
#  'kEnableManagedStorage',
#  'kDisableAppList',
#  'kEnableEac3Playback',
#  'kEnableDirectWrite',
#  'kEnableBrowserPlugin',
#  'kAnswersEnabled',
#  'kDisableThirdPartyKeyboardWorkaround',
#  'kEnableVp9InMp4',
#  'kDisableHighResTimer',
#  'kArcEnableNativeBridge64BitSupportExperiment',
#  'kEnableWin32kRendererLockDown',
#  'kDisableSyncTabs',
#  'kWinSboxDisableExtensionPoints',
#  'kDisableDesktopShortcuts',
#  'kEnableSubscribeUniformExtension',
#  'kEnableMetricsReportingForTesting',
#  'kDisableVideoCaptureUseGpuMemoryBuffer',
#  'kDisableMojoChannel',
#  'kDisableDirectCompositionLayers',
#  'kEnableNewBadgeOnMenuItems',
#  'kDisableOOBEBlockingUpdate',
#  'kEnterpriseDisableLicenseTypeSelection',
#  'kEnableGPUDriverDebugLogging',
#  'kDisableRTCSmoothnessAlgorithm',
#  'kWindowAnimationsDisabled',
#  'kEnableHostnameSetting',
#  'kEnableIOSWKWebView',
#  'kDisableInputImeAPI',
#  'kDisableNewProfileManagement',
#  'kDisableBackgroundMediaSuspend',
#  'kDisableCompositingForFixedPosition',
#  'kDisableOnlineEULA',
#  'kDisableStorageManager',
#  'kEnableAcceleratedOverflowScroll',
#  'kTopChromeTouchUiEnabled',
#  'kEnableSpellingFeedbackFieldTrial',
#  'kEnableOriginBoundCerts',
#  'kDisableSyncPreferences',
#  'kEnableExperimentalAccessibilityAutoclick',
#  'kDisableAudioTrackProcessing',
#  'kEnableAppListSearchAutocomplete',
#  'kDisableLoginScreenApps',
#  'kEnableExtensionApps',
#  'kEnableServiceWorkerSync',
#  'kWebViewEnableSafeBrowsingSupport',
#  'kDisableAppWindowCycling',
#  'kDisableZeroBrowsersOpenForTests',
#  'kAnswersTextAnnotatorEnabled',
#  'kEnableStrictMixedContentChecking',
#  'kDisableGestureRequirementForPresentation',
#  'kEnableStrictPowerfulFeatureRestrictions',
#  'kDisableSpellcheckAPI',
#  'kEnableSync',
#  'kEnableEmbeddedSignin',
#  'kEnableTopDragGesture',
#  'kEnableDelegatedRenderer',
#  'kDisableOriginChipV2',
#  'kOmniboxHistoryQuickProviderNewScoringEnabled',
#  'kDisableTLSChannelID',
#  'kDisableCookieEncryption',
#  'kEnableGestureTapHighlight',
#  'kEnableFuzzyAppSearch',
#  'kDisableCrashReporter',
#  'kEnableNewAutofillHeuristics',
#  'kDisableRendererSideMixing',
#  'kEnableHostedMode',
#  'kDisableAccountConsistency',
#  'kEnableExposeForTabs',
#  'kEnableWebBasedSignin',
#  'kEnableCompositingForTransition',
#  'kDisablePartialRaster',
#  'kEnableWebRtcEventLoggingFromExtension',
#  'kFileManagerEnableMultiProfile',
#  'kDisableCloudImport',
#  'kDisableAudioFallback',
#  'kEnableWebRtcSrtpEncryptedHeaders',
#  'kEnableExtensionActivityLogging',
#  'kDisableTimeoutsForProfiling',
#  'kDisableSpeechSynthesisAPI',
#  'kEnablePlatformApps',
#  'kEnableMDRoundedCornersOnDialogs',
#  'kDisableDemoMode',
#  'kEnableCredentialManagerAPI',
#  'kEnableSyncTabsForOtherClients',
#  'kUIEnablePartialSwap',
#  'kDisableDataSaverPrompt',
#  'kEnableEasySignin',
#  'kEnableTouchpadThreeFingerSwipe',
#  'kEnablePixelOutputInTests',
#  'kEnableGLPathRendering',
#  'kAutofillEnableCardNicknameManagement',
#  'kDisablePlugins',
#  'kDisableSuggestionsUI',
#  'kProfilerTimingDisabledValue',
#  'kEnableAccessibilityExposeHTMLElement',
#  'kEnableNetBenchmarking',
#  'kAshDisableDragAndDropAppListToLauncher',
#  'kEnableHungRendererInfoBar',
#  'kDisableRestoreSessionState',
#  'kEnableBlockContentAnimation',
#  'kAshForceEnableStylusTools',
#  'kEnablePluginPowerSaver',
#  'kEnableDownloadResumption',
#  'kProviderEnabled',
#  'kEnableFontAntialiasing',
#  'kDisableSVG1DOM',
#  'kEnableIncognitoModeAvailabilityIOS',
#  'kDisablePresetsParameterName',
#  'kEnableTcpFastOpen',
#  'kEnableRequestTabletSite',
#  'kDisableDeferred2dCanvas',
#  'kDisableMtpWriteSupport',
#  'kDisableHolePunching',
#  'kEnableScrollPrediction',
#  'kSyncEnableGetUpdatesBeforeCommit',
#  'kEnableTouchSupportForScreenMagnifier',
#  'kDisableCompositedCoreAnimationPlugins',
#  'kDisableDropSyncCredential',
#  'kEnableNativeWebWorkers',
#  'kEnableCastReceiver',
#  'kAshEnableMemoryMonitor',
#  'kEnableExperimentalUIAutomation',
#  'kEnableTouchDragDrop',
#  'kOmniboxMaxURLMatchesEnabledByDefault',
#  'kEnableMediaStream',
#  'kEnableCssRegions',
#  'kEnableAddToShelf',
#  'kEnableScriptedSpeech',
#  'kEnableTracingFormat',
#  'kPrerenderFromOmniboxSwitchValueDisabled',
#  'kAutofillEnableLabelPrecedenceForTurkishAddresses',
#  'kSbDisableSideEffectFreeWhitelist',
#  'kPrerenderFromOmniboxSwitchValueEnabled',
#  'kEnableInputMethodFeature',
#  'kEnableNetworkInformationDownlinkMax',
#  'kAmbientModeCapturedOnPixelPhotosEnabled',
#  'kEnablePartialRaster',
#  'kEnableTransparentVisuals',
#  'kDisableMultiDisplayLayout',
#  'kEnableMovingMultiplePasswordsToAccount',
#  'kDisableJavaScript',
#  'kEnableSoftwareMirroring',
#  'kEnableCloudPrintXps',
#  'kAshEnableImmersiveFullscreenForAllWindows',
#  'kForceEnablePreviews',
#  'kDisableSoftwareCompositingFallback',
#  'kDisabledNewSpecBehavior',
#  'kDisableNewChannelSwitcherUI',
#  'kDisableSigninFrameClientCertUserSelection',
#  'kEnablePinch',
#  'kEnableDNSSECCerts',
#  'kEnableNaClDebug',
#  'kEnableSyncedBookmarksFolder',
#  'kEnableUnsafeFastJSCalls',
#  'kEnableFileCookies',
#  'kEnableMaterialDesignExtensions',
#  'kEnableAggregatedMlSearchRanking',
#  'kDisablePageVisibility',
#  'kSyncDisableBackup',
#  'kAshEnableTabletMode',
#  'kEnablePerfettoSystemTracing',
#  'kDisableNewTabFirstRun',
#  'kEnableUserAlternateProtocolPorts',
#  'kAshEnableWaylandServer',
#  'kEnableMediaInternals',
#  'kDocumentDomainEnabledCrossOriginAccess',
#  'kDisableSyncThemes',
#  'kEnableApplicationZoomFeature',
#  'kEnableFileManagerFeedbackPanel',
#  'kDisableSigninScopedDeviceId',
#  'kDisableWebRtcHWDecoding',
#  'kEnableNavigationTracing',
#  'kMediaDrmEnableNonCompositing',
#  'kImpliesNoOpenerDisable',
#  'kEnableWebGLImageChromium',
#  'kEnableLongpressDragSelection',
#  'kDisableNv12DxgiVideo',
#  'kEnableNaClNonSfiMode',
#  'kEnableMP3StreamParser',
#  'kEnableFillOnAccountSelect',
#  'kAutofillEnableAccountWalletStorageUpload',
#  'kEnableExperimentalWebPlatformFeatures',
#  'kAshEnableStickyEdges',
#  'kAmbientModeDefaultFeedEnabled',
#  'kDisableWindows10CustomTitlebar',
#  'kEnableBrowserInputController',
#  'kEnableWebAudioInput',
#  'kUIDisableZeroCopy',
#  'kEnableSgiVideoSync',
#  'kEnableCarbonInterposing',
#  'kEnabledPerSiteInstance',
#  'kEnablePruneGpuCommandBuffers',
#  'kEnableLocalSearchService',
#  'kDisableGpuProcessCrashLimit',
#  'kEnableNTPPopularSites',
#  'kEnableDefaultMediaSession',
#  'kEnableAutoReload',
#  'kEnableAccessibilityExposeIgnoredNodes',
#  'kEnableUnifiedMultiDeviceSettings',
#  'kCrOSActionRecorderDisabled',
#  'kDisableHostedAppShimCreation',
#  'kEnablePermissionActionReporting',
#  'kEnableZeroSuggestMostVisited',
#  'kEnableAdaptiveSelectionHandleOrientation',
#  'kEnableHoudini64',
#  'kEnableWebKitMediaSource',
#  'kEnableSettingsWindow',
#  'kDisableSuggestionsService',
#  'kDisableNTPOtherSessionsMenu',
#  'kEnableDeferredImageDecoding',
#  'kEnableShowSavedCopyPrimary',
#  'kEnableWebNotificationCustomLayouts',
#  'kEnableUnifiedMediaPipeline',
#  'kEnableLRUSnapshotCache',
#  'kDisablePnaclInstall',
#  'kEnableBeginFrameControl',
#  'kEnableDefaultApps',
#  'kEnableWindowsGamingInputDataFetcher',
#  'kSyncForceDisableScryptForCustomPassphrase',
#  'kAshEnableTrayDragging',
#  'kEnableArcOOBEOptIn',
#  'kEnableSecondaryAccountsForChild',
#  'kDisablePolicyKeyVerification',
#  'kEnableExperimentalCanvasFeatures',
#  'kDisableFillOnAccountSelect',
#  'kDisableFullScreen',
#  'kUtilityProcessEnableMDns',
#  'kMixerEnableDynamicChannelCount',
#  'kEnableGpuSandbox',
#  'kDisableUsbKeyboardDetect',
#  'kEnableMacCookies',
#  'kDisableAcceleratedJpegDecoding',
#  'kEnableSettingsShortcutSearch',
#  'kEnablePnacl',
#  'kWebViewEnableSharedImage',
#  'kUIEnableZeroCopy',
#  'kEnableSlimmingPaintInvalidation',
#  'kEnableSdchPersistence',
#  'kDisableKillAfterBadIPC',
#  'kEnableSnapStart',
#  'kEnableAnswersInSuggest',
#  'kEnableExplicitDmaFences',
#  'kDisableSiteEngagementService',
#  'kEnableTabSwitcher',
#  'kEnableOriginChipV2',
#  'kEnableMojoShellConnection',
#  'kDisableMdOobe',
#  'kDisableSeccompSandbox',
#  'kDisableDistanceFieldText',
#  'kEnableLayerSquashing',
#  'kDisableSyncTypedUrls',
#  'kDisableWebRtcHWVP8Encoding',
#  'kDisableArcOptInVerification',
#  'kEnableIPv6',
#  'kEnableWebkitTextSubpixelPositioning',
#  'kDisableClientSidePhishingDetection',
#  'kUIEnablePerTilePainting',
#  'kEnableZeroSuggestPersonalized',
#  'kDisableFixedPositionCreatesStackingContext',
#  'kDisablePanels',
#  'kDisableWebsiteSettings',
#  'kAnswersRichUiEnabled',
#  'kEnableSideGesturePassThrough',
#  'kDisableSystemFullscreenForTesting',
#  'kEnablePersistentFilesystemInIncognito',
#  'kEnablePermissionsBubbles',
#  'kEnableDeferred2dCanvas',
#  'kDisableVaapiAcceleratedVideoEncode',
#  'kEnableSyncSyncedNotifications',
#  'kAshDisableSystemSounds',
#  'kDisableCancelAllTouches',
#  'kDisableInstantExtendedAPI',
#  'kDisableSurfaceControlForWebview',
#  'kDisableInternalFlash',
#  'kAnswersTranslationEnabled',
#  'kForceDisableWebRtcApmInAudioService',
#  'kDisable2dCanvasAntialiasing',
#  'kEnableBackgroundMode',
#  'kEnableThreadedCompositing',
#  'kDisableFeatures',
#  'kEnableSyncPasswords',
#  'kEnableXSSAuditor',
#  'kEnableGPUCommandLogging',
#  'kDisableSiteIsolation',
#  'kDisableD3D11',
#  'kTopChromeTouchUiDisabled',
#  'kEnableOpusPlayback',
#  'kDefaultEnableOopRasterization',
#  'kEnableDisplayList2dCanvas',
#  'kSbDisableExtensionBlacklist',
#  'kEnableZeroStateSuggestions',
#  'kDisableDeadlineScheduling',
#  'kDisableWebAudio',
#  'kDisableSyncTypes',
#  'kEnableBeginFrameScheduling',
#  'kDisableThreadedAnimation',
#  'kDisableRemotePlaybackAPI',
#  'kDisableSaveCardBubble',
#  'kEnableAppWindowControls',
#  'kAmbientModeCulturalInstitutePhotosEnabled',
#  'kEnableDocumentsProviderInFilesAppFeature',
#  'kEnableContacts',
#  'kDisablePinch',
#  'kEnablePrivilegedWebGLExtensions',
#  'kDisableES3APIs',
#  'kDisableGpuProcessPrelaunch',
#  'kEnableFixedLayout',
#  'kEnableWebMIDI',
#  'kDisableGaiaServices',
#  'kDisableVirtualKeyboard',
#  'kEnableMessageCenterAlwaysScrollUpUponNotificationRemoval',
#  'kEnableVrShell',
#  'kDisableZipArchiverPacker',
#  'kAmbientModeCapturedOnPixelAlbumEnabled',
#  'kDisableVp8AlphaPlayback',
#  'kDisableExperimentalWebGL',
#  'kEnableOriginChipOnSrp',
#  'kEnableTouchpadThreeFingerClick',
#  'kOmniboxHistoryQuickProviderNewScoringDisabled',
#  'kEnableMaterialDesignSettings',
#  'kEnableWebRtcSrtpAesGcm',
#  'kEnableGamepad',
#  'kPpapiAntialiasedTextEnabled',
#  'kEnableHomeLauncher',
#  'kWebRtcEnableCaptureMultiChannelApm',
#  'kEnableStyleScoped',
#  'kEnableFullscreenHandwritingVirtualKeyboard',
#  'kEnableThreadedTextureMailboxes',
#  'kDisableSiteIsolationForPolicy',
#  'kEnableProtectedVideoBuffers',
#  'kEnableTeamDrives',
#  'kAshEnablePowerButtonQuickLock',
#  'kEnableAeroPeekTabs',
#  'kEnableIdleTracing',
#  'kEnableGoogleNowIntegration',
#  'kEnableUiDevTools',
#  'kEnableAppShortcutSearch',
#  'kEnableRasterToSkImage',
#  'kDisableDirectWrite',
#  'kEnableExperimentalCookieFeatures',
#  'kEnableGenericSensors',
#  'kEnableExperimentalWebGL',
#  'kEnableFolderUI',
#  'kEnableSharedImageForWebview',
#  'kEnableDOMUIMenu',
#  'kAudioModemEnableInaudibleBroadcast',
#  'kDisableVulkanFallbackToGLForTesting',
#  'kEnableSpdyCredentialFrames',
#  'kDisableGpuCompositing',
#  'kDisableSingleClickAutofill',
#  'kDisableIOSPasswordSuggestions',
#  'kEnableSSLCachedInfo',
#  'kAutofillEnableLocalCardMigrationForNonSyncUser',
#  'kEnablePreferCompositingToLCDText',
#  'kDisableDefaultApps',
#  'kEnableOmniboxAutoCompletionForIme',
#  'kDisableDevShmUsage',
#  'kDisableMacViewsNativeAppWindows',
#  'kDisableExperimentalAppList',
#  'kDisableWebGL',
#  'kDisableTranslateNewUX',
#  'kDisable3DAPIs',
#  'kEnableMacViewsNativeAppWindows',
#  'kEnableAVFoundation',
#  'kDisableInteractiveFormValidation',
#  'kDisableShaderNameHashing',
#  'kEnableLinkDisambiguationPopup',
#  'kDisableImageTransportSurface',
#  'kAshEnableSoftwareMirroring',
#  'kDisableFieldTrialTestingConfig',
#  'kEnableOriginChipTrailingLocationBar',
#  'kEnableContentVideoViewPowerSaveBlocker',
#  'kEnableCloudPrintProxy',
#  'kDisableSearchGeolocationDisclosure',
#  'kEnableNewProfileManagement',
#  'kEnableDataReductionProxySavingsPromo',
#  'kEnableOverscrollNotifications',
#  'kDisableOfflinePages',
#  'kDisableDriveSearchInChromeLauncher',
#  'kDisableSyncExtensionSettings',
#  'kDisableForceCompositingMode',
#  'kAshEnableTouchViewTesting',
#  'kEnabled',
#  'kAppCacheForceEnabled',
#  'kEnableAsyncDns',
#  'kEnableWebFontsInterventionV2SwitchValueEnabledWith3G',
#  'kDisableNTPFavicons',
#  'kEnableDisplayCompositorPixelDump',
#  'kEnableExperimentalAccessibilityLabelsDebugging',
#  'kEnableUniversalAcceleratedOverflowScroll',
#  'kDisableSharedWorkers',
#  'kEnableAppShims',
#  'kDisableGpuMemoryBufferCompositorResources',
#  'kEnableExperimentalHotwordHardware',
#  'kEnableAppRanker',
#  'kDisableSearchButtonInOmnibox',
#  'kAshEnableAdvancedGestures',
#  'kEnableSwapBuffersWithBounds',
#  'kOmniboxHistoryQuickProviderReorderForInliningDisabled',
#  'kDisablePeopleSearch',
#  'kEnableOriginChipV2HideOnMouseRelease',
#  'kDisableSettingsWindow',
#  'kGestureEditingEnabled',
#  'kEnableAudioTrackProcessing',
#  'kDisableAcceleratedVideoDecode',
#  'kEnableInputView',
#  'kEnableSingleClickAutofill',
#  'kEnableCrOSActionRecorder',
#  'kDisableRestoreBackgroundContents',
#  'kSyncEnableGetUpdateAvoidance',
#  'kDisableSyncSearchEngines',
#  'kEnableColorCorrectRendering',
#  'kAshDisableSmoothScreenRotation',
#  'kDisableSeccompFilterSandbox',
#  'kGestureEditingDisabled',
#  'kEnableDomDistillerButtonAnimation',
#  'kEnableChildToRegularTransitionFeature',
#  'kEnableTabletFormFactor',
#  'kEnableMemoryBenchmarking',
#  'kForceToDisableOutOfBlinkCors',
#  'kEnableServiceBinaryLauncher',
#  'kDisablePhysicalKeyboardAutocorrect',
#  'kEnableSyncTypedUrls',
#  'kDisableAltWinstation',
#  'kEnableLocalFileAccesses',
#  'kDisableCoreAnimationPlugins',
#  'kEnableAppReinstallZeroState',
#  'kDisableOpusPlayback',
#  'kEnableNdkTranslation',
#  'kDisableConnectBackupJobs',
#  'kEnableSiteEngagementAppBanner',
#  'kEnablePresetsParameterName',
#  'kEnableRepaintAfterLayout',
#  'kEnableDevicePolicy',
#  'kDisableLowResTiling',
#  'kDisableIgnoreAutocompleteOff',
#  'kEnableRendererAccessibility',
#  'kDisableJobUpdatePriority',
#  'kAshNewLockAnimationsEnabled',
#  'kUIEnableThreadedCompositing',
#  'kEnablePlayStoreAppSearch',
#  'kDisableFactoryReset',
#  'kDisableFlashStage3d',
#  'kEnableAdview',
#  'kEnableDawnFeatures',
#  'kSyncDisableRollback',
#  'kDisablePushStateThrottle',
#  'kEnableWin7WebRtcHWH264Decoding',
#  'kEnableGpuAsyncWorkerContext',
#  'kEnableNewStyleLauncher',
#  'kEnableSlimmingPaintV2',
#  'kDisableSpeechInput',
#  'kEnableVideoTrack',
#  'kActivationLevelEnabled',
#  'kEnableWebUITaskManager',
#  'kDataReductionProxyServerExperimentsDisabled',
#  'kEnableOopPrintDrivers',
#  'kEnableExperimentalAccessibilityLanguageDetectionDynamic',
#  'kEnableExtensionAssetsSharing',
#  'kDisableAppLink',
#  'kEnableSupervisedUserBlacklist',
#  'kEnableAppGridGhost',
#  'kHeavyAdReportingEnabledParamName',
#  'kEnableAdaptiveResultRanker',
#  'kDisableSyncDictionary',
#  'kDisableScriptedPrintThrottling',
#  'kDisableFullFormAutofillIOS',
#  'kEnableAuthNegotiatePort',
#  'kEnableDomainReliability',
#  'kDisableEnterpriseUserReporting',
#  'kAutofillEnableSaveCardInfoBarAccountIndicationFooter',
#  'kDisableGpuMemoryBufferVideoFrames',
#  'kDisableMinimizeOnSecondLauncherItemClick',
#  'kDisableSyncBookmarks',
#  'kDisableGpu',
#  'kDisableFetchingHintsAtNavigationStartForTesting',
#  'kDisableTestCompositor',
#  'kDisableCheckingUserPermissionsForTesting',
#  'kDisableBlinkScheduler',
#  'kAmbientModeFeaturedPhotoAlbumEnabled',
#  'kAutoplayDisableSettings',
#  'kTLS13VariantDisabled',
#  'kDisableTabSwitcher',
#  'kEnableOpenMax',
#  'kOriginTrialDisabledFeatures',
#  'kEnableDeprecatedPeerConnection',
#  'kEnableOSKOverscroll',
#  'kEnableWelcomeWin10',
#  'kDisableIpv4',
#  'kEnableNativeNotifications',
#  'kEnablePermissionsBlacklist',
#  'kEnableCrashReporter',
#  'kDisableSkiaRuntimeOpts',
#  'kEnableKioskMode',
#  'kDisableTLS1',
#  'kEnableRendererMojoChannel',
#  'kEnableOverlayFullscreenVideoSubtitle',
#  'kDisableNavigatorContentUtils',
#  'kDisableAnswersInSuggest',
#  'kDisableV8IdleNotificationAfterCommit',
#  'kEnableNTPFavicons',
#  'kEnablePixelCanvasRecording',
#  'kEnableViewsTextfield',
#  'kDisableQuicPortSelection',
#  'kDisableJava',
#  'kDisableSessionStorage',
#  'kEnableAppInfoDialogMac',
#  'kEnableAutofillFeedback',
#  'kEnableOobeTestAPI',
#  'kDisablePromptOnRepost',
#  'kAmbientModeEarthAndSpaceAlbumEnabled',
#  'kEnableSuggestionsTabPage',
#  'kAutofillEnableAugmentedPhoneCountryCode',
#  'kTouchEventFeatureDetectionEnabled',
#  'kDisableAutoReload',
#  'kEnableImeMenu',
#  'kDisableTabCloseableStateWatcher',
#  'kDisableMipmapGeneration',
#  'kEnableNewAppListMixer',
#  'kDisableNewWallpaperUI',
#  'kUIDisableThreadedCompositing',
#  'kSbDisableAutoUpdate',
#  'kDisableScalingInImageSkiaOperations',
#  'kEnableCrxlessWebApps',
#  'kEnableLocalOnlyInstantExtendedAPI',
#  'kDisableSyncApps',
#  'kEnableMobileSetupDialog',
#  'kEnableOfflineAutoReloadVisibleOnly',
#  'kEnableExperimentalAccessibilityFeatures',
#  'kEnableNpapi',
#  'kEnableAccessibilityLogging',
#  'kEnableZeroStateAppsRanker',
#  'kEnableExperimentalAccessibilitySwitchAccess',
#  'kEnableCreditCardScan',
#  'kEnableSaveAsMenuLabelExperiment',
#  'kEnableFastback',
#  'kEnableGPUDebugging',
#  'kEnableExperimentalAccessibilityLanguageDetection',
#  'kDisablePrintPreview',
#  'kProactiveTabFreezeAndDiscard_DisableHeuristicsParam',
#  'kDisableRepaintAfterLayout',
#  'kEnableWebApk',
#  'kDisablePreconnect',
#  'kAutofillEnableToolbarStatusChip',
#  'kEnableComponentCloudPolicy',
#  'kEnableUseHDRTransferFunction',
#  'kDisableBackForwardCache',
#  'kDisableCompositedScrollingForFrames',
#  'kDisableHTMLNotifications',
#  'kEnableSearchProviderApiV2',
#  'kEnableClientHints',
#  'kDisableMojoRenderer',
#  'kEnableFullScreen',
#  'kEnableAccelerated2dCanvas',
#  'kEnableAdviewSrcAttribute',
#  'kGestureTypingEnabled',
#  'kWebViewDisableSafebrowsingSupport',
#  'kDisableFileManagerTouchMode',
#  'kEnableManagerForSyncSignin',
#  'kAutofillEnableIFrameSupportOniOS',
#  'kDisablePnacl',
#  'kDisableNewDialogStyle',
#  'kDisableV8IdleTasks',
#  'kEnableDirectCompositionLayers',
#  'kScreenNotificationsEnabled',
#  'kDisableOriginTrialControlledBlinkFeatures',
#  'kDisableCastStreamingHWEncoding',
#  'kEnableWebRtcHWVp8Encoding',
#  'kWebIntentsNativeServicesEnabled',
#  'kDisableWebGL2',
#  'kDisableUnifiedMediaPipeline',
#  'kDisableTargetBlankImpliesNoOpener',
#  'kDisableHistogramCustomizer',
#  'kDisableApplicationCache',
#  'kEnableAppLink',
#  'kOriginTrialDisabledTokens',
#  'kEnableMediaSource',
#  'kDisableLoggingRedirect',
#  'kEnableTabEviction',
#  'kDisableRollbackOption',
#  'kDisableHidBlocklist',
#  'kEnableFileManagerPiexWasm',
#  'kDisableLogging',
#  'kDisablePrivetLocalPrinting',
#  'kDisableLegacyEncryptedMedia',
#  'kEnableSignedCertificateTimestampsViewer',
#  'kDisableFocusController',
#  'kTouchEventsDisabled',
#  'kEnableTouch',
#  'kEnterpriseDisableArc',
#  'kDisableIdleSocketsCloseOnMemoryPressure',
#  'kEnableAppsShowOnFirstPaint',
#  'kEnableAggressiveDOMStorageFlushing',
#  'kEnableIOSPhysicalWeb',
#  'kDisableThreadedCompositing',
#  'kEnableNewCanvas2DAPI',
#  'kAshMaterialDesignDisabled',
#  'kEnableWebStoreLink',
#  'kDisableOriginChip',
#  'kAshDisableBootAnimation2',
#  'kAutofillEnableGoogleIssuedCard',
#  'kDisableMemoryPressureSystemChromeOS',
#  'kEnableEncryptionSelection',
#  'kDisableAccessorySuggestionView',
#  'kDisableAllBookmarksView',
#  'kDisableOmniboxAutoCompletionForIme',
#  'kDisableUniversalAcceleratedOverflowScroll',
#  'kEnableShareGroupAsyncTextureUpload',
#  'kAutofillEnableCardNicknameUpstream',
#  'kDisableWebRtcEncryption',
#  'kEnableLoginScreenApps',
#  'kDisableGpuEarlyInit',
#  'kDisableAVFoundationOverlays',
#  'kDisableIMEModeIndicator',
#  'kEnableViewPaintOptimization',
#  'kEnableExtensionTimelineApi',
#  'kAshEnableSmoothScreenRotation',
#  'kEnableClearServerData',
#  'kEnterpriseEnableInitialEnrollment',
#  'kEnableOfflinePages',
#  'kDisableGpuShaderDiskCache',
#  'kEnableStubInteractive',
#  'kDisableBreakpad',
#  'kScreenInlineReplyEnabled',
#  'kEnableBrowserSideNavigation',
#  'kDisableBundledPpapiFlash',
#  'kAuraDisableHoldMouseMoves',
#  'kEnableIncognitoWindowCounter',
#  'kAutofillEnableDependentLocalityParsing',
#  'kEnableSpdy4a2',
#  'kEnableOfferStoreUnmaskedWalletCards',
#  'kEnableAppInstallAlerts',
#  'kEnableDemoMode',
#  'kEnableReaderModeToolbarIcon',
#  'kDisableFlashFullscreen3d',
#  'kGLImplementationDisabledName',
#  'kEnableWebFontsInterventionV2',
#  'kEnableAutomaticUiAdjustmentsForTouch',
#  'kEnableWebSocketOverSpdy',
#  'kDisableBackingStoreLimit',
#  'kAutofillEnableSurfacingServerCardNickname',
#  'kDisableHangMonitor',
#  'kEnableHostedAppsInWindows',
#  'kDisableAppContainer',
#  'kDisableAudioOutputResampler',
#  'kDisableLegacyIntermediateWindow',
#  'kEnableMergeKeyCharEvents',
#  'kEnableFilesAppCopyImage',
#  'kDisableInputView',
#  'kDisableNewNetworkChangeNotifier',
#  'kEnableSyncNewAutofill',
#  'kAutofillEnableOffersInClankKeyboardAccessory',
#  'kEnableImplSidePainting',
#  'kAutofillEnableInfoBarAccountIndicationFooterForSingleAccountUsers',
#  'kEnableNetworkTime',
#  'kDisableWin32kLockDown',
#  'kArcDisableLocaleSync',
#  'kAshDisableLockLayoutManager',
#  'kEnableSettingsApp',
#  'kEnableAudioMixer',
#  'kDisableArcCpuRestriction',
#  'kDisableAboutInSettings',
#  'kDisablePullToRefreshEffect',
#  'kPrerenderSwitchValueDisabled',
#  'kDisableOOBEChromeVoxHintTimerForTesting',
#  'kEnterpriseEnableForcedReEnrollment',
#  'kDisableResizeLock',
#  'kDisableGestureEditing',
#  'kEnableGPUServiceTracing',
#  'kEnableCompositorAnimationTimelines',
#  'kDisablePopupBlocking',
#  'kEnableContinueReading',
#  'kEnableFastTextAutosizing',
#  'kEnableNpnHttpOnly',
#  'kDisableMediaSessionAPI',
#  'kDisableRemoteFonts',
#  'kAshMaterialDesignEnabled',
#  'kEnableSdchOverHttps',
#  'kDisableMaterialDesignNTP',
#  'kDisableImageAnimationResync',
#  'kEnableSkiaBenchmarking',
#  'kDisableFineGrainedTimeZoneDetection',
#  'kEnablePredictiveInstant',
#  'kEnableNewDialogStyle',
#  'kDisableAppMode',
#  'kEnableNewAvatarMenu',
#  'kArcDisableSystemDefaultApps',
#  'kEnableSpatialNavigation',
#  'kDisableExtensionsExcept',
#  'kEnableDeferredFilters',
#  'kEnableExperimentalInputViewFeatures',
#  'kEnableSoftwareCompositing',
#  'kEnableAppContainer',
#  'kDisableIpcFloodingProtection',
#  'kDisableSoftwareRasterizer',
#  'kEnableMacViewsAppList',
#  'kEnableDefaultMediaSessionDuckFlash',
#  'kDisablePerUserTimezone',
#  'kDisableDhcpWpad',
#  'kEnableCanvas2dDynamicRenderingModeSwitching',
#  'kEnableArcVm',
#  'kEnableLauncherSearchNormalization',
#  'kEnableTranslateNewUX',
#  'kEnableAccessibilityExposeDisplayNone',
#  'kEnableAccountConsistency',
#  'kUIEnableRGBA4444Textures',
#  'kEnablePrecache',
#  'kEnableFtp',
#  'kAshDisableOverviewMode',
#  'kEnableDriveV2Api',
#  'kDisableDwmComposition',
#  'kDisableGpuProcessForDX12VulkanInfoCollection',
#  'kAshDisableDragOffShelf',
#  'kEnableMonitorProfile',
#  'kDisableDeviceDiscoveryNotifications',
#  'kDisableAsyncDns',
#  'kEnableAppsFileAssociations',
#  'kEnableIOSPasswordGeneration',
#  'kEnableGpuBlockedTime',
#  'kEnableEasterEggBdayMode',
#  'kTouchEventsEnabled',
#  'kDisableES3GLContextForTesting',
#  'kEnableImageColorProfiles',
#  'kDisableAcceleratedCompositing',
#  'kEnableDawnBackendValidation',
#  'kEnableAccessibility',
#  'kDisabled',
#  'kEnableGlobalBookmarkMenu',
#  'kDisableNewBookmarkApps',
#  'kEnableHoudini',
#  'kDisableDisplayColorCalibration',
#  'kEnableUnrestrictedSSL3Fallback',
#  'kDefaultEnableGpuRasterization',
#  'kEnableQuicPortSelection',
#  'kAmbientModePersonalPhotosEnabled',
#  'kEnableInBrowserThumbnailing',
#  'kEnableClickToPlay',
#  'kEnableAndroidSpellChecker',
#  'kEnableAudioDebugRecordingsFromExtension',
#  'kAutofillEnableSupportForMergingSubsetNames',
#  'kDisableOneCopy',
#  'kDisableVulkanSurface',
#  'kEnterpriseEnablePrivateSetMembership',
#  'kDisableMetrics',
#  'kEnableResetProfileSettings',
#  'kEnableSearchButtonInOmniboxForStrOrIip',
#  'kEnableSpdyProxyAuth',
#  'kEnableRemoting',
#  'kEnableSpeechSynthesis',
#  'kDisableLocalAccounts',
#  'kDisableSurfaceLayerForVideo',
#  'kEnableSuggestedFiles',
#  'kEnableWebGL2ComputeContext',
#  'kEnableAcceleratedScrollableFrames',
#  'kAshDisableAutoWindowPlacement',
#  'kAlsaEnableUpsampling',
#  'kEnableBluetoothSerialPortProfileInSerialApi',
#  'kEnableLowResTiling',
#  'kDisableAppBanners',
#  'kEnableSCTPDataChannels',
#  'kEnableNpn',
#  'kDisableSCTPDataChannels',
#  'kDisableBackgroundingOccludedWindowsForTesting',
#  'kEnableNewNTP',
#  'kEnableWebFontsInterventionV2SwitchValueEnabledWithSlow2G',
#  'kEnableADTSStreamParser',
#  'kDisablePasswordAutofillPublicSuffixDomainMatching',
#  'kEnableTether',
#  'kActivationStateDisabled',
#  'kEnableAppListShim',
#  'kEnableAppList',
#  'kAshDisableSoftwareMirroring',
#  'kEnablePerMonitorDpi',
#  'kDisableOnly',
#  'kDisableDomainBlockingFor3DAPIs',
#  'kDisableInfoBars',
#  'kDisableVolumeAdjustSound',
#  'kEnableSupervisionTransitionScreens',
#  'kEnableAcceleratedDrawing',
#  'kAutofillEnableStickyPaymentsBubble',
#  'kDisableNotifications',
#  'kEnableHardwareMirrorMode',
#  'kEnableAuraTooltipsOnWindows',
#  'kDisableOutdatedPlugins',
#  'kEnableBookmarkUndo',
#  'kEnableAcceleratedCompositingForOverflowScroll',
#  'kEnableSuggestionsUI',
#  'kEnableMaterialDesignNTP',
#  'kUIDisableSlimmingPaint',
#  'kOmniboxDisableInstantExtendedLimit',
#  'kDisableSyncAppList',
#  'kEnableUseZoomForDSF',
#  'kDisableBufferBWCompression',
#  'kEnableNonValidatingReloadOnRefreshContent',
#  'kDisableImages',
#  'kEnableDeadlineScheduling',
#  'kDisableWebSecurity',
#  'kAshForceEnablePalette',
#  'kAshDisableDisplayChangeLimiter',
#  'kEnableAccessibilityLanguageDetection',
#  'kEnableBackgroundLoader',
#  'kEnableInput',
#  'kDisableMainThreadAudio',
#  'kEnableNdkTranslation64',
#  'kDisableRunningAsSystemCompositor',
#  'kDisableFileSystem',
#  'kEnableDisplayZoomSetting',
#  'kDisableDataReductionProxyWarmupURLFetch',
#  'kDisable2dCanvasClipAntialiasing',
#  'kEnableLinkableEphemeralApps',
#  'kEnableNetworkInformation',
#  'kDisableExtensionsHttpThrottling',
#  'kEnableGamepadButtonAxisEvents',
#  'kDisableAcceleratedScrollableFrames',
#  'kDisableWebRtcHWEncoding',
#  'kEnableChromeAudioSwitching',
#  'kDisablePdfMaterialUI',
#  'kEnableEncryptedMedia',
#  'kDisableWebRTC',
#  'kEnableAndroidWallpapersApp',
#  'kDisableLocalFirstLoadNTP',
#  'kEnableChromeVoxNext',
#  'kDisableLocalStorage',
#  'kDisableGoogleNowIntegration',
#  'kEnableGPUPlugin',
#  'kDisableIPv6',
#  'kEnableFullscreenToolbarReveal',
#  'kDisableWebNotificationCustomLayouts',
#  'kEnablePointerLock',
#  'kEnableReachedCodeProfiler',
#  'kEnableTopSites',
#  'kEnableSaveCardBubble',
#  'kAmbientModeFeaturedPhotosEnabled',
#  'kDisableSyncEncryption',
#  'kEnableRichNotifications',
#  'kEnableQueryBasedMixedTypesRanker',
#  'kDisableAcceleratedOverflowScroll',
#  'kDisableVulkanForTestsSwitch',
#  'kEnableSyncOAuth',
#  'kDisableGestureDebounce',
#  'kDisableExperimentalAccessibilityChromeVoxLanguageSwitching',
#  'kEnableSeccompFilterSandbox',
#  'kEnableGPUClientLogging',
#  'kEnableSensors',
#  'kAshDisableDockedWindows',
#  'kDisableTouchAdjustment',
#  ...]

# %% [markdown]
# # Nested Codes inside code files....

# %%
dead_test_files = glob.glob('/Users/govardhanrathamsetty/Desktop/ToggleSmell-Chromium/All versions/**/chromium 90.0.4390.0/**/*.cc', recursive=True)
dead_list, dead_list2,dead_list3=[], [], []
        

for code_lines in dead_test_files:
    if 'switch' not in code_lines:
        if 'feature' not in code_lines:
            with open(code_lines, 'rb') as file:  
                try:
                    content = file.read().decode('utf-8')  
                    dead_list.append(content)
                except UnicodeDecodeError:
                    pass

patterns = [r'.*HasSwitch\(.*\)']

for dead in dead_list:
    for pattern in patterns:
        matches = re.findall(pattern, dead)
        dead_list2.extend(matches)

dead_list2
# Out:
# ['  if (command_line->HasSwitch(kHelpSwitchName)',
#  '      command_line->HasSwitch(kQuestionSwitchName))',
#  '  if (command_line->HasSwitch(kVersionSwitchName))',
#  '  if (command_line->HasSwitch(kElevateSwitchName))',
#  '  if (command_line->HasSwitch(kProcessTypeSwitchName))',
#  '    if (command_line->HasSwitch(kEvaluateCapabilitySwitchName))',
#  '  if (command_line->HasSwitch(kHostConfigSwitchName))',
#  '  if (cmd_line->HasSwitch(kCheckAccessibilityPermissionSwitchName))',
#  '  if (cmd_line->HasSwitch(kCheckScreenRecordingPermissionSwitchName))',
#  '  if (cmd_line->HasSwitch(kHostConfigSwitchName))',
#  '  signal_parent_ = cmd_line->HasSwitch(kSignalParentSwitchName)',
#  '  if (cmd_line->HasSwitch(kReportOfflineReasonSwitchName))',
#  '  if (command_line->HasSwitch(kHostConfigSwitchName))',
#  '  if (command_line->HasSwitch(kElevateSwitchName))',
#  '    DCHECK(command_line->HasSwitch(kInputSwitchName))',
#  '    DCHECK(command_line->HasSwitch(kOutputSwitchName))',
#  '  if (cmd_line->HasSwitch(kCheckAccessibilityPermissionSwitchName))',
#  '  if (cmd_line->HasSwitch(kCheckScreenRecordingPermissionSwitchName))',
#  '  DCHECK(!current_command_line->HasSwitch(kElevateSwitchName))',
#  '      command_line->HasSwitch(kConsoleSwitchName))',
#  '  if (command_line->HasSwitch("help") || command_line->HasSwitch("h")',
#  '      command_line->HasSwitch("?") || !command_line->GetArgs().empty())',
#  '  if (command_line->HasSwitch(kCheckPermissionSwitchName))',
#  '  if (command_line->HasSwitch(kParentWindowSwitchName))',
#  '  if (command_line->HasSwitch(kElevateSwitchName))',
#  '    DCHECK(command_line->HasSwitch(kInputSwitchName))',
#  '    DCHECK(command_line->HasSwitch(kOutputSwitchName))',
#  '  if (current_process->HasSwitch(kHostConfigSwitchName))',
#  '  if (current_cmdline->HasSwitch(remoting::kSwitchDisable))',
#  '  } else if (current_cmdline->HasSwitch(remoting::kSwitchEnable))',
#  '  } else if (current_cmdline->HasSwitch(remoting::kSwitchSaveConfig))',
#  '  } else if (current_cmdline->HasSwitch(remoting::kSwitchHostVersion))',
#  '  } else if (current_cmdline->HasSwitch(remoting::kSwitchHostRunFromLaunchd))',
#  '    if (command_line->HasSwitch(kFtlServerEndpointSwitch))',
#  '    if (command_line->HasSwitch(kRemotingServerEndpointSwitch))',
#  '  if (base::CommandLine::ForCurrentProcess()->HasSwitch(kHelp))',
#  '  if (command_line->HasSwitch("partial-primary-plane"))',
#  '  if (command_line->HasSwitch("enable-overlay"))',
#  '  disable_primary_plane_ = command_line->HasSwitch("disable-primary-plane")',
#  '  if (!base::CommandLine::ForCurrentProcess()->HasSwitch(kDisableSurfaceless))',
#  '  if (command_line->HasSwitch(kEnableVulkan))',
#  '  if (!command_line->HasSwitch(kDisableGpu) && gl::init::InitializeGLOneOff())',
#  '      use_ddl_(base::CommandLine::ForCurrentProcess()->HasSwitch(kUseDDL))',
#  '  if (command_line->HasSwitch(kPartialPrimaryPlane))',
#  '  if (command_line->HasSwitch(kEnableOverlay))',
#  '  disable_primary_plane_ = command_line->HasSwitch(kDisablePrimaryPlane)',
#  '  if (!base::CommandLine::ForCurrentProcess()->HasSwitch(kDisableSurfaceless))',
#  '  if (command_line->HasSwitch(switches::kVSyncInterval))',
#  '        base::CommandLine::ForCurrentProcess()->HasSwitch("disable-gpu")',
#  '  DCHECK(!cmd_line->HasSwitch(switches::kEnableWaylandIme)',
#  '         !cmd_line->HasSwitch(switches::kDisableWaylandIme))',
#  '  if (cmd_line->HasSwitch(switches::kEnableWaylandIme))',
#  '  if (cmd_line->HasSwitch(switches::kDisableWaylandIme))',
#  '  if (command_line->HasSwitch(switches::kTestGLLib))',
#  '  if (cmd->HasSwitch(switches::kOzoneDumpFile))',
#  '  if (command_line->HasSwitch(cc::switches::kUIShowCompositedLayerBorders))',
#  '      command_line->HasSwitch(cc::switches::kUIShowFPSCounter)',
#  '      command_line->HasSwitch(cc::switches::kUIShowLayerAnimationBounds)',
#  '      command_line->HasSwitch(switches::kUIShowPaintRects)',
#  '      command_line->HasSwitch(cc::switches::kUIShowPropertyChangedRects)',
#  '      command_line->HasSwitch(cc::switches::kUIShowSurfaceDamageRects)',
#  '      command_line->HasSwitch(cc::switches::kUIShowScreenSpaceRects)',
#  '      command_line->HasSwitch(cc::switches::kEnableGpuBenchmarking))',
#  '      command_line->HasSwitch(cc::switches::kUIEnableLayerLists)',
#  '      command_line->HasSwitch(switches::kUIEnableRGBA4444Textures)',
#  '      command_line->HasSwitch(switches::kDisallowNonExactResourceReuse)',
#  '  if (command_line->HasSwitch(switches::kRunAllCompositorStagesBeforeDraw))',
#  '  if (command_line->HasSwitch(cc::switches::kLogOnUIDoubleBackgroundBlur))',
#  '  if (command_line->HasSwitch(switches::kUISlowAnimations))',
#  '  if (command_line->HasSwitch(switches::kUseCmdDecoder))',
#  '    if (command_line->HasSwitch(switches::kUseAdapterLuid))',
#  '      !command_line->HasSwitch(switches::kUseANGLE)',
#  '      if (!command_line->HasSwitch(switches::kDisableD3D11))',
#  '      command_line->HasSwitch(switches::kDisableGpuDriverBugWorkarounds)',
#  '    if (command_line->HasSwitch(switches::kDisableDirectComposition))',
#  '  if (command_line->HasSwitch(switches::kEnableDirectCompositionVideoOverlays))',
#  '  if (command_line->HasSwitch(switches::kDisableDirectCompositionVideoOverlays))',
#  '  if (cmd->HasSwitch(switches::kUseGL)',
#  '  if (cmd->HasSwitch(switches::kDisableES3GLContext))',
#  '  if (cmd->HasSwitch(switches::kDisableES3GLContextForTesting))',
#  '  if (cmd->HasSwitch(switches::kOverrideUseSoftwareGLForTests))',
#  '  } else if (cmd->HasSwitch(switches::kUseGL))',
#  '  bool disable_gl_drawing = cmd->HasSwitch(switches::kDisableGLDrawingForTests)',
#  '  if (command_line->HasSwitch(switches::kTestGLLib))',
#  '  if (!command_line->HasSwitch(::switches::kHostWindowBounds))',
#  '  bool ret = command_line->HasSwitch(::switches::kUseFirstDisplayAsInternal)',
#  '  if (command_line->HasSwitch(switches::kSecondaryDisplayLayout))',
#  '  if (!command_line->HasSwitch(switches::kSecondaryDisplayLayout))',
#  '  if (command_line->HasSwitch(switches::kScreenConfig))',
#  '      !base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kHeadless)',
#  '      !base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kHeadless))',
#  '    params.single_process = command_line->HasSwitch("single-process")',
#  '                            command_line->HasSwitch("in-process-gpu")',
#  '  if (command_line->HasSwitch(switches::kForceTextDirection))',
#  '  if (base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kHeadless))',
#  '  if (base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kHeadless))',
#  '  if (base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kHeadless))',
#  '  if (base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kNoXshm))',
#  '  if (base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kHeadless))',
#  '  if (cmd->HasSwitch(kCountSwitch))',
#  '  bool permute = cmd->HasSwitch(kPermuteSwitch)',
#  '  if (args.size() == 0 || args.size() > 2 || cmd->HasSwitch(kHelpSwitch))',
#  '  if (cmd->HasSwitch(kFuzzerNameSwitch))',
#  '  if (cmd->HasSwitch(kFrequencySwitch))',
#  '  if (args.size() < 1 || args.size() > 2 || cmd->HasSwitch(kHelpSwitch))',
#  '  if (cmd->HasSwitch(kStartSwitch))',
#  '  if (cmd->HasSwitch(kEndSwitch))',
#  '  bool has_regexp = cmd->HasSwitch(kRegexpSwitch)',
#  '  bool invert = cmd->HasSwitch(kInvertSwitch)',
#  '  bool perform_dump = cmd->HasSwitch(kDumpSwitch)',
#  '  bool has_indices = cmd->HasSwitch(kInSwitch)',
#  '      cmd_line.HasSwitch("serial-id")',
#  '  if (cmd_line.HasSwitch("kill-server"))',
#  '  } else if (cmd_line.HasSwitch("unmap"))',
#  '  } else if (cmd_line.HasSwitch("unmap-all"))',
#  '  } else if (cmd_line.HasSwitch("map"))',
#  '  if (cmd_line.HasSwitch("adb"))',
#  '      base::CommandLine::ForCurrentProcess()->HasSwitch("kill-server")',
#  '  return command_line.HasSwitch("h") || command_line.HasSwitch("help")',
#  '  return command_line.HasSwitch(kNoSpawnDaemon)',
#  '  bool fuzzy_diff = parsed_command_line.HasSwitch(kOptionFuzzyDiff)',
#  '  bool histograms = parsed_command_line.HasSwitch(kOptionCompareHistograms)',
#  '  if (parsed_command_line.HasSwitch(kOptionPollStdin))',
#  '  if (parsed_command_line.HasSwitch(kOptionGenerateDiff))',
#  '  if (command_line.HasSwitch("help") || command_line.HasSwitch("h")',
#  '  bool filter_files = !command_line.HasSwitch("no-filtering")',
#  '  bool all_files = command_line.HasSwitch("all-files")',
#  '  bool test_only = command_line.HasSwitch("test-only")',
#  '  bool no_missing_error = command_line.HasSwitch("no-missing-error")',
#  '  if (command_line.HasSwitch("limit"))',
#  '  bool error_resilient = command_line.HasSwitch("error-resilient")',
#  '  if (command_line->HasSwitch(kChromeSwitch))',
#  '  } else if (command_line->HasSwitch(kChromiumSwitch))',
#  '  } else if (command_line->HasSwitch(kFirefoxSwitch))',
#  '  } else if (command_line->HasSwitch(kSafariSwitch))',
#  '  if (command_line->HasSwitch(kActiveTabSwitch))',
#  '  if (command_line->HasSwitch(kHelpSwitch))',
#  '  if (command_line->HasSwitch(kHelpSwitch))',
#  '  bool should_recurse = parsed_command_line.HasSwitch("recurse")',
#  '  if (command_line.HasSwitch(kNoSmartSkippingSwitch))',
#  '  if (command_line.HasSwitch(kMoreSlopeChecksSwitch))',
#  '  if (!command_line->HasSwitch(switch_string))',
#  '      command_line->HasSwitch(switches::kCompileShaderAlwaysSucceeds)',
#  '      command_line->HasSwitch(switches::kDisableGLErrorLimit)',
#  '      command_line->HasSwitch(switches::kDisableGLSLTranslator)',
#  '      command_line->HasSwitch(switches::kDisableShaderNameHashing)',
#  '      command_line->HasSwitch(switches::kEnableGPUCommandLogging)',
#  '      command_line->HasSwitch(switches::kEnableGPUDebugging)',
#  '      command_line->HasSwitch(switches::kEnableGPUServiceLoggingGPU)',
#  '      command_line->HasSwitch(switches::kEnableGPUDriverDebugLogging)',
#  '      command_line->HasSwitch(switches::kDisableGpuProgramCache)',
#  '      command_line->HasSwitch(switches::kEnforceGLMinimums)',
#  '      command_line->HasSwitch(switches::kDisableGpuShaderDiskCache)',
#  '      command_line->HasSwitch(switches::kEnableThreadedTextureMailboxes)',
#  '      command_line->HasSwitch(switches::kGLShaderIntermOutput)',
#  '      command_line->HasSwitch(switches::kEmulateShaderPrecision)',
#  '      command_line->HasSwitch(switches::kEnableGPUServiceLogging)',
#  '      command_line->HasSwitch(switches::kEnableGPUServiceTracing)',
#  '      command_line->HasSwitch(switches::kIgnoreGpuBlocklist)',
#  '      command_line->HasSwitch(switches::kEnableUnsafeWebGPU)',
#  '      command_line->HasSwitch(switches::kEnableDawnBackendValidation)',
#  '  if (command_line->HasSwitch(switches::kEnableDawnFeatures))',
#  '  if (command_line->HasSwitch(switches::kDisableDawnFeatures))',
#  '      command_line->HasSwitch(switches::kDisableVulkanSurface)',
#  '      command_line->HasSwitch(switches::kEnableGpuBlockedTime)',
#  '  if (command_line->HasSwitch(switches::kWebViewDrawFunctorUsesVulkan)',
#  '  if (command_line->HasSwitch(switches::kUseVulkan))',
#  '  if (cl->HasSwitch("duration"))',
#  '  if (command_line.HasSwitch(switches::kDisableGpuRasterization))',
#  '  else if (command_line.HasSwitch(switches::kEnableGpuRasterization))',
#  '  if (command_line->HasSwitch(switches::kUseGL))',
#  '      if (command_line->HasSwitch(switches::kUseANGLE))',
#  '      !command_line->HasSwitch(switches::kUseGpuInTests))',
#  '    if (command_line->HasSwitch(switches::kGpuBlocklistTestGroup))',
#  '  if (!command_line->HasSwitch(switches::kDisableGpuDriverBugWorkarounds))',
#  '    if (command_line->HasSwitch(switches::kGpuDriverBugListTestGroup))',
#  '  if (command_line->HasSwitch(switches::kUseGL))',
#  '  if (command_line->HasSwitch(switches::kGpuVendorId))',
#  '  if (command_line->HasSwitch(switches::kGpuDeviceId))',
#  '  if (command_line->HasSwitch(switches::kGpuSubSystemId))',
#  '  if (command_line->HasSwitch(switches::kGpuRevision))',
#  '  if (command_line->HasSwitch(switches::kGpuDriverVersion))',
#  '      command_line->HasSwitch(switches::kOverrideUseSoftwareGLForTests))',
#  '    if (command_line.HasSwitch(kFeatureList[i].name))',
#  '  if (process_command_line.HasSwitch(switch_string))',
#  '                         !command_line->HasSwitch(switches::kHeadless)',
#  '  if (!gl_use_swiftshader_ && command_line->HasSwitch(switches::kUseGL))',
#  '  if (command_line->HasSwitch(switches::kWebViewDrawFunctorUsesVulkan)',
#  '      if (!command_line->HasSwitch(switches::kDisableGpuDriverBugWorkarounds))',
#  '      base::CommandLine::ForCurrentProcess()->HasSwitch("full-key")',
#  '  bool print_csv = base::CommandLine::ForCurrentProcess()->HasSwitch("csv")',
#  '  bool verbose = base::CommandLine::ForCurrentProcess()->HasSwitch("v")',
#  '  bool verbose = base::CommandLine::ForCurrentProcess()->HasSwitch("v")',
#  '  if (command_line.HasSwitch(kDumpContents))',
#  '  if (command_line.HasSwitch(kDumpLists))',
#  '  if (command_line.HasSwitch(kDumpEntry) && command_line.HasSwitch(kDumpAt))',
#  '  if (command_line.HasSwitch(kDumpAllocation)',
#  '      command_line.HasSwitch(kDumpFile))',
#  '  if (command_line.HasSwitch(kDumpHeaders))',
#  '  if (args.size() != 1U || command_line.HasSwitch("help"))',
#  '  bool use_system_roots = !command_line.HasSwitch("no-system-roots")',
#  '  if (command_line.HasSwitch("trust-last-cert"))',
#  '  if (!command_line.HasSwitch(kFileToWrite)',
#  '      !command_line.HasSwitch(kExampleCount))',
#  '    if (!command_line.HasSwitch(name))',
#  '  if (command_line.HasSwitch("h") || command_line.HasSwitch("help"))',
#  '    if (command_line_switch && command_line->HasSwitch(command_line_switch))',
#  '  if (command_line.HasSwitch(kRMQFileName))',
#  '  if (command_line.HasSwitch(kAndroidIdSwitch))',
#  '  if (command_line.HasSwitch(kSecretSwitch))',
#  '  if (command_line.HasSwitch(kServerHostSwitch))',
#  '  if (command_line.HasSwitch(kServerPortSwitch))',
#  '  if (command_line_.HasSwitch(kLogFileSwitch))',
#  '  if (command_line_.HasSwitch(kIgnoreCertSwitch))',
#  '  if (command_line->HasSwitch(switches::kGCMCheckinURL))',
#  '  if (command_line->HasSwitch(switches::kGCMMCSEndpoint))',
#  '  if (command_line->HasSwitch(switches::kGCMMCSEndpoint))',
#  '  if (command_line->HasSwitch(switches::kGCMRegistrationURL))',
#  '  if (!command_line->HasSwitch(switches::kGaiaConfig))',
#  '  if (command_line->HasSwitch(switch_value))',
#  '      command_line->HasSwitch(kForceHeadlessForTestsSwitch)',
#  '  if (command_line->HasSwitch(kDisableVulkanForTestsSwitch))',
#  '  if (base::CommandLine::ForCurrentProcess()->HasSwitch(kFrameHostConfigKey)',
#  '  if (command_line->HasSwitch(switches::kGoogleApiKey))',
#  '  if (!command_line->HasSwitch(features_flag))',
#  '    DCHECK(!command_line->HasSwitch(arg.first))',
#  '  if (launch_command.HasSwitch(switches::kGoogleApiKey))',
#  '  if (command_line->HasSwitch(switches::kEnableWidevine))',
#  '  if (command_line->HasSwitch(switches::kCdmDataQuotaBytes))',
#  '  return base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kHeadless)',
#  '  if (command_line.HasSwitch(switches::kRemoteDebuggingPort))',
#  '  if (command_line.HasSwitch(switches::kRemoteDebuggerHandles))',
#  '  if (command_line->HasSwitch(switches::kDataQuotaBytes))',
#  '  if (command_line->HasSwitch(network::switches::kLogNetLog))',
#  '      base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kIncognito))',
#  '  if (command_line.HasSwitch(kLogFile))',
#  '      HasSwitch(chromeos::switches::kSystemInDevMode)',
#  '      command_line.HasSwitch(kSwitchErrorOnUnknownField)',
#  '      command_line.HasSwitch(kSwitchErrorOnWrongRecommended)',
#  '      command_line.HasSwitch(kSwitchErrorOnMissingField)',
#  '      command_line.HasSwitch(kSwitchManagedOnc))',
#  '  if (command_line.HasSwitch(kSwitchUserPolicy))',
#  '  else if (command_line.HasSwitch(kSwitchDevicePolicy))',
#  '  else if (command_line.HasSwitch(kSwitchUserImport))',
#  '  if (!command_line->HasSwitch(switches::kHermesFake))',
#  '  if (!command_line->HasSwitch(switches::kShillStub))',
#  '  if (command_line->HasSwitch(chromeos::switches::kCrosRegionsMode))',
#  '    if (command_line->HasSwitch(switches::kAppOemManifestFile))',
#  '  if (command_line->HasSwitch(chromeos::switches::kCrosRegion))',
#  '      command_line->HasSwitch(chromeos::switches::kTelemetryExtensionDirectory)',
#  '  if (!command_line->HasSwitch(switches::kCrosStartupDataFD))',
#  '  return command_line->HasSwitch(kOndeviceHandwritingSwitch)',
#  '  GURL google_apis_url = command_line->HasSwitch(switches::kCryptAuthHTTPHost)',
#  '      command_line->HasSwitch(switches::kCryptAuthV2EnrollmentHTTPHost)',
#  '      command_line->HasSwitch(switches::kCryptAuthV2DeviceSyncHTTPHost)',
#  '  if (command_line.HasSwitch("nologfile"))',
#  '  bool cmd_sup = command_line.HasSwitch("supported")',
#  '  bool cmd_dis = command_line.HasSwitch("dis")',
#  '  bool cmd_asm = command_line.HasSwitch("asm")',
#  '  bool cmd_disadj = command_line.HasSwitch("disadj")',
#  '  bool cmd_make_patch = command_line.HasSwitch("gen")',
#  '  bool cmd_apply_patch = command_line.HasSwitch("apply")',
#  '  bool cmd_make_bsdiff_patch = command_line.HasSwitch("genbsdiff")',
#  '  bool cmd_apply_bsdiff_patch = command_line.HasSwitch("applybsdiff")',
#  '  bool cmd_spread_1_adjusted = command_line.HasSwitch("gen1a")',
#  '  bool cmd_spread_1_unadjusted = command_line.HasSwitch("gen1u")',
#  'void SetV8FlagIfHasSwitch(const char* switch_name, const char* v8_flag)',
#  '  if (base::CommandLine::ForCurrentProcess()->HasSwitch(switch_name))',
#  '  SetV8FlagIfHasSwitch(switches::kJavaScriptHarmony, "--harmony")',
#  '    if (!command_line->HasSwitch(switches::kDisableInProcessStackTraces))',
#  '    } else if (!command_line->HasSwitch(switches::kEnableCrashReporter)',
#  '  if (command_line.HasSwitch(switches::kNoV8UntrustedCodeMitigations))',
#  '  if (command_line.HasSwitch(switches::kJavaScriptFlags))',
#  '  if (command_line.HasSwitch(switches::kIpcDumpDirectory))',
#  '      !command_line.HasSwitch(cc::switches::kDisableThreadedAnimation)',
#  '  if (command_line.HasSwitch(switches::kDisableLCDText))',
#  '  } else if (command_line.HasSwitch(switches::kEnableLCDText))',
#  '  if (command_line.HasSwitch(switches::kDisableGpuCompositing))',
#  '  if (!command_line.HasSwitch(switches::kDisableAcceleratedVideoDecode)',
#  '  if (command_line.HasSwitch(switches::kEnableVtune))',
#  '  if (!command_line.HasSwitch(switches::kDisableThreadedCompositing))',
#  '  if (command_line.HasSwitch(network::switches::kExplicitlyAllowedPorts))',
#  '      !cmd_line->HasSwitch(switches::kDisableAcceleratedVideoDecode)',
#  '      !cmd_line->HasSwitch(switches::kDisableGpuMemoryBufferVideoFrames)',
#  '      cmd_line->HasSwitch(switches::kEnableGpuMemoryBufferVideoFrames)',
#  '      (cmd_line->HasSwitch(switches::kEnableGpuMemoryBufferVideoFrames)',
#  '  if (command_line.HasSwitch(switches::kWaitForDebugger))',
#  '  if (command_line.HasSwitch(switches::kRendererStartupDialog))',
#  '  if (command_line.HasSwitch(switches::kLang))',
#  '  if (command_line.HasSwitch(switches::kInitialVirtualTime))',
#  '        !command_line.HasSwitch(sandbox::policy::switches::kNoSandbox)',
#  '    if (command_line->HasSwitch(switches::kWebglMSAASampleCount))',
#  '    if (command_line->HasSwitch(switches::kWebglAntialiasingMode))',
#  '    if (command_line->HasSwitch(switches::kMaxActiveWebGLContexts))',
#  '      command_line.HasSwitch(sandbox::policy::switches::kNoSandbox)',
#  '  if (command_line.HasSwitch(switches::kDomAutomationController))',
#  '  if (command_line.HasSwitch(switches::kStatsCollectionController))',
#  '  if (command_line.HasSwitch(cc::switches::kEnableGpuBenchmarking))',
#  '  if (command_line.HasSwitch(switches::kEnableSkiaBenchmarking))',
#  '  if (!cmd_line->HasSwitch(switches::kWebRtcStunProbeTrialParameter))',
#  '  if (command_line->HasSwitch(::switches::kDisableAXMenuList))',
#  '  if (command_line.HasSwitch(switches::kGpuPreferences))',
#  '  if (command_line.HasSwitch(switches::kHeadless))',
#  '      (command_line.HasSwitch(switches::kUseHighGPUThreadPriorityForPerfTests)',
#  '  if (parsed_command_line.HasSwitch(switches::kNoZygote))',
#  '    if (!parsed_command_line.HasSwitch(sandbox::policy::switches::kNoSandbox))',
#  '        cmd->HasSwitch(switches::kSingleProcess)',
#  '        (process_type.empty() && cmd->HasSwitch(switches::kInProcessGPU)))',
#  '        cmd->HasSwitch(switches::kSingleProcess))',
#  '        cmd->HasSwitch(switches::kSingleProcess))',
#  '  if (command_line.HasSwitch(switches::kDeviceScaleFactor))',
#  '      !command_line.HasSwitch(switches::kDisableInProcessStackTraces))',
#  '  const bool is_browser = !command_line.HasSwitch(switches::kProcessType)',
#  '  if (cmd.HasSwitch(switches::kExposeInternalsForTesting))',
#  '  if (command_line.HasSwitch("run-layout-test"))',
#  '    if (command_line.HasSwitch(name))',
#  '        command_line->HasSwitch(switches::kUseMobileUserAgent)',
#  '  if (command_line->HasSwitch(switches::kUseMobileUserAgent))',
#  '      command_line->HasSwitch(switches::kUseFakeDeviceForMediaStream)',
#  '      command_line->HasSwitch(switches::kUseFakeUIForMediaStream))',
#  '  if (command_line->HasSwitch(switches::kForceWebRtcIPHandlingPolicy))',
#  '  if (command_line->HasSwitch(switches::kContentShellHostWindowSize))',
#  '  if (command_line->HasSwitch(switches::kBrowserTest))',
#  '  if (command_line->HasSwitch(switches::kEnableCrashReporter))',
#  '  if (command_line.HasSwitch(switches::kRemoteDebuggingSocketName))',
#  '  if (command_line.HasSwitch(switches::kRemoteDebuggingPort))',
#  '  if (command_line.HasSwitch(switches::kRemoteDebuggingPipe))',
#  '  if (cmd_line->HasSwitch(switches::kIgnoreCertificateErrors))',
#  '  if (cmd_line->HasSwitch(switches::kContentShellDataPath))',
#  '  if (command_line.HasSwitch(switches::kProcessPerSite))',
#  '         !command_line()->HasSwitch(sandbox::policy::switches::kNoSandbox))',
#  '  CHECK(!command_line()->HasSwitch(switches::kSingleProcess))',
#  '  if (command_line->HasSwitch(cc::switches::kEnableGpuBenchmarking))',
#  '  if (command_line.HasSwitch(switch_name))',
#  '      if (command_line->HasSwitch(network::switches::kLogNetLog))',
#  '      if (command_line->HasSwitch(network::switches::kSSLKeyLogFile))',
#  '    if (parameters.command_line.HasSwitch(switches::kWaitForDebugger))',
#  '    if (parameters.command_line.HasSwitch(switches::kBrowserStartupDialog))',
#  '      command_line_->HasSwitch(sandbox::policy::switches::kNoSandbox)',
#  '  if (command_line->HasSwitch(::switches::kForceFieldTrials))',
#  '        browser_command_line.HasSwitch(switches::kUtilityCmdPrefix)',
#  '      base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kNoZygote)',
#  '  if (command_line.HasSwitch(switches::kBrowserTest))',
#  '  if (!parsed_command_line_.HasSwitch(switches::kSingleProcess))',
#  '  if (parsed_command_line_.HasSwitch(switches::kRendererProcessLimit))',
#  '  if (!parsed_command_line_.HasSwitch(switches::kSingleProcess))',
#  '  if (parsed_command_line_.HasSwitch(switches::kSingleProcess))',
#  '  if (parsed_command_line_.HasSwitch(switches::kDisableGpu)',
#  '      parsed_command_line_.HasSwitch(switches::kDisableGpuCompositing)',
#  '      parsed_command_line_.HasSwitch(switches::kDisableGpuEarlyInit))',
#  '  return parsed_command_line_.HasSwitch(switches::kSingleProcess)',
#  '         parsed_command_line_.HasSwitch(switches::kInProcessGPU)',
#  '      !parsed_command_line_.HasSwitch(switches::kHeadless)',
#  '  if (!parsed_command_line_.HasSwitch(switches::kSingleProcess))',
#  '  if (command_line->HasSwitch(switches::kTraceStartupFile))',
#  '  if (result.empty() && command_line->HasSwitch(switches::kTraceStartup))',
#  '    if (cmd_line_.HasSwitch(switches::kEnableLogging))',
#  '    if (cmd_line_.HasSwitch(sandbox::policy::switches::kDisableGpuSandbox))',
#  '    if (command_line->HasSwitch(switches::kDisableGpu)',
#  '        command_line->HasSwitch(switches::kSingleProcess)',
#  '        command_line->HasSwitch(switches::kInProcessGPU))',
#  '  if (browser_command_line.HasSwitch(switches::kDisableFrameRateLimit))',
#  '     command_line.HasSwitch(switches::kDisableAccelerated2dCanvas)',
#  '     command_line.HasSwitch(switches::kDisableWebGL)',
#  '     command_line.HasSwitch(switches::kDisableAcceleratedVideoDecode)',
#  '     (command_line.HasSwitch(switches::kDisableGpuRasterization))',
#  '     command_line.HasSwitch(switches::kDisableOopRasterization)',
#  '         !command_line.HasSwitch(switches::kUseVulkan)',
#  '     (command_line.HasSwitch(switches::kDisableWebGL)',
#  '      command_line.HasSwitch(switches::kDisableWebGL2))',
#  '        if (command_line.HasSwitch(switches::kEnableGpuRasterization))',
#  '        if (command_line.HasSwitch(switches::kNumRasterThreads))',
#  '  if (command_line.HasSwitch(switches::kNumRasterThreads))',
#  '  return !command_line.HasSwitch(blink::switches::kDisableZeroCopy)',
#  '  return command_line.HasSwitch(blink::switches::kEnableZeroCopy)',
#  '  return !command_line.HasSwitch(blink::switches::kDisablePartialRaster)',
#  '  if (cl->HasSwitch(switches::kDisableTimeoutsForProfiling))',
#  '  if (cl->HasSwitch(switches::kSingleProcess)',
#  '      cl->HasSwitch(switches::kInProcessGPU))',
#  '  if (command_line.HasSwitch(sandbox::policy::switches::kNoSandbox))',
#  '      !cmd_line->HasSwitch(sandbox::policy::switches::kNoZygoteSandbox)',
#  '  if (command_line->HasSwitch(switches::kDisableFrameRateLimit))',
#  '      !command_line.HasSwitch(switches::kDisableWebSecurity)',
#  '      !command_line.HasSwitch(switches::kDisableRemoteFonts)',
#  '      !command_line.HasSwitch(switches::kDisableLocalStorage)',
#  '      !command_line.HasSwitch(switches::kDisableDatabases)',
#  '  prefs.webgl1_enabled = !command_line.HasSwitch(switches::kDisable3DAPIs)',
#  '                         !command_line.HasSwitch(switches::kDisableWebGL)',
#  '  prefs.webgl2_enabled = !command_line.HasSwitch(switches::kDisable3DAPIs)',
#  '                         !command_line.HasSwitch(switches::kDisableWebGL)',
#  '                         !command_line.HasSwitch(switches::kDisableWebGL2)',
#  '  prefs.pepper_3d_enabled = !command_line.HasSwitch(switches::kDisablePepper3d)',
#  '  prefs.flash_3d_enabled = !command_line.HasSwitch(switches::kDisableFlash3d)',
#  '      !command_line.HasSwitch(switches::kDisableFlashStage3d)',
#  '      !command_line.HasSwitch(switches::kDisableFlashStage3d)',
#  '      command_line.HasSwitch(switches::kAllowFileAccessFromFiles)',
#  '      !command_line.HasSwitch(switches::kDisableAccelerated2dCanvas)',
#  '      command_line.HasSwitch(switches::kEnableNewCanvas2DAPI)',
#  '      command_line.HasSwitch(switches::kDisable2dCanvasAntialiasing)',
#  '      !command_line.HasSwitch(switches::kDisable2dCanvasClipAntialiasing)',
#  '      command_line.HasSwitch(switches::kDisableIpcFloodingProtection)',
#  '      command_line.HasSwitch(switches::kDisablePushStateThrottle)',
#  '      !command_line.HasSwitch(switches::kDisableAcceleratedVideoDecode)',
#  '      command_line.HasSwitch(switches::kEnableSmoothScrolling)',
#  '      (!command_line.HasSwitch(switches::kDisableSmoothScrolling)',
#  '  prefs.viewport_enabled = command_line.HasSwitch(switches::kEnableViewport)',
#  '      !command_line.HasSwitch(blink::switches::kDisableThreadedScrolling)',
#  '      command_line.HasSwitch(switches::kMainFrameResizesAreOrientationChanges)',
#  '      command_line.HasSwitch(switches::kEnableSpatialNavigation)',
#  '      command_line.HasSwitch(switches::kDisableReadingFromCanvas)',
#  '      command_line.HasSwitch(switches::kEnableStrictMixedContentChecking)',
#  '        command_line.HasSwitch(switches::kTouchEventFeatureDetection)',
#  '  if (!command_line->HasSwitch(switches::kWebXrForceRuntime))',
#  '  if (!command_line.HasSwitch(switches::kEnableSpeechDispatcher))',
#  '  if (!command_line->HasSwitch(switches::kDisableNewContentRenderingTimeout))',
#  '  if (command_line->HasSwitch(switches::kDisableKillAfterBadIPC))',
#  '      browser_cmd.HasSwitch(switches::kWebRtcStunProbeTrialParameter))',
#  '      !browser_cmd.HasSwitch(switches::kDisableDatabases))',
#  '  if (browser_cmd.HasSwitch(switches::kDisableGpuCompositing))',
#  '  if (browser_cmd.HasSwitch(switches::kWaitForDebuggerChildren))',
#  '  if (renderer_cmd->HasSwitch(switches::kRendererStartupDialog)',
#  '      !renderer_cmd->HasSwitch(sandbox::policy::switches::kNoSandbox))',
#  '    if (!command_line->HasSwitch(switches::kLang))',
#  '      command_line->HasSwitch(cc::switches::kEnableGpuBenchmarking))',
#  '      command_line->HasSwitch(cc::switches::kUIShowFPSCounter)',
#  '  if (command_line->HasSwitch(cc::switches::kUIShowCompositedLayerBorders))',
#  '      command_line->HasSwitch(switches::kUseFakeDeviceForMediaStream))',
#  '      command_line->HasSwitch(switches::kUseFakeDeviceForMediaStream))',
#  '        command->HasSwitch(switches::kNoDelayForDX12VulkanInfoCollection)',
#  '  if (command_line->HasSwitch(switches::kEnableAutomation))',
#  '      command_line->HasSwitch(switches::kSingleProcess)',
#  '    if (command_line->HasSwitch(switches::kQuotaChangeEventInterval))',
#  '      command_line->HasSwitch(switches::kDisableAcceleratedVideoDecode))',
#  '  if (!command_line.HasSwitch(switches::kMojoCoreLibraryPath))',
#  '  if (current_command_line->HasSwitch(switches::kWaitForDebuggerChildren))',
#  '  if (!cmd.HasSwitch(switches::kDisableSkiaRuntimeOpts))',
#  '  if (cmd.HasSwitch(switches::kSkiaFontCacheLimitMb))',
#  '  if (cmd.HasSwitch(switches::kSkiaResourceCacheLimitMb))',
#  '        if (command_line->HasSwitch(switches::kGpuPreferences))',
#  '  if (command_line->HasSwitch(sandbox::switches::kSeatbeltClientName))',
#  '  if (browser_command_line.HasSwitch(switches::kZygoteCmdPrefix))',
#  '  if (cmdline->HasSwitch(switches::kPpapiInProcess))',
#  '  if (command_line->HasSwitch(switches::kDisableKillAfterBadIPC))',
#  '      command_line->HasSwitch(switches::kDisableAcceleratedVideoDecode)',
#  '      command_line->HasSwitch(switches::kDisableAcceleratedVideoEncode)',
#  '      !command_line->HasSwitch(switches::kDisableLowLatencyDxva)',
#  '      !command_line->HasSwitch(switches::kDisableZeroCopyDxgiVideo)',
#  '      !command_line->HasSwitch(switches::kDisableNv12DxgiVideo)',
#  '      command_line->HasSwitch(switches::kDisableSoftwareRasterizer)',
#  '      command_line->HasSwitch(switches::kLogGpuControlListDecisions)',
#  '      command_line->HasSwitch(switches::kGpuStartupDialog)',
#  '      command_line->HasSwitch(switches::kDisableGpuWatchdog)',
#  '      command_line->HasSwitch(switches::kSingleProcess)',
#  '      command_line->HasSwitch(switches::kInProcessGPU)',
#  '      command_line->HasSwitch(switches::kGpuSandboxStartEarly)',
#  '      command_line->HasSwitch(switches::kEnableOopRasterization)',
#  '      command_line->HasSwitch(switches::kDisableOopRasterization)',
#  '      command_line->HasSwitch(switches::kEnableVulkanProtectedMemory)',
#  '      command_line->HasSwitch(switches::kEnforceVulkanProtectedMemory)',
#  '      command_line->HasSwitch(switches::kDisableVulkanFallbackToGLForTesting)',
#  '      command_line->HasSwitch(cc::switches::kEnableGpuBenchmarking)',
#  '      command_line->HasSwitch(switches::kEnableNativeGpuMemoryBuffers)',
#  '      command_line->HasSwitch(switches::kDisableOoprDebugCrashDump)',
#  '    if (command_line.HasSwitch(switches::kProfilingFile))',
#  '  if (command_line.HasSwitch(switches::kProfilingAtStart))',
#  '  bool flush = command_line.HasSwitch(switches::kProfilingFlush)',
#  '  bool enabled = (command_line->HasSwitch(switches::kEnableUseZoomForDSF)',
#  '  if (command_line.HasSwitch(switches::kMaxDecodedImageSizeMb))',
#  '  if (base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kProcessType))',
#  '      !command_line.HasSwitch(switches::kProcessType)',
#  '  if (!command_line->HasSwitch(switches::kWebXrForceRuntime))',
#  '  if (!command_line.HasSwitch(switches::kSingleProcess))',
#  '  if (command_line.HasSwitch(switches::kPpapiStartupDialog))',
#  '  if (command_line.HasSwitch(switches::kLang))',
#  '      parameters.command_line.HasSwitch(switches::kMessageLoopTypeUi)',
#  '  if (parameters.command_line.HasSwitch(switches::kUtilityStartupDialog))',
#  '          command_line->HasSwitch(kBlobFileTransportByFileTriggerSwitch)))',
#  '          command_line->HasSwitch(kBlobSharedMemoryTransportMaxSizeSwitch)))',
#  '  if (UNLIKELY(command_line->HasSwitch(kBlobFileTransportMinFileSizeSwitch)))',
#  '  if (UNLIKELY(command_line->HasSwitch(kBlobFileTransportMaxFileSizeSwitch)))',
#  '            !command_line->HasSwitch(kBlobFileTransportByFileTriggerSwitch)))',
#  '                       HasSwitch(::switches::kTestType)',
#  '  if (cmd_line->HasSwitch(switches::kContentShellDataPath))',
#  '  if (base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kLogFile))',
#  '  if (command_line->HasSwitch(switches::kAppShellHostWindowSize))',
#  '  if (!command_line->HasSwitch(switches::kLoadExtension))',
#  '  if (!command_line->HasSwitch(switches::kLoadApps))',
#  '  if (!command_line.HasSwitch(kSwitchInputFilterlistFiles)',
#  '      !command_line.HasSwitch(kSwitchOutputPath))',
#  '  if (command_line.HasSwitch(kSwitchOutputType))',
#  '  if (command_line->HasSwitch(switches::kOverrideMetricsUploadUrl))',
#  '    if (browser_command_line->HasSwitch(switches::kAudioOutputChannels))',
#  '    if (!command_line->HasSwitch(switches::kCastInitialScreenWidth))',
#  '    if (!command_line->HasSwitch(switches::kCastInitialScreenHeight))',
#  '        !command_line->HasSwitch(default_command_line_flag_content[0]))',
#  '    if (!command_line->HasSwitch(name))',
#  '  if (!command_line->HasSwitch(switches::kDisableGpu))',
#  '  if (command_line->HasSwitch(switches::kRemoteDebuggingSocketName))',
#  '  if (base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kTestType))',
#  '  if (command_line->HasSwitch(kCastMojoBrokerPathSwitch))',
#  '  if (cmd_line->HasSwitch(switches::kSysInfoFilePath))',
#  '  if (cmd_line->HasSwitch(kHeightSwitch)',
#  '  if (cmd_line->HasSwitch(kWidthSwitch)',
#  '    if (command_line_->HasSwitch(string_switch[i].switch_name))',
#  '    if (command_line_->HasSwitch(path_switch[i].switch_name))',
#  '    if (command_line_->HasSwitch(integer_switch[i].switch_name))',
#  '    if (command_line_->HasSwitch(boolean_switch_map[i].switch_name))',
#  '  if (cmdline->HasSwitch(metrics::switches::kMetricsRecordingOnly))',
#  '  if (!command_line->HasSwitch(switches::kResetVariationState))',
#  '  if (command_line->HasSwitch(metrics::switches::kMetricsUploadIntervalSec))',
#  '  if (command_line->HasSwitch(switches::kAutofillAssistantServerKey))',
#  '  DCHECK(command_line.HasSwitch(switches::kTraceToConsole))',
#  '  if (command_line->HasSwitch(switches::kTraceStartupDuration))',
#  '  } else if (command_line->HasSwitch(switches::kEnableTracing))',
#  '  if (command_line->HasSwitch(switches::kTraceStartupFormat))',
#  '  if (!command_line->HasSwitch(switches::kTraceStartup)',
#  '      !command_line->HasSwitch(switches::kEnableTracing))',
#  '  if (command_line->HasSwitch(switches::kTraceStartup))',
#  '  if (!command_line->HasSwitch(switches::kTraceConfigFile))',
#  '  if (command_line.HasSwitch(switches::kEnableWebsocketOverHttp2))',
#  '  if (command_line.HasSwitch(switches::kHttp2GreaseSettings)',
#  '  if (command_line.HasSwitch(switches::kHttp2GreaseFrameType)',
#  '  if (command_line.HasSwitch(switches::kHttp2EndStreamWithDataFrame)',
#  '  if (command_line.HasSwitch(variations::switches::kForceFieldTrialParams))',
#  '  is_quic_force_disabled |= command_line.HasSwitch(switches::kDisableQuic)',
#  '  if (command_line.HasSwitch(switches::kDisableHttp2))',
#  '    if (command_line.HasSwitch(switches::kQuicConnectionOptions))',
#  '    if (command_line.HasSwitch(switches::kQuicClientConnectionOptions))',
#  '    if (command_line.HasSwitch(switches::kQuicMaxPacketLength))',
#  '    if (command_line.HasSwitch(switches::kQuicVersion))',
#  '    if (command_line.HasSwitch(switches::kOriginToForceQuicOn))',
#  '  if (command_line.HasSwitch(switches::kEnableUserAlternateProtocolPorts))',
#  '  if (command_line.HasSwitch(switches::kIgnoreCertificateErrors))',
#  '      command_line.HasSwitch(switches::kIgnoreCertificateErrors))',
#  '  if (command_line.HasSwitch(switches::kTestingFixedHttpPort))',
#  '  if (command_line.HasSwitch(switches::kTestingFixedHttpsPort))',
#  '  if (command_line.HasSwitch(switches::kHostRules))',
#  '    if (command_line->HasSwitch(kOriginTrialPublicKey))',
#  '    if (command_line->HasSwitch(kOriginTrialDisabledFeatures))',
#  '    if (command_line->HasSwitch(kOriginTrialDisabledTokens))',
#  '    if (command_line->HasSwitch(kTrustedCDNBaseURLForTests))',
#  '  if (command_line->HasSwitch(switches::kGoogleDoodleUrl))',
#  '  if (command_line->HasSwitch(switches::kSearchProviderLogoURL))',
#  '    if (command_line->HasSwitch(switches::kThirdPartyDoodleURL))',
#  '  if (command_line->HasSwitch(switches::kTranslateRankerModelURL))',
#  '  if (command_line.HasSwitch(translate::switches::kTranslateScriptURL))',
#  '  if (command_line->HasSwitch(switches::kTranslateSecurityOrigin))',
#  '    return command_line.HasSwitch(experiment.forcing_flag())',
#  '          command_line.HasSwitch(experiment->forcing_flag))',
#  '  if (command_line->HasSwitch(switches::kEnableBenchmarking)',
#  '      command_line->HasSwitch(kEnableGpuBenchmarking))',
#  '  if (command_line->HasSwitch(switches::kForceFieldTrialParams))',
#  '  if (command_line->HasSwitch(::switches::kForceFieldTrials))',
#  '  if (!command_line->HasSwitch(switches::kDisableFieldTrialTestingConfig)',
#  '      !command_line->HasSwitch(::switches::kForceFieldTrials)',
#  '      !command_line->HasSwitch(switches::kVariationsServerURL))',
#  '  if (command_line->HasSwitch(switches::kForceRemoteShellScale))',
#  '  if (command_line->HasSwitch(switches::kWaylandServerSocket))',
#  '  if (command_line->HasSwitch("cs1"))',
#  '  if (command_line->HasSwitch("cs2"))',
#  '  if (command_line->HasSwitch(switches::kSigmaX)',
#  '  if (command_line->HasSwitch(switches::kSigmaY)',
#  '  if (command_line->HasSwitch(switches::kMaxSigma)',
#  '  if (command_line.HasSwitch(switches::kSize))',
#  '  if (command_line.HasSwitch(switches::kScale)',
#  '  if (command_line.HasSwitch(switches::kTransform))',
#  '  use_drm = command_line.HasSwitch(switches::kUseDrm)',
#  '  use_memfd = command_line.HasSwitch(switches::kUseMemfd)',
#  '  fullscreen = command_line.HasSwitch(switches::kFullscreen)',
#  '      command_line.HasSwitch(switches::kTransparentBackground)',
#  '  y_invert = command_line.HasSwitch(switches::kYInvert)',
#  '      command_line->HasSwitch(switches::kLogVSyncTimingUpdates)',
#  '  if (command_line->HasSwitch(switches::kMaxFramesPending)',
#  '  if (command_line->HasSwitch(switches::kNumRects)',
#  '  if (command_line->HasSwitch(switches::kBenchmark)',
#  '  if (command_line->HasSwitch(switches::kBenchmarkInterval)',
#  '                    command_line->HasSwitch(switches::kShowFpsCounter))',
#  '  if (cmd->HasSwitch("help"))',
#  '  if (command_line.HasSwitch(switches::kAutofillServerURL))',
#  '  if (command_line.HasSwitch(switches::kAutofillAPIKey))',
#  '  if (base::CommandLine::ForCurrentProcess()->HasSwitch("sync-url"))',
#  '  return base::CommandLine::ForCurrentProcess()->HasSwitch(kEnableCrashpad)',
#  '  if (parsed_command_line.HasSwitch(switches::kDisableBreakpad))',
#  '        !parsed_command_line.HasSwitch(switches::kDisableBreakpad)',
#  '    if (!parsed_command_line.HasSwitch(switches::kEnableCrashReporter))',
#  '  if (command_line->HasSwitch(switches::kEnableCrashReporter))',
#  '  if (command_line.HasSwitch(::switches::kTestChildProcess))',
#  '                           (cmd_line->HasSwitch(switches::kNoErrorDialogs)',
#  '                           (command.HasSwitch(switches::kNoErrorDialogs)',
#  '  if (command.HasSwitch(switches::kDisableBreakpad))',
#  '  if (command.HasSwitch(switches::kFullMemoryCrashReport))',
#  '  return GURL(command_line.HasSwitch(switches::kFeedbackServer)',
#  '  if (cmd->HasSwitch(switches::kEnableExperimentalWebPlatformFeatures))',
#  '  if (!cmd_line->HasSwitch(switches::kEnableNTPSearchEngineCountryDetection))',
#  '      !command_line->HasSwitch(switches::kUIDisablePartialSwap)',
#  '      !command_line->HasSwitch(switches::kDisableCompositedAntialiasing)',
#  '  if (command_line->HasSwitch(switches::kSlowDownCompositingScaleFactor))',
#  '    if (command_line->HasSwitch(switches::kEnableHardwareOverlays))',
#  '      command_line->HasSwitch(switches::kTintCompositedContent)',
#  '      command_line->HasSwitch(switches::kShowOverdrawFeedback)',
#  '      command_line->HasSwitch(switches::kShowDCLayerDebugBorders)',
#  '      command_line->HasSwitch(switches::kShowAggregatedDamage)',
#  '        command_line->HasSwitch("dump-to-png")',
#  '  if (command_line->HasSwitch(switches::kDoubleBufferCompositing))',
#  '  if (command_line->HasSwitch(switches::kDoubleBufferCompositing))',
#  '  const bool headless = command_line->HasSwitch(switches::kHeadless)',
#  '      command_line->HasSwitch(switches::kRunAllCompositorStagesBeforeDraw)',
#  '  if (cmd_line->HasSwitch(switches::kClearTokenService))',
#  '  if (cmd->HasSwitch(switches::kEnableNaClDebug)',
#  '      !cmd->HasSwitch(sandbox::policy::switches::kNoSandbox))',
#  '  if (cmd->HasSwitch(switches::kNaClGdb)',
#  '      !cmd->HasSwitch(switches::kEnableNaClDebug))',
#  '        cmd->HasSwitch(switches::kEnableNaClNonSfiMode)',
#  '      parsed_command_line.HasSwitch(sandbox::policy::switches::kNoSandbox)',
#  '  if (command_line.HasSwitch(switches::kEnableLogging))',
#  '    enable_nacl_debug_ = command_line->HasSwitch(switches::kEnableNaClDebug)',
#  '  if (cl->HasSwitch(switches::kSyncShortInitialRetryOverride))',
#  '  if (cl->HasSwitch(switches::kSyncShortNudgeDelayForTest))',
#  '  if (cmdline->HasSwitch(switches::kSyncDeferredStartupTimeoutSeconds))',
#  '  if (command_line.HasSwitch(switches::kSyncServiceURL))',
#  '  if (!command_line.HasSwitch(kSwitchRuleset))',
#  '    if (!command_line.HasSwitch(kSwitchOrigin)',
#  '        !command_line.HasSwitch(kSwitchUrl)',
#  '        !command_line.HasSwitch(kSwitchType))',
#  '        if (!command_line.HasSwitch(arg))',
#  '  if (command_line.HasSwitch(kSwitchMinMatches)',
#  '  if (command_line.HasSwitch(kSwitchInputFile))',
#  '  if (!command_line.HasSwitch(kSwitchVersionOutput))',
#  '  LOG_IF(FATAL, !command_line.HasSwitch(kSwitchContentVersion))',
#  '  if (command_line.HasSwitch(kSwitchOutputFile)',
#  '  if (command_line.HasSwitch(kSwitchOutputFileUrl)',
#  '  if (command_line.HasSwitch(kSwitchOutputFileCss)',
#  '  if (command_line.HasSwitch(kSwitchChromeVersion)',
#  '  if (command_line.HasSwitch(kSwitchInputFormat)',
#  '  if (command_line.HasSwitch(kSwitchOutputFormat)',
#  '      params.command_line.HasSwitch(kSwitchKeep)',
#  '      params.command_line.HasSwitch(kSwitchRaw)',
#  '                         params.command_line.HasSwitch(kSwitchKeep))',
#  '  bool do_dump = params.command_line.HasSwitch(kSwitchDump)',
#  '    if (command_line.HasSwitch(command.name))',
#  '  if (command_line->HasSwitch(chromeos::switches::kArcAvailability))',
#  '  return command_line->HasSwitch(chromeos::switches::kEnableArc)',
#  '         (command_line->HasSwitch(chromeos::switches::kArcAvailable)',
#  '  if (!command_line->HasSwitch(chromeos::switches::kArcStartMode))',
#  '  if (command_line->HasSwitch(chromeos::switches::kArcAvailability))',
#  '  if (command_line->HasSwitch(chromeos::switches::kArcAvailable))',
#  '  if (command_line->HasSwitch(chromeos::switches::kArcScale))',
#  '  if (!cl->HasSwitch(chromeos::switches::kArcBuildProperties))',
#  '      command_line->HasSwitch(chromeos::switches::kEnableHoudini)',
#  '      command_line->HasSwitch(chromeos::switches::kEnableHoudini64)',
#  '      command_line->HasSwitch(chromeos::switches::kEnableNdkTranslation)',
#  '      command_line->HasSwitch(chromeos::switches::kEnableNdkTranslation64)',
#  '         command_line->HasSwitch(chromeos::switches::kLoginUser)',
#  '  if (cmdline->HasSwitch("enable-heap-profiling"))',
#  '  if (cmdline->HasSwitch(kMemlogMode)',
#  '    if (cmdline->HasSwitch(kMemlogMode))',
#  '  LOG_IF(ERROR, cmdline->HasSwitch(kMemlogMode))',
#  '  if (cmdline->HasSwitch(kMemlogStackMode))',
#  '  if (cmdline->HasSwitch(kMemlogSamplingRate))',
#  '  if (command_line && command_line->HasSwitch(switches::kSingleProcess))',
#  '  if (command_line->HasSwitch(switches::kDeviceManagementUrl)',
#  '  if (command_line->HasSwitch(switches::kRealtimeReportingUrl)',
#  '  if (command_line->HasSwitch(switches::kEncryptedReportingUrl)',
#  '  if (!command_line_.HasSwitch(switches::kChromePolicy))',
#  '  bool is_browser = !command_line->HasSwitch(switches::kProcessType)',
#  '      base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kNoSandbox))',
#  '        DCHECK(!command_line->HasSwitch(switches::kServiceSandboxType))',
#  '      DCHECK(!command_line->HasSwitch(switches::kServiceSandboxType))',
#  '  if (command_line.HasSwitch(switches::kNoSandbox))',
#  '  if (command_line.HasSwitch(switches::kNoSandboxAndElevatedPrivileges))',
#  '    if (command_line.HasSwitch(switches::kDisableGpuSandbox))',
#  '    return !cmd_line.HasSwitch(switches::kAllowNoSandboxJob)',
#  '  if (launcher_process_command_line.HasSwitch(switches::kAllowNoSandboxJob)',
#  '      !cmd_line->HasSwitch(switches::kAllowNoSandboxJob))',
#  '      cmd_line->HasSwitch(switches::kNoSandbox)',
#  '      launcher_process_command_line.HasSwitch(switches::kNoSandbox))',
#  '  if (!cmd_line->HasSwitch(switches::kAllowThirdPartyModules)',
#  '  if (base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kNoSandbox))',
#  '  return !command_line.HasSwitch(switches::kNoSandbox)',
#  '         !command_line.HasSwitch(switches::kDisableSeccompFilterSandbox)',
#  '        command_line->HasSwitch(switches::kGpuSandboxFailuresFatal))',
#  '  if (!command_line->HasSwitch(switches::kSingleProcess))',
#  '  if (command_line.HasSwitch(switches::kRemoteDebuggingPort))',
#  '  if (command_line.HasSwitch(kProxyServerSwitch))',
#  '    if (command_line.HasSwitch(kProxyBypassListSwitch))',
#  '      cl->HasSwitch(switches::kForceGpuMemAvailableMb)',
#  '      command_line->HasSwitch(switches::kTintCompositedContent)',
#  '  if (cl->HasSwitch(switches::kWebViewSandboxedRenderer))',
#  '    if (cl->HasSwitch(switches::kWebViewLogJsConsoleMessages))',
#  '    if (cl->HasSwitch(switches::kWebViewDrawFunctorUsesVulkan))',
#  '  if (command_line->HasSwitch(variations::switches::kEnableBenchmarking))',
#  '  if (command_line->HasSwitch(switches::kEnableNetBenchmarking))',
#  '  if (!command_line->HasSwitch(switches::kInstantProcess))',
#  '  if (command_line->HasSwitch(switches::kInstantProcess)',
#  '  if (cmdline->HasSwitch(switches::kPpapiInProcess))',
#  '  if (!command_line.HasSwitch(switches::kDisableClientSidePhishingDetection))',
#  '  if (command_line.HasSwitch(switches::kInstantProcess))',
#  '  return !command_line->HasSwitch(switches::kDisablePrintPreview)',
#  '  if (cmdline.HasSwitch(switches::kStandaloneInstall))',
#  '    if (cmdline.HasSwitch(switches::kInstallerData))',
#  '  if (cmdline->HasSwitch(switches::kLoggingLevel))',
#  '  if (cmdline->HasSwitch(credential_provider::switches::kEnableStats)',
#  '      cmdline->HasSwitch(credential_provider::switches::kDisableStats))',
#  '      cmdline->HasSwitch(credential_provider::switches::kUninstall)',
#  '  DCHECK(cmdline.HasSwitch(switches::kEnableStats)',
#  '         cmdline.HasSwitch(switches::kDisableStats))',
#  '  bool enable = !cmdline.HasSwitch(switches::kDisableStats)',
#  '      command_line.HasSwitch(credential_provider::switches::kUninstall)',
#  '  if (!cmd_line->HasSwitch(kExecutable))',
#  '  if (!cmd_line->HasSwitch(kOutputFile))',
#  '  if (command_line->HasSwitch(switches::kHeadless))',
#  '  if (command_line.HasSwitch(switches::kProductVersion))',
#  '  if (command_line.HasSwitch(switches::kVersion))',
#  '  if (command_line.HasSwitch(switches::kHelp)',
#  '      command_line.HasSwitch(switches::kHelpShort))',
#  '  if (command_line.HasSwitch(switches::kDisableWebSecurity))',
#  '  const bool is_browser = !command_line.HasSwitch(switches::kProcessType)',
#  '  const bool is_browser = !command_line.HasSwitch(switches::kProcessType)',
#  '  if (command_line.HasSwitch(switches::kDiagnostics))',
#  '    if (command_line.HasSwitch(switches::kDiagnosticsFormat))',
#  '  if (command_line.HasSwitch(chromeos::switches::kHomedir))',
#  '       command_line.HasSwitch(chromeos::switches::kLoginUser))',
#  '      command_line.HasSwitch(switches::kDiagnosticsRecovery))',
#  '    if (command_line.HasSwitch(switches::kDiagnosticsFormat))',
#  '      command_line.HasSwitch(switches::kRelauncherProcessDMGDevice)',
#  '    CHECK(command_line.HasSwitch(switches::kProcessType)',
#  '    CHECK(!command_line.HasSwitch(switches::kProcessType)',
# ...
#  '  if (browser_command_line.HasSwitch(blink::switches::kBlinkSettings)',
#  '      command_line->HasSwitch(blink::switches::kBlinkSettings))',
#  '    if (browser_command_line.HasSwitch(switches::kIgnoreGpuBlocklist)',
#  '        !command_line->HasSwitch(switches::kDisableBreakpad))',
#  '  if (browser_command_line.HasSwitch(switches::kEnableThreadInstructionCount)',
#  '      command_line->HasSwitch(sandbox::policy::switches::kNoSandbox))',
#  '  // HasSwitch(switches::kEnableWebBluetooth)',
#  '  return command_line.HasSwitch(switches::kEnableNetBenchmarking)',
#  '  if (command_line.HasSwitch(switches::kBrowserCrashTest))',
#  '      parsed_command_line.HasSwitch(switches::kProfileDirectory)',
#  '      !parsed_command_line.HasSwitch(switches::kAppId))',
#  '  if (!command_line->HasSwitch(embedder_support::kOriginTrialPublicKey))',
#  '  if (!command_line->HasSwitch(embedder_support::kOriginTrialDisabledTokens))',
#  '    if (!parsed_command_line().HasSwitch(switches::kApp)',
#  '        !parsed_command_line().HasSwitch(switches::kAppId))',
#  '      !command_line->HasSwitch(switches::kSitePerProcess))',
#  '  if (parsed_command_line().HasSwitch(::switches::kAutoOpenDevToolsForTabs))',
#  '  if (parsed_command_line().HasSwitch(switches::kUninstall))',
#  '  if (parsed_command_line().HasSwitch(switches::kHideIcons)',
#  '      parsed_command_line().HasSwitch(switches::kShowIcons))',
#  '  if (parsed_command_line().HasSwitch(switches::kMakeDefaultBrowser))',
#  '  if (parsed_command_line().HasSwitch(switches::kPackExtension))',
#  '      if (parsed_command_line().HasSwitch(switches::kTestType))',
#  '  if (!parsed_command_line().HasSwitch(switches::kBrowserTest))',
#  '  if (parsed_command_line().HasSwitch(switches::kDebugPrint))',
#  '  if (!parsed_command_line().HasSwitch(switches::kDisableComponentUpdate))',
#  '  if (!parsed_command_line().HasSwitch(switches::kAppId))',
#  '  if (command_line->HasSwitch(switches::kNoExperiments))',
#  '  if (command_line.HasSwitch(switches::kWmClass))',
#  '      !parsed_command_line().HasSwitch(switches::kAppId))',
#  '  if (parsed_command_line().HasSwitch(switches::kAppId)',
#  '  if (parsed_command_line().HasSwitch(switches::kFromInstaller))',
#  '  if (parsed_command_line.HasSwitch(switches::kBrowserCrashTest)',
#  '      parsed_command_line.HasSwitch(switches::kNoErrorDialogs))',
#  '  if (parsed_command_line.HasSwitch(switches::kHideIcons))',
#  '  if (!command_line.HasSwitch(switches::kRestoreLastSession))',
#  '    if (!new_cl->HasSwitch(switch_to_add))',
#  '  if (base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kUserDataDir))',
#  '                        command_line.HasSwitch(switches::kNoStartupWindow))',
#  '  if (command_line.HasSwitch(switches::kNoStartupWindow))',
#  '  if (command_line.HasSwitch(switches::kKeepAliveForTest))',
#  '  if (command_line()->HasSwitch(switches::kNoProxyServer)',
#  '      (command_line()->HasSwitch(switches::kProxyAutoDetect)',
#  '       command_line()->HasSwitch(switches::kProxyServer)',
#  '       command_line()->HasSwitch(switches::kProxyPacUrl)',
#  '       command_line()->HasSwitch(switches::kProxyBypassList)))',
#  '  if (command_line()->HasSwitch(switches::kNoProxyServer))',
#  '  } else if (command_line()->HasSwitch(switches::kProxyPacUrl))',
#  '  } else if (command_line()->HasSwitch(switches::kProxyAutoDetect))',
#  '  } else if (command_line()->HasSwitch(switches::kProxyServer))',
#  '  if (command_line()->HasSwitch(switches::kCipherSuiteBlacklist))',
#  '  if (command_line()->HasSwitch(switches::kDisableExtensions))',
#  '      command_line.HasSwitch(switches::kIncognito)',
#  '  if (command_line->HasSwitch(switches::kUserDataDir))',
#  '  if (command_line->HasSwitch(switches::kApp))',
#  '  if (command_line.HasSwitch(switches::kCrashOnHangThreads))',
#  '      command_line.HasSwitch(switches::kTouchEventFeatureDetection)',
#  '  if (command_line.HasSwitch(switches::kWindowSize))',
#  '  if (command_line.HasSwitch(switches::kWindowPosition))',
#  '  return base::CommandLine::ForCurrentProcess()->HasSwitch(kEnableCommander)',
#  '  if (command_line->HasSwitch(ash::switches::kEnableCrOSActionRecorder))',
#  '  if (command_line->HasSwitch(switches::kEnableAutomation))',
#  '  if (base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kTestType)',
#  '      !command_line->HasSwitch(switches::kBrowserTest))',
#  '  if (cmd_line->HasSwitch(switches::kCustomDevtoolsFrontend))',
#  '      cmd.HasSwitch(::switches::kEnableExperimentalWebPlatformFeatures))',
#  '                              cmdline->HasSwitch(switches::kKioskModePrinting))',
#  '  bool prompt_user = !cmdline->HasSwitch(switches::kKioskModePrinting)',
#  '  if (command_line->HasSwitch(kEduCoexistenceLoginURLSwitch))',
#  '  if (command_line->HasSwitch(kAddSupervisionSwitch))',
#  '      command_line->HasSwitch(::chromeos::switches::kShowOobeDevOverlay)',
#  '      command_line->HasSwitch(::chromeos::switches::kEnableOobeTestAPI)',
#  '  const bool is_running_test = command_line->HasSwitch(::switches::kTestName)',
#  '                               command_line->HasSwitch(::switches::kTestType)',
#  '      command_line->HasSwitch(::chromeos::switches::kShowOobeDevOverlay)',
#  '      command_line->HasSwitch(::chromeos::switches::kEnableOobeTestAPI)',
#  '  if (command_line->HasSwitch(switches::kOobeScreenshotDirectory))',
#  '      base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kKioskMode))',
#  '      base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kKioskMode))',
#  '  const bool is_running_test = command_line->HasSwitch(::switches::kTestName)',
#  '                               command_line->HasSwitch(::switches::kTestType)',
#  '    if (base::CommandLine::ForCurrentProcess()->HasSwitch(flag))',
#  '  if (base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kKioskMode)',
#  '  if (command_line_.HasSwitch(switches::kInstallChromeApp))',
#  '  if (command_line_.HasSwitch(switches::kNoStartupWindow))',
#  '  if (command_line_.HasSwitch(switches::kOpenInNewWindow))',
#  '  if (command_line_.HasSwitch(switches::kEnableAutomation)',
#  '  if (command_line_.HasSwitch(switches::kKioskMode))',
#  '      !command_line_.HasSwitch(switches::kTestType)',
#  '      !command_line_.HasSwitch(switches::kEnableAutomation))',
#  '    if (!command_line_.HasSwitch(switches::kNoDefaultBrowserCheck))',
#  '      command_line.HasSwitch(switches::kIncognito)',
#  '      command_line.HasSwitch(switches::kProfileDirectory))',
#  '  if (command_line.HasSwitch(switches::kApp)',
#  '      command_line.HasSwitch(switches::kAppId))',
#  '  if (command_line.HasSwitch(switches::kSilentLaunch))',
#  '  if (command_line.HasSwitch(switches::kApp))',
#  '  if (command_line.HasSwitch(switches::kAppId))',
#  '  DCHECK(!command_line.HasSwitch(credential_provider::kGcpwSigninSwitch))',
#  '  DCHECK(!command_line.HasSwitch(switches::kNotificationLaunchId))',
#  '  } else if (command_line.HasSwitch(switches::kIncognito))',
#  '  if ((command_line.HasSwitch(switches::kRestoreLastSession) || did_restart)',
#  '      command_line.HasSwitch(switches::kDisablePromptOnRepost))',
#  '  if (command_line.HasSwitch(switches::kCloudPrintFile)',
#  '  if (command_line.HasSwitch(switches::kValidateCrx))',
#  '  if (command_line.HasSwitch(chromeos::switches::kLoginManager))',
#  '      command_line.HasSwitch(switches::kDumpBrowserHistograms))',
#  '      command_line.HasSwitch(switches::kNativeMessagingConnectHost)',
#  '      command_line.HasSwitch(switches::kNativeMessagingConnectExtension))',
#  '  if (!process_startup && command_line.HasSwitch(switches::kNoStartupWindow))',
#  '  if (command_line.HasSwitch(switches::kUninstallAppId))',
#  '  if (command_line.HasSwitch(extensions::switches::kLoadApps)',
#  '  if (command_line.HasSwitch(apps::kLoadAndLaunchApp) && can_use_last_profile)',
#  '  if (command_line.HasSwitch(switches::kWinJumplistAction))',
#  '  if (command_line.HasSwitch(switches::kNotificationLaunchId))',
#  '  if (command_line.HasSwitch(credential_provider::kGcpwSigninSwitch))',
#  '  if (command_line.HasSwitch(switches::kAppId))',
#  '      command_line.HasSwitch(switches::kNotificationLaunchId)',
#  '  if (command_line.HasSwitch(switches::kProfileDirectory))',
#  '  if (command_line.HasSwitch(sandbox::policy::switches::kNoSandbox))',
#  '    if (parsed_command_line.HasSwitch(switches::kWindowWorkspace))',
#  '  if (base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kKioskMode))',
#  '  if (base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kKioskMode))',
#  '  if (command_line->HasSwitch(switches::kEnableBackgroundTracing)',
#  '      command_line->HasSwitch(switches::kTraceUploadURL))',
#  '  if (command_line->HasSwitch(switches::kEnableBackgroundTracing)',
#  '      command_line->HasSwitch(switches::kTraceUploadURL))',
#  '  if (command_line.HasSwitch(switches::kTraceUploadURL))',
#  '  if (command_line->HasSwitch(switches::kDisableDomainReliability))',
#  '  if (command_line->HasSwitch(switches::kEnableDomainReliability))',
#  '      command_line.HasSwitch(switches::kEnableEncryptionSelection)',
#  '  if (!command_line.HasSwitch(switches::kWinHttpProxyResolver))',
#  '    if (command_line.HasSwitch(switches::kSingleProcess))',
#  '  if (command_line->HasSwitch(switches::kShortReportingDelay))',
#  '  if (!cmd_line.HasSwitch(switches::kSimulateUpdateHresult))',
#  '  return command_line.HasSwitch(switches::kLoginManager)',
#  '  if (parsed_command_line().HasSwitch(switches::kGuestSession))',
#  '      !parsed_command_line().HasSwitch(switches::kLoginManager)',
#  '      !parsed_command_line().HasSwitch(switches::kLoginUser)',
#  '      !parsed_command_line().HasSwitch(switches::kGuestSession))',
#  '    if (!parsed_command_line().HasSwitch(switches::kLoginProfile))',
#  '  bool immediate_login = parsed_command_line().HasSwitch(switches::kLoginUser)',
#  '  if (parsed_command_line().HasSwitch(::switches::kTestType)',
#  '  if (command_line.HasSwitch(switches::kDisableLoggingRedirect))',
#  '  if (command_line->HasSwitch(chromeos::switches::kTetherStub))',
#  '      base::CommandLine::ForCurrentProcess()->HasSwitch(::switches::kTestType))',
#  '  if (base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kLoginUser))',
#  '  if (command_line->HasSwitch(switches::kForceFirstRunUI))',
#  '  if (command_line->HasSwitch(::switches::kTestType))',
#  '  if (cmdline->HasSwitch(browser_util::kLacrosStabilitySwitch))',
#  '  if (!command_line->HasSwitch(switches::kForceFirstRun)',
#  '      command_line->HasSwitch(switches::kNoFirstRun))',
#  '  if (command_line->HasSwitch(::switches::kTestType))',
#  '  if (cl->HasSwitch(kAshDisableSystemSounds))',
#  '      current_command_line->HasSwitch(switches::kAppAutoLaunched)',
#  '        current_command_line->HasSwitch(::switches::kTestName)',
#  '        current_command_line->HasSwitch(::switches::kTestType)',
#  '  return (command_line->HasSwitch(switches::kMarketingOptInUrl))',
#  '  if (cmd_line->HasSwitch(chromeos::switches::kForceHWIDCheckFailureForTest))',
#  '  if (cmd_line->HasSwitch(::switches::kTestType))',
#  '  if (!cl->HasSwitch(switches::kFingerprintSensorLocation))',
#  '  if (!cl->HasSwitch(switches::kFingerprintSensorLocation))',
#  '  if (!command_line->HasSwitch(switch_name))',
#  '  if (!command_line->HasSwitch(switches::kEnterpriseEnableInitialEnrollment))',
#  '  if (!command_line->HasSwitch(switches::kEnterpriseEnablePrivateSetMembership))',
#  '  if (command_line->HasSwitch(switches::kDisableGaiaServices))',
#  '  if (!command_line->HasSwitch(switches::kEnterpriseEnrollmentInitialModulus)',
#  '      !command_line->HasSwitch(switches::kEnterpriseEnrollmentModulusLimit))',
#  '  if (command_line->HasSwitch(policy::switches::kUserAlwaysAffiliated))',
#  '  if (command_line->HasSwitch(chromeos::switches::kForceFirstRunUI))',
#  '  if (base::CommandLine::ForCurrentProcess()->HasSwitch(::switches::kTestType))',
#  '  if (command_line->HasSwitch(switches::kLoginUser)',
#  '      command_line->HasSwitch(switches::kAppAutoLaunched)',
#  '         command_line->HasSwitch(chromeos::switches::kLoginUser)',
#  '         command_line->HasSwitch(chromeos::switches::kLoginUser)',
#  '  if (cmdline->HasSwitch(switches::kDerelictDetectionTimeout)',
#  '  if (cmdline->HasSwitch(switches::kDerelictIdleTimeout)',
#  '  if (cmdline->HasSwitch(switches::kOobeTimerInterval)',
#  '  return command_line.HasSwitch(switches::kLoginManager)',
#  '  if (command_line->HasSwitch(chromeos::switches::kLoginUser))',
#  '  bool is_running_test = command_line->HasSwitch(::switches::kTestName)',
#  '                         command_line->HasSwitch(::switches::kTestType)',
#  '      parsed_command_line.HasSwitch(switches::kForceLoginManagerInTests)',
#  '  if (parsed_command_line.HasSwitch(switches::kLoginManager)',
#  '  if (base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kLoginUser))',
#  '        cmdline->HasSwitch(chromeos::switches::kOobeSkipPostLogin)',
#  '    if (command_line->HasSwitch(::switches::kAppModeOAuth2Token))',
#  '    if (command_line->HasSwitch(::switches::kAppModeAuthCode))',
#  '      !command_line->HasSwitch(chromeos::switches::kProfileRequiresPolicy)',
#  '  if (base::CommandLine::ForCurrentProcess()->HasSwitch(switches::kTestType))',
#  '    return shortcut_cmd_line.HasSwitch(switches::kProfileDirectory)',
#  '           shortcut_cmd_line.HasSwitch(switches::kAppId)',
#  '      cmdline->HasSwitch(::switches::kDisableBackgroundNetworking))',
#  '  if (command_line->HasSwitch(kBinaryUploadServiceUrlFlag))',
#  '      command_line.HasSwitch(kUwsFoundSwitch)',
#  '  options->set_reboot_required(command_line.HasSwitch(kRebootRequiredSwitch))',
#  '  if (command_line.HasSwitch(kCrashPointSwitch))',
#  '  if (command_line.HasSwitch(kExpectedUserResponseSwitch))',
#  '  return command_line->HasSwitch(switches::kEnableDeviceDiscoveryNotifications)',
#  '  if (command_line->HasSwitch(switches::kStoragePressureNotificationInterval))',
#  '  if (cmdline->HasSwitch(::switches::kExtensionsInstallVerification))',
#  '      command_line_->HasSwitch(switches::kLoadSigninProfileTestExtension)',
#  '  if (command_line_->HasSwitch(switch_name))',
#  '  if (command_line->HasSwitch(::switches::kForceFieldTrials))',
#  '  if (command_line->HasSwitch(::switches::kExtensionContentVerification))',
#  '  if (cmd_line->HasSwitch(::switches::kAppsGalleryDownloadURL))',
#  '  return command_line.HasSwitch(::switches::kDisableExtensions)',
#  '         command_line.HasSwitch(::switches::kDisableExtensionsExcept)',
#  '  if (base::CommandLine::ForCurrentProcess()->HasSwitch(::switches::kTestType))',
#  '  if (!cmd_line.HasSwitch(::switches::kPackExtension))',
#  '  if (cmd_line.HasSwitch(::switches::kPackExtensionKey))',
#  '      (command_line->HasSwitch(::switches::kTestType)',
#  '    if (!command_line->HasSwitch(chromeos::switches::kGuestSession))',
#  '      (command_line->HasSwitch(::switches::kTestType)',
#  '      !command_line->HasSwitch(::switches::kNoErrorDialogs)',
#  '  test_request_ = cmdline->HasSwitch(kSwitchTestRequestParam)',
#  '  if (command_line->HasSwitch(extensions::kSwitchTestRequestParam))',
#  '  std::string result = src.HasSwitch(switch_name)',
#  '  if (command_line->HasSwitch(switches::kCroshCommand))',
#  '          base::CommandLine::ForCurrentProcess()->HasSwitch(params->name))))',
#  '  if (command_line->HasSwitch(query_tiles::switches::kQueryTilesCountryCode))',
#  '  return cmd_line.HasSwitch(switches::kSimulateOutdated)',
#  '         cmd_line.HasSwitch(switches::kSimulateOutdatedNoAU)',
#  '  return cmd_line.HasSwitch(switches::kSimulateUpgrade)',
#  '         cmd_line.HasSwitch(switches::kCheckForUpdateIntervalSec)',
#  '         cmd_line.HasSwitch(switches::kSimulateCriticalUpdate)',
#  '  if (cmd_line.HasSwitch(switches::kDisableBackgroundNetworking))',
#  '    if (cmd_line.HasSwitch(switches::kSimulateOutdatedNoAU))',
#  '  if (cmd_line.HasSwitch(switches::kSimulateUpgrade))',
#  '  if (cmd_line.HasSwitch(switches::kSimulateCriticalUpdate))',
#  '  if (command_line.HasSwitch(switches::kUserDataMigrated))',
#  '  if (command_line->HasSwitch(kAllowBrowserSigninArgument))',
#  '  if (command_line->HasSwitch(switches::kNoStartupWindow)',
#  '      (command_line->HasSwitch(switches::kRemoteDebuggingPipe)',
#  '       command_line->HasSwitch(switches::kRemoteDebuggingPort)))',
#  ...]

# %%
for x in dead_list2:
    print(re.findall(r'k.*', x))
# Out:
# ['kHelpSwitchName)']
# ['kQuestionSwitchName))']
# ['kVersionSwitchName))']
# ['kElevateSwitchName))']
# ['kProcessTypeSwitchName))']
# ['kEvaluateCapabilitySwitchName))']
# ['kHostConfigSwitchName))']
# ['kCheckAccessibilityPermissionSwitchName))']
# ['kCheckScreenRecordingPermissionSwitchName))']
# ['kHostConfigSwitchName))']
# ['kSignalParentSwitchName)']
# ['kReportOfflineReasonSwitchName))']
# ['kHostConfigSwitchName))']
# ['kElevateSwitchName))']
# ['kInputSwitchName))']
# ['kOutputSwitchName))']
# ['kCheckAccessibilityPermissionSwitchName))']
# ['kCheckScreenRecordingPermissionSwitchName))']
# ['kElevateSwitchName))']
# ['kConsoleSwitchName))']
# []
# []
# ['kCheckPermissionSwitchName))']
# ['kParentWindowSwitchName))']
# ['kElevateSwitchName))']
# ['kInputSwitchName))']
# ['kOutputSwitchName))']
# ['kHostConfigSwitchName))']
# ['kSwitchDisable))']
# ['kSwitchEnable))']
# ['kSwitchSaveConfig))']
# ['kSwitchHostVersion))']
# ['kSwitchHostRunFromLaunchd))']
# ['kFtlServerEndpointSwitch))']
# ['kRemotingServerEndpointSwitch))']
# ['kHelp))']
# []
# []
# []
# ['kDisableSurfaceless))']
# ['kEnableVulkan))']
# ['kDisableGpu) && gl::init::InitializeGLOneOff())']
# ['kUseDDL))']
# ['kPartialPrimaryPlane))']
# ['kEnableOverlay))']
# ['kDisablePrimaryPlane)']
# ['kDisableSurfaceless))']
# ['kVSyncInterval))']
# []
# ['kEnableWaylandIme)']
# ['kDisableWaylandIme))']
# ['kEnableWaylandIme))']
# ['kDisableWaylandIme))']
# ['kTestGLLib))']
# ['kOzoneDumpFile))']
# ['kUIShowCompositedLayerBorders))']
# ['kUIShowFPSCounter)']
# ['kUIShowLayerAnimationBounds)']
# ['kUIShowPaintRects)']
# ['kUIShowPropertyChangedRects)']
# ['kUIShowSurfaceDamageRects)']
# ['kUIShowScreenSpaceRects)']
# ['kEnableGpuBenchmarking))']
# ['kUIEnableLayerLists)']
# ['kUIEnableRGBA4444Textures)']
# ['kDisallowNonExactResourceReuse)']
# ['kRunAllCompositorStagesBeforeDraw))']
# ['kLogOnUIDoubleBackgroundBlur))']
# ['kUISlowAnimations))']
# ['kUseCmdDecoder))']
# ['kUseAdapterLuid))']
# ['kUseANGLE)']
# ['kDisableD3D11))']
# ['kDisableGpuDriverBugWorkarounds)']
# ['kDisableDirectComposition))']
# ['kEnableDirectCompositionVideoOverlays))']
# ['kDisableDirectCompositionVideoOverlays))']
# ['kUseGL)']
# ['kDisableES3GLContext))']
# ['kDisableES3GLContextForTesting))']
# ['kOverrideUseSoftwareGLForTests))']
# ['kUseGL))']
# ['kDisableGLDrawingForTests)']
# ['kTestGLLib))']
# ['kHostWindowBounds))']
# ['kUseFirstDisplayAsInternal)']
# ['kSecondaryDisplayLayout))']
# ['kSecondaryDisplayLayout))']
# ['kScreenConfig))']
# ['kHeadless)']
# ['kHeadless))']
# []
# []
# ['kForceTextDirection))']
# ['kHeadless))']
# ['kHeadless))']
# ['kHeadless))']
# ['kNoXshm))']
# ['kHeadless))']
# ['kCountSwitch))']
# ['kPermuteSwitch)']
# ['kHelpSwitch))']
# ['kFuzzerNameSwitch))']
# ['kFrequencySwitch))']
# ['kHelpSwitch))']
# ['kStartSwitch))']
# ['kEndSwitch))']
# ['kRegexpSwitch)']
# ['kInvertSwitch)']
# ['kDumpSwitch)']
# ['kInSwitch)']
# []
# ['kill-server"))']
# []
# []
# []
# []
# ['kill-server")']
# []
# ['kNoSpawnDaemon)']
# ['kOptionFuzzyDiff)']
# ['kOptionCompareHistograms)']
# ['kOptionPollStdin))']
# ['kOptionGenerateDiff))']
# []
# []
# []
# []
# []
# []
# []
# ['kChromeSwitch))']
# ['kChromiumSwitch))']
# ['kFirefoxSwitch))']
# ['kSafariSwitch))']
# ['kActiveTabSwitch))']
# ['kHelpSwitch))']
# ['kHelpSwitch))']
# []
# ['kNoSmartSkippingSwitch))']
# ['kMoreSlopeChecksSwitch))']
# []
# ['kCompileShaderAlwaysSucceeds)']
# ['kDisableGLErrorLimit)']
# ['kDisableGLSLTranslator)']
# ['kDisableShaderNameHashing)']
# ['kEnableGPUCommandLogging)']
# ['kEnableGPUDebugging)']
# ['kEnableGPUServiceLoggingGPU)']
# ['kEnableGPUDriverDebugLogging)']
# ['kDisableGpuProgramCache)']
# ['kEnforceGLMinimums)']
# ['kDisableGpuShaderDiskCache)']
# ['kEnableThreadedTextureMailboxes)']
# ['kGLShaderIntermOutput)']
# ['kEmulateShaderPrecision)']
# ['kEnableGPUServiceLogging)']
# ['kEnableGPUServiceTracing)']
# ['kIgnoreGpuBlocklist)']
# ['kEnableUnsafeWebGPU)']
# ['kEnableDawnBackendValidation)']
# ['kEnableDawnFeatures))']
# ['kDisableDawnFeatures))']
# ['kDisableVulkanSurface)']
# ['kEnableGpuBlockedTime)']
# ['kWebViewDrawFunctorUsesVulkan)']
# ['kUseVulkan))']
# []
# ['kDisableGpuRasterization))']
# ['kEnableGpuRasterization))']
# ['kUseGL))']
# ['kUseANGLE))']
# ['kUseGpuInTests))']
# ['kGpuBlocklistTestGroup))']
# ['kDisableGpuDriverBugWorkarounds))']
# ['kGpuDriverBugListTestGroup))']
# ['kUseGL))']
# ['kGpuVendorId))']
# ['kGpuDeviceId))']
# ['kGpuSubSystemId))']
# ['kGpuRevision))']
# ['kGpuDriverVersion))']
# ['kOverrideUseSoftwareGLForTests))']
# ['kFeatureList[i].name))']
# []
# ['kHeadless)']
# ['kUseGL))']
# ['kWebViewDrawFunctorUsesVulkan)']
# ['kDisableGpuDriverBugWorkarounds))']
# ['key")']
# []
# []
# []
# ['kDumpContents))']
# ['kDumpLists))']
# ['kDumpEntry) && command_line.HasSwitch(kDumpAt))']
# ['kDumpAllocation)']
# ['kDumpFile))']
# ['kDumpHeaders))']
# []
# []
# []
# ['kFileToWrite)']
# ['kExampleCount))']
# []
# []
# []
# ['kRMQFileName))']
# ['kAndroidIdSwitch))']
# ['kSecretSwitch))']
# ['kServerHostSwitch))']
# ['kServerPortSwitch))']
# ['kLogFileSwitch))']
# ['kIgnoreCertSwitch))']
# ['kGCMCheckinURL))']
# ['kGCMMCSEndpoint))']
# ['kGCMMCSEndpoint))']
# ['kGCMRegistrationURL))']
# ['kGaiaConfig))']
# []
# ['kForceHeadlessForTestsSwitch)']
# ['kDisableVulkanForTestsSwitch))']
# ['kFrameHostConfigKey)']
# ['kGoogleApiKey))']
# []
# []
# ['kGoogleApiKey))']
# ['kEnableWidevine))']
# ['kCdmDataQuotaBytes))']
# ['kHeadless)']
# ['kRemoteDebuggingPort))']
# ['kRemoteDebuggerHandles))']
# ['kDataQuotaBytes))']
# ['k::switches::kLogNetLog))']
# ['kIncognito))']
# ['kLogFile))']
# ['kSystemInDevMode)']
# ['kSwitchErrorOnUnknownField)']
# ['kSwitchErrorOnWrongRecommended)']
# ['kSwitchErrorOnMissingField)']
# ['kSwitchManagedOnc))']
# ['kSwitchUserPolicy))']
# ['kSwitchDevicePolicy))']
# ['kSwitchUserImport))']
# ['kHermesFake))']
# ['kShillStub))']
# ['kCrosRegionsMode))']
# ['kAppOemManifestFile))']
# ['kCrosRegion))']
# ['kTelemetryExtensionDirectory)']
# ['kCrosStartupDataFD))']
# ['kOndeviceHandwritingSwitch)']
# ['kCryptAuthHTTPHost)']
# ['kCryptAuthV2EnrollmentHTTPHost)']
# ['kCryptAuthV2DeviceSyncHTTPHost)']
# []
# []
# []
# []
# []
# ['ke_patch = command_line.HasSwitch("gen")']
# []
# ['ke_bsdiff_patch = command_line.HasSwitch("genbsdiff")']
# []
# []
# []
# []
# []
# ['kJavaScriptHarmony, "--harmony")']
# ['kDisableInProcessStackTraces))']
# ['kEnableCrashReporter)']
# ['kNoV8UntrustedCodeMitigations))']
# ['kJavaScriptFlags))']
# ['kIpcDumpDirectory))']
# ['kDisableThreadedAnimation)']
# ['kDisableLCDText))']
# ['kEnableLCDText))']
# ['kDisableGpuCompositing))']
# ['kDisableAcceleratedVideoDecode)']
# ['kEnableVtune))']
# ['kDisableThreadedCompositing))']
# ['k::switches::kExplicitlyAllowedPorts))']
# ['kDisableAcceleratedVideoDecode)']
# ['kDisableGpuMemoryBufferVideoFrames)']
# ['kEnableGpuMemoryBufferVideoFrames)']
# ['kEnableGpuMemoryBufferVideoFrames)']
# ['kWaitForDebugger))']
# ['kRendererStartupDialog))']
# ['kLang))']
# ['kInitialVirtualTime))']
# ['kNoSandbox)']
# ['kWebglMSAASampleCount))']
# ['kWebglAntialiasingMode))']
# ['kMaxActiveWebGLContexts))']
# ['kNoSandbox)']
# ['kDomAutomationController))']
# ['kStatsCollectionController))']
# ['kEnableGpuBenchmarking))']
# ['kEnableSkiaBenchmarking))']
# ['kWebRtcStunProbeTrialParameter))']
# ['kDisableAXMenuList))']
# ['kGpuPreferences))']
# ['kHeadless))']
# ['kUseHighGPUThreadPriorityForPerfTests)']
# ['kNoZygote))']
# ['kNoSandbox))']
# ['kSingleProcess)']
# ['kInProcessGPU)))']
# ['kSingleProcess))']
# ['kSingleProcess))']
# ['kDeviceScaleFactor))']
# ['kDisableInProcessStackTraces))']
# ['kProcessType)']
# ['kExposeInternalsForTesting))']
# []
# []
# ['kUseMobileUserAgent)']
# ['kUseMobileUserAgent))']
# ['kUseFakeDeviceForMediaStream)']
# ['kUseFakeUIForMediaStream))']
# ['kForceWebRtcIPHandlingPolicy))']
# ['kContentShellHostWindowSize))']
# ['kBrowserTest))']
# ['kEnableCrashReporter))']
# ['kRemoteDebuggingSocketName))']
# ['kRemoteDebuggingPort))']
# ['kRemoteDebuggingPipe))']
# ['kIgnoreCertificateErrors))']
# ['kContentShellDataPath))']
# ['kProcessPerSite))']
# ['kNoSandbox))']
# ['kSingleProcess))']
# ['kEnableGpuBenchmarking))']
# []
# ['k::switches::kLogNetLog))']
# ['k::switches::kSSLKeyLogFile))']
# ['kWaitForDebugger))']
# ['kBrowserStartupDialog))']
# ['kNoSandbox)']
# ['kForceFieldTrials))']
# ['kUtilityCmdPrefix)']
# ['kNoZygote)']
# ['kBrowserTest))']
# ['kSingleProcess))']
# ['kRendererProcessLimit))']
# ['kSingleProcess))']
# ['kSingleProcess))']
# ['kDisableGpu)']
# ['kDisableGpuCompositing)']
# ['kDisableGpuEarlyInit))']
# ['kSingleProcess)']
# ['kInProcessGPU)']
# ['kHeadless)']
# ['kSingleProcess))']
# ['kTraceStartupFile))']
# ['kTraceStartup))']
# ['kEnableLogging))']
# ['kDisableGpuSandbox))']
# ['kDisableGpu)']
# ['kSingleProcess)']
# ['kInProcessGPU))']
# ['kDisableFrameRateLimit))']
# ['kDisableAccelerated2dCanvas)']
# ['kDisableWebGL)']
# ['kDisableAcceleratedVideoDecode)']
# ['kDisableGpuRasterization))']
# ['kDisableOopRasterization)']
# ['kUseVulkan)']
# ['kDisableWebGL)']
# ['kDisableWebGL2))']
# ['kEnableGpuRasterization))']
# ['kNumRasterThreads))']
# ['kNumRasterThreads))']
# ['k::switches::kDisableZeroCopy)']
# ['k::switches::kEnableZeroCopy)']
# ['k::switches::kDisablePartialRaster)']
# ['kDisableTimeoutsForProfiling))']
# ['kSingleProcess)']
# ['kInProcessGPU))']
# ['kNoSandbox))']
# ['kNoZygoteSandbox)']
# ['kDisableFrameRateLimit))']
# ['kDisableWebSecurity)']
# ['kDisableRemoteFonts)']
# ['kDisableLocalStorage)']
# ['kDisableDatabases)']
# ['kDisable3DAPIs)']
# ['kDisableWebGL)']
# ['kDisable3DAPIs)']
# ['kDisableWebGL)']
# ['kDisableWebGL2)']
# ['kDisablePepper3d)']
# ['kDisableFlash3d)']
# ['kDisableFlashStage3d)']
# ['kDisableFlashStage3d)']
# ['kAllowFileAccessFromFiles)']
# ['kDisableAccelerated2dCanvas)']
# ['kEnableNewCanvas2DAPI)']
# ['kDisable2dCanvasAntialiasing)']
# ['kDisable2dCanvasClipAntialiasing)']
# ['kDisableIpcFloodingProtection)']
# ['kDisablePushStateThrottle)']
# ['kDisableAcceleratedVideoDecode)']
# ['kEnableSmoothScrolling)']
# ['kDisableSmoothScrolling)']
# ['kEnableViewport)']
# ['k::switches::kDisableThreadedScrolling)']
# ['kMainFrameResizesAreOrientationChanges)']
# ['kEnableSpatialNavigation)']
# ['kDisableReadingFromCanvas)']
# ['kEnableStrictMixedContentChecking)']
# ['kTouchEventFeatureDetection)']
# ['kWebXrForceRuntime))']
# ['kEnableSpeechDispatcher))']
# ['kDisableNewContentRenderingTimeout))']
# ['kDisableKillAfterBadIPC))']
# ['kWebRtcStunProbeTrialParameter))']
# ['kDisableDatabases))']
# ['kDisableGpuCompositing))']
# ['kWaitForDebuggerChildren))']
# ['kRendererStartupDialog)']
# ['kNoSandbox))']
# ['kLang))']
# ['kEnableGpuBenchmarking))']
# ['kUIShowFPSCounter)']
# ['kUIShowCompositedLayerBorders))']
# ['kUseFakeDeviceForMediaStream))']
# ['kUseFakeDeviceForMediaStream))']
# ['kNoDelayForDX12VulkanInfoCollection)']
# ['kEnableAutomation))']
# ['kSingleProcess)']
# ['kQuotaChangeEventInterval))']
# ['kDisableAcceleratedVideoDecode))']
# ['kMojoCoreLibraryPath))']
# ['kWaitForDebuggerChildren))']
# ['kDisableSkiaRuntimeOpts))']
# ['kSkiaFontCacheLimitMb))']
# ['kSkiaResourceCacheLimitMb))']
# ['kGpuPreferences))']
# ['kSeatbeltClientName))']
# ['kZygoteCmdPrefix))']
# ['kPpapiInProcess))']
# ['kDisableKillAfterBadIPC))']
# ['kDisableAcceleratedVideoDecode)']
# ['kDisableAcceleratedVideoEncode)']
# ['kDisableLowLatencyDxva)']
# ['kDisableZeroCopyDxgiVideo)']
# ['kDisableNv12DxgiVideo)']
# ['kDisableSoftwareRasterizer)']
# ['kLogGpuControlListDecisions)']
# ['kGpuStartupDialog)']
# ['kDisableGpuWatchdog)']
# ['kSingleProcess)']
# ['kInProcessGPU)']
# ['kGpuSandboxStartEarly)']
# ['kEnableOopRasterization)']
# ['kDisableOopRasterization)']
# ['kEnableVulkanProtectedMemory)']
# ['kEnforceVulkanProtectedMemory)']
# ['kDisableVulkanFallbackToGLForTesting)']
# ['kEnableGpuBenchmarking)']
# ['kEnableNativeGpuMemoryBuffers)']
# ['kDisableOoprDebugCrashDump)']
# ['kProfilingFile))']
# ['kProfilingAtStart))']
# ['kProfilingFlush)']
# ['kEnableUseZoomForDSF)']
# ['kMaxDecodedImageSizeMb))']
# ['kProcessType))']
# ['kProcessType)']
# ['kWebXrForceRuntime))']
# ['kSingleProcess))']
# ['kPpapiStartupDialog))']
# ['kLang))']
# ['kMessageLoopTypeUi)']
# ['kUtilityStartupDialog))']
# ['kBlobFileTransportByFileTriggerSwitch)))']
# ['kBlobSharedMemoryTransportMaxSizeSwitch)))']
# ['kBlobFileTransportMinFileSizeSwitch)))']
# ['kBlobFileTransportMaxFileSizeSwitch)))']
# ['kBlobFileTransportByFileTriggerSwitch)))']
# ['kTestType)']
# ['kContentShellDataPath))']
# ['kLogFile))']
# ['kAppShellHostWindowSize))']
# ['kLoadExtension))']
# ['kLoadApps))']
# ['kSwitchInputFilterlistFiles)']
# ['kSwitchOutputPath))']
# ['kSwitchOutputType))']
# ['kOverrideMetricsUploadUrl))']
# ['kAudioOutputChannels))']
# ['kCastInitialScreenWidth))']
# ['kCastInitialScreenHeight))']
# []
# []
# ['kDisableGpu))']
# ['kRemoteDebuggingSocketName))']
# ['kTestType))']
# ['kCastMojoBrokerPathSwitch))']
# ['kSysInfoFilePath))']
# ['kHeightSwitch)']
# ['kWidthSwitch)']
# []
# []
# []
# []
# ['kMetricsRecordingOnly))']
# ['kResetVariationState))']
# ['kMetricsUploadIntervalSec))']
# ['kAutofillAssistantServerKey))']
# ['kTraceToConsole))']
# ['kTraceStartupDuration))']
# ['kEnableTracing))']
# ['kTraceStartupFormat))']
# ['kTraceStartup)']
# ['kEnableTracing))']
# ['kTraceStartup))']
# ['kTraceConfigFile))']
# ['kEnableWebsocketOverHttp2))']
# ['kHttp2GreaseSettings)']
# ['kHttp2GreaseFrameType)']
# ['kHttp2EndStreamWithDataFrame)']
# ['kForceFieldTrialParams))']
# ['kDisableQuic)']
# ['kDisableHttp2))']
# ['kQuicConnectionOptions))']
# ['kQuicClientConnectionOptions))']
# ['kQuicMaxPacketLength))']
# ['kQuicVersion))']
# ['kOriginToForceQuicOn))']
# ['kEnableUserAlternateProtocolPorts))']
# ['kIgnoreCertificateErrors))']
# ['kIgnoreCertificateErrors))']
# ['kTestingFixedHttpPort))']
# ['kTestingFixedHttpsPort))']
# ['kHostRules))']
# ['kOriginTrialPublicKey))']
# ['kOriginTrialDisabledFeatures))']
# ['kOriginTrialDisabledTokens))']
# ['kTrustedCDNBaseURLForTests))']
# ['kGoogleDoodleUrl))']
# ['kSearchProviderLogoURL))']
# ['kThirdPartyDoodleURL))']
# ['kTranslateRankerModelURL))']
# ['kTranslateScriptURL))']
# ['kTranslateSecurityOrigin))']
# []
# []
# ['kEnableBenchmarking)']
# ['kEnableGpuBenchmarking))']
# ['kForceFieldTrialParams))']
# ['kForceFieldTrials))']
# ['kDisableFieldTrialTestingConfig)']
# ['kForceFieldTrials)']
# ['kVariationsServerURL))']
# ['kForceRemoteShellScale))']
# ['kWaylandServerSocket))']
# []
# []
# ['kSigmaX)']
# ['kSigmaY)']
# ['kMaxSigma)']
# ['kSize))']
# ['kScale)']
# ['kTransform))']
# ['kUseDrm)']
# ['kUseMemfd)']
# ['kFullscreen)']
# ['kTransparentBackground)']
# ['kYInvert)']
# ['kLogVSyncTimingUpdates)']
# ['kMaxFramesPending)']
# ['kNumRects)']
# ['kBenchmark)']
# ['kBenchmarkInterval)']
# ['kShowFpsCounter))']
# []
# ['kAutofillServerURL))']
# ['kAutofillAPIKey))']
# []
# ['kEnableCrashpad)']
# ['kDisableBreakpad))']
# ['kDisableBreakpad)']
# ['kEnableCrashReporter))']
# ['kEnableCrashReporter))']
# ['kTestChildProcess))']
# ['kNoErrorDialogs)']
# ['kNoErrorDialogs)']
# ['kDisableBreakpad))']
# ['kFullMemoryCrashReport))']
# ['kFeedbackServer)']
# ['kEnableExperimentalWebPlatformFeatures))']
# ['kEnableNTPSearchEngineCountryDetection))']
# ['kUIDisablePartialSwap)']
# ['kDisableCompositedAntialiasing)']
# ['kSlowDownCompositingScaleFactor))']
# ['kEnableHardwareOverlays))']
# ['kTintCompositedContent)']
# ['kShowOverdrawFeedback)']
# ['kShowDCLayerDebugBorders)']
# ['kShowAggregatedDamage)']
# []
# ['kDoubleBufferCompositing))']
# ['kDoubleBufferCompositing))']
# ['kHeadless)']
# ['kRunAllCompositorStagesBeforeDraw)']
# ['kClearTokenService))']
# ['kEnableNaClDebug)']
# ['kNoSandbox))']
# ['kNaClGdb)']
# ['kEnableNaClDebug))']
# ['kEnableNaClNonSfiMode)']
# ['kNoSandbox)']
# ['kEnableLogging))']
# ['kEnableNaClDebug)']
# ['kSyncShortInitialRetryOverride))']
# ['kSyncShortNudgeDelayForTest))']
# ['kSyncDeferredStartupTimeoutSeconds))']
# ['kSyncServiceURL))']
# ['kSwitchRuleset))']
# ['kSwitchOrigin)']
# ['kSwitchUrl)']
# ['kSwitchType))']
# []
# ['kSwitchMinMatches)']
# ['kSwitchInputFile))']
# ['kSwitchVersionOutput))']
# ['kSwitchContentVersion))']
# ['kSwitchOutputFile)']
# ['kSwitchOutputFileUrl)']
# ['kSwitchOutputFileCss)']
# ['kSwitchChromeVersion)']
# ['kSwitchInputFormat)']
# ['kSwitchOutputFormat)']
# ['kSwitchKeep)']
# ['kSwitchRaw)']
# ['kSwitchKeep))']
# ['kSwitchDump)']
# []
# ['kArcAvailability))']
# ['kEnableArc)']
# ['kArcAvailable)']
# ['kArcStartMode))']
# ['kArcAvailability))']
# ['kArcAvailable))']
# ['kArcScale))']
# ['kArcBuildProperties))']
# ['kEnableHoudini)']
# ['kEnableHoudini64)']
# ['kEnableNdkTranslation)']
# ['kEnableNdkTranslation64)']
# ['kLoginUser)']
# []
# ['kMemlogMode)']
# ['kMemlogMode))']
# ['kMemlogMode))']
# ['kMemlogStackMode))']
# ['kMemlogSamplingRate))']
# ['kSingleProcess))']
# ['kDeviceManagementUrl)']
# ['kRealtimeReportingUrl)']
# ['kEncryptedReportingUrl)']
# ['kChromePolicy))']
# ['kProcessType)']
# ['kNoSandbox))']
# ['kServiceSandboxType))']
# ['kServiceSandboxType))']
# ['kNoSandbox))']
# ['kNoSandboxAndElevatedPrivileges))']
# ['kDisableGpuSandbox))']
# ['kAllowNoSandboxJob)']
# ['kAllowNoSandboxJob)']
# ['kAllowNoSandboxJob))']
# ['kNoSandbox)']
# ['kNoSandbox))']
# ['kAllowThirdPartyModules)']
# ['kNoSandbox))']
# ['kNoSandbox)']
# ['kDisableSeccompFilterSandbox)']
# ['kGpuSandboxFailuresFatal))']
# ['kSingleProcess))']
# ['kRemoteDebuggingPort))']
# ['kProxyServerSwitch))']
# ['kProxyBypassListSwitch))']
# ['kForceGpuMemAvailableMb)']
# ['kTintCompositedContent)']
# ['kWebViewSandboxedRenderer))']
# ['kWebViewLogJsConsoleMessages))']
# ['kWebViewDrawFunctorUsesVulkan))']
# ['kEnableBenchmarking))']
# ['kEnableNetBenchmarking))']
# ['kInstantProcess))']
# ['kInstantProcess)']
# ['kPpapiInProcess))']
# ['kDisableClientSidePhishingDetection))']
# ['kInstantProcess))']
# ['kDisablePrintPreview)']
# ['kStandaloneInstall))']
# ['kInstallerData))']
# ['kLoggingLevel))']
# ['kEnableStats)']
# ['kDisableStats))']
# ['kUninstall)']
# ['kEnableStats)']
# ['kDisableStats))']
# ['kDisableStats)']
# ['kUninstall)']
# ['kExecutable))']
# ['kOutputFile))']
# ['kHeadless))']
# ['kProductVersion))']
# ['kVersion))']
# ['kHelp)']
# ['kHelpShort))']
# ['kDisableWebSecurity))']
# ['kProcessType)']
# ['kProcessType)']
# ['kDiagnostics))']
# ['kDiagnosticsFormat))']
# ['kHomedir))']
# ['kLoginUser))']
# ['kDiagnosticsRecovery))']
# ['kDiagnosticsFormat))']
# ['kRelauncherProcessDMGDevice)']
# ['kProcessType)']
# ['kProcessType)']
# ['kEnableUserMetrics)']
# ['kMakeChromeDefault)']
# ['kLang)']
# ['kLang)']
# ['ks"))']
# ['kUserDataDir))']
# ['kConsoleSwitchName))']
# ['kCrashHandlerSwitch))']
# ['kCrashHandlerSwitch))']
# ['kCrashMeSwitch))']
# ['kServerSwitch))']
# ['kUpdateSwitch))']
# ['kComServiceSwitch))']
# ['kInstallSwitch)']
# ['kTagSwitch))']
# ['kUninstallSwitch))']
# ['kWakeSwitch))']
# ['kTestSwitch))']
# ['kCrashHandlerSwitch))']
# ['kGetSuperfluousCertTagSwitch)']
# ['kPaddedLength))']
# ['kConsoleSwitchName))']
# ['kInstallFromOutDir))']
# ['kEnableEncryptionSelection)']
# ['kLoginManager))']
# ['kUserDataDir))']
# ['kProfileDirectory))']
# ['kApp))']
# ['kAppId))']
# ['kDisableBackgroundNetworking))']
# ['kExtensionProcess))']
# ['kEnableAutomation))']
# ['kEnableAutoReload))']
# ['kDisableAutoReload))']
# ['kUserAgent))']
# ['kUseMobileUserAgent)']
# ['kUseMobileUserAgent))']
# ['king HasSwitch() and returning)']
# ['k::switches::kBlinkSettings)']
# ['k::switches::kBlinkSettings))']
# ['kIgnoreGpuBlocklist)']
# ['kDisableBreakpad))']
# ['kEnableThreadInstructionCount)']
# ['kNoSandbox))']
# ['kEnableWebBluetooth)']
# ['kEnableNetBenchmarking)']
# ['kBrowserCrashTest))']
# ['kProfileDirectory)']
# ['kAppId))']
# ['kOriginTrialPublicKey))']
# ['kOriginTrialDisabledTokens))']
# ['kApp)']
# ['kAppId))']
# ['kSitePerProcess))']
# ['kAutoOpenDevToolsForTabs))']
# ['kUninstall))']
# ['kHideIcons)']
# ['kShowIcons))']
# ['kMakeDefaultBrowser))']
# ['kPackExtension))']
# ['kTestType))']
# ['kBrowserTest))']
# ['kDebugPrint))']
# ['kDisableComponentUpdate))']
# ['kAppId))']
# ['kNoExperiments))']
# ['kWmClass))']
# ['kAppId))']
# ['kAppId)']
# ['kFromInstaller))']
# ['kBrowserCrashTest)']
# ['kNoErrorDialogs))']
# ['kHideIcons))']
# ['kRestoreLastSession))']
# []
# ['kUserDataDir))']
# ['kNoStartupWindow))']
# ['kNoStartupWindow))']
# ['kKeepAliveForTest))']
# ['kNoProxyServer)']
# ['kProxyAutoDetect)']
# ['kProxyServer)']
# ['kProxyPacUrl)']
# ['kProxyBypassList)))']
# ['kNoProxyServer))']
# ['kProxyPacUrl))']
# ['kProxyAutoDetect))']
# ['kProxyServer))']
# ['kCipherSuiteBlacklist))']
# ['kDisableExtensions))']
# ['kIncognito)']
# ['kUserDataDir))']
# ['kApp))']
# ['kCrashOnHangThreads))']
# ['kTouchEventFeatureDetection)']
# ['kWindowSize))']
# ['kWindowPosition))']
# ['kEnableCommander)']
# ['kEnableCrOSActionRecorder))']
# ['kEnableAutomation))']
# ['kTestType)']
# ['kBrowserTest))']
# ['kCustomDevtoolsFrontend))']
# ['kEnableExperimentalWebPlatformFeatures))']
# ['kKioskModePrinting))']
# ['kKioskModePrinting)']
# ['kEduCoexistenceLoginURLSwitch))']
# ['kAddSupervisionSwitch))']
# ['kShowOobeDevOverlay)']
# ['kEnableOobeTestAPI)']
# ['kTestName)']
# ['kTestType)']
# ['kShowOobeDevOverlay)']
# ['kEnableOobeTestAPI)']
# ['kOobeScreenshotDirectory))']
# ['kKioskMode))']
# ['kKioskMode))']
# ['kTestName)']
# ['kTestType)']
# []
# ['kKioskMode)']
# ['kInstallChromeApp))']
# ['kNoStartupWindow))']
# ['kOpenInNewWindow))']
# ['kEnableAutomation)']
# ['kKioskMode))']
# ['kTestType)']
# ['kEnableAutomation))']
# ['kNoDefaultBrowserCheck))']
# ['kIncognito)']
# ['kProfileDirectory))']
# ['kApp)']
# ['kAppId))']
# ['kSilentLaunch))']
# ['kApp))']
# ['kAppId))']
# ['kGcpwSigninSwitch))']
# ['kNotificationLaunchId))']
# ['kIncognito))']
# ['kRestoreLastSession) || did_restart)']
# ['kDisablePromptOnRepost))']
# ['kCloudPrintFile)']
# ['kValidateCrx))']
# ['kLoginManager))']
# ['kDumpBrowserHistograms))']
# ['kNativeMessagingConnectHost)']
# ['kNativeMessagingConnectExtension))']
# ['kNoStartupWindow))']
# ['kUninstallAppId))']
# ['kLoadApps)']
# ['kLoadAndLaunchApp) && can_use_last_profile)']
# ['kWinJumplistAction))']
# ['kNotificationLaunchId))']
# ['kGcpwSigninSwitch))']
# ['kAppId))']
# ['kNotificationLaunchId)']
# ['kProfileDirectory))']
# ['kNoSandbox))']
# ['kWindowWorkspace))']
# ['kKioskMode))']
# ['kKioskMode))']
# ['kEnableBackgroundTracing)']
# ['kTraceUploadURL))']
# ['kEnableBackgroundTracing)']
# ['kTraceUploadURL))']
# ['kTraceUploadURL))']
# ['kDisableDomainReliability))']
# ['kEnableDomainReliability))']
# ['kEnableEncryptionSelection)']
# ['kWinHttpProxyResolver))']
# ['kSingleProcess))']
# ['kShortReportingDelay))']
# ['kSimulateUpdateHresult))']
# ['kLoginManager)']
# ['kGuestSession))']
# ['kLoginManager)']
# ['kLoginUser)']
# ['kGuestSession))']
# ['kLoginProfile))']
# ['kLoginUser)']
# ['kTestType)']
# ['kDisableLoggingRedirect))']
# ['kTetherStub))']
# ['kTestType))']
# ['kLoginUser))']
# ['kForceFirstRunUI))']
# ['kTestType))']
# ['kLacrosStabilitySwitch))']
# ['kForceFirstRun)']
# ['kNoFirstRun))']
# ['kTestType))']
# ['kAshDisableSystemSounds))']
# ['kAppAutoLaunched)']
# ['kTestName)']
# ['kTestType)']
# ['kMarketingOptInUrl))']
# ['kForceHWIDCheckFailureForTest))']
# ['kTestType))']
# ['kFingerprintSensorLocation))']
# ['kFingerprintSensorLocation))']
# []
# ['kEnterpriseEnableInitialEnrollment))']
# ['kEnterpriseEnablePrivateSetMembership))']
# ['kDisableGaiaServices))']
# ['kEnterpriseEnrollmentInitialModulus)']
# ['kEnterpriseEnrollmentModulusLimit))']
# ['kUserAlwaysAffiliated))']
# ['kForceFirstRunUI))']
# ['kTestType))']
# ['kLoginUser)']
# ['kAppAutoLaunched)']
# ['kLoginUser)']
# ['kLoginUser)']
# ['kDerelictDetectionTimeout)']
# ['kDerelictIdleTimeout)']
# ['kOobeTimerInterval)']
# ['kLoginManager)']
# ['kLoginUser))']
# ['kTestName)']
# ['kTestType)']
# ['kForceLoginManagerInTests)']
# ['kLoginManager)']
# ['kLoginUser))']
# ['kOobeSkipPostLogin)']
# ['kAppModeOAuth2Token))']
# ['kAppModeAuthCode))']
# ['kProfileRequiresPolicy)']
# ['kTestType))']
# ['kProfileDirectory)']
# ['kAppId)']
# ['kDisableBackgroundNetworking))']
# ['kBinaryUploadServiceUrlFlag))']
# ['kUwsFoundSwitch)']
# ['kRebootRequiredSwitch))']
# ['kCrashPointSwitch))']
# ['kExpectedUserResponseSwitch))']
# ['kEnableDeviceDiscoveryNotifications)']
# ['kStoragePressureNotificationInterval))']
# ['kExtensionsInstallVerification))']
# ['kLoadSigninProfileTestExtension)']
# []
# ['kForceFieldTrials))']
# ['kExtensionContentVerification))']
# ['kAppsGalleryDownloadURL))']
# ['kDisableExtensions)']
# ['kDisableExtensionsExcept)']
# ['kTestType))']
# ['kPackExtension))']
# ['kPackExtensionKey))']
# ['kTestType)']
# ['kGuestSession))']
# ['kTestType)']
# ['kNoErrorDialogs)']
# ['kSwitchTestRequestParam)']
# ['kSwitchTestRequestParam))']
# []
# ['kCroshCommand))']
# []
# ['kQueryTilesCountryCode))']
# ['kSimulateOutdated)']
# ['kSimulateOutdatedNoAU)']
# ['kSimulateUpgrade)']
# ['kCheckForUpdateIntervalSec)']
# ['kSimulateCriticalUpdate)']
# ['kDisableBackgroundNetworking))']
# ['kSimulateOutdatedNoAU))']
# ['kSimulateUpgrade))']
# ['kSimulateCriticalUpdate))']
# ['kUserDataMigrated))']
# ['kAllowBrowserSigninArgument))']
# ['kNoStartupWindow)']
# ['kRemoteDebuggingPipe)']
# ['kRemoteDebuggingPort)))']
# ['kForceDevToolsAvailable))']
# ['kRemoteDebuggingPipe))']
# ['kCustomDevtoolsFrontend))']
# ['kCustomDevtoolsFrontend)']
# ['kDevToolsFlags))']
# ['kCustomDevtoolsFrontend))']
# ['kKioskMode))']
# ['kRemoteDebuggingTargets))']
# ['kForceFirstRun)']
# ['kNoFirstRun))']
# ['kNoFirstRun)']
# []
# []
# ['kRemoteDebuggingSocketName))']
# []
# []
# []
# []
# ['kDisableTopSites)']
# ['kLoginUser))']
# ['kHomePage))']
# ['kEnableProfileShortcutManager))']
# ['kGuest)']
# ['kSupervisedUserId)']
# ['kNearbyShareHTTPHost)']
# ['kEnableLiveCaptionPrefForTesting))']
# ['kForceAppMode)']
# ['kAppId))']
# ['kKioskMode)']
# ['kTestType))']
# ['kAppId))']
# ['kDesktopPWAsAttentionBadgingCrOS))']
# ['kInstallAutogeneratedTheme))']
# ['kNotificationLaunchId))']
# ['kTestType))']
# ['kSystemDevMode)']
# ['kAllowRAInDevMode))']
# ['kInvertLoggingSwitch))']
# ['kEnableLogging))']
# ['kLoginProfile))']
# ['kGuestSession))']
# ['kNoErrorDialogs)']
# ['kLoggingLevel)']
# ['kAppsGalleryURL))']
# ['kAppsGalleryUpdateURL))']
# ['kStartStackProfiler)']
# ['kExtensionProcess)']
# ['kSingleProcess)']
# ['kInProcessGPU)']
# ['kWaitForDebugger))']
# ['kNoErrorDialogs))']
# ['k::switches::kIgnoreUrlFetcherCertRequests))']
# ['kEnableCloudPrintProxy)']
# ['kInstallerData))']
# []
# ['kLegacySwitches[i]))']
# ['kUninstall)']
# ['kExperimentParticipation))']
# ['kDeleteProfile)']
# ['kRunAsAdmin))']
# ['kSelfDestruct)']
# []
# ['kChannel)']
# ['kSelfDestruct)']
# ['kForceUninstall)']
# ['kDoNotRemoveSharedItems)']
# ['kTriggerActiveSetup))']
# ['kInstallerData))']
# ['kDelay))']
# ['kUpdateSetupExe))']
# ['kShowEula))']
# ['kConfigureUserSettings))']
# ['kForceConfigureUserSettings)']
# ['kRegisterDevChrome))']
# ['kRegisterChromeBrowser))']
# ['kRegisterChromeBrowserSuffix))']
# ['kRegisterURLProtocol))']
# ['kDeleteOldVersions)']
# ['kRenameChromeExe))']
# ['kDeleteOldVersions))']
# ['kRenameChromeExe))']
# ['kRegisterChromeBrowserSuffix))']
# ['kOnOsUpgrade))']
# ['kUserExperiment))']
# ['kPatch))']
# ['kReenableAutoupdates))']
# ['kStoreDMToken))']
# ['kPreviousVersion))']
# ['kUninstall)']
# ['kSelfDestruct)']
# ['kRemoveChromeRegistration)))']
# ['kMakeChromeDefault)']
# ['kRegisterChromeBrowser)))']
# ['kUserExperiment))']
# ['kRunAsAdmin))']
# ['kSystemLevel))']
# []
# ['kEngineSwitch))']
# ['kExtendedSafeBrowsingEnabledSwitch)']
# ['kWithCleanupModeLogsSwitch))']
# ['kWithScanningModeLogsSwitch))']
# ['kNoReportUploadSwitch))']
# ['kTestLoggingURLSwitch))']
# ['kNoCrashUploadSwitch))']
# ['kEnableCrashReportingSwitch)']
# ['kScanLocationsSwitch))']
# []
# ['kUmaUserSwitch)']
# ['kExtendedSafeBrowsingEnabledSwitch)']
# ['kHandleSwitch)']
# ['kRemoveScanOnlyUwS)']
# ['kRunWithoutSandboxForTestingSwitch)']
# ['kCrashHandlerSwitch))']
# ['kUseCrashHandlerWithIdSwitch))']
# ['kLogInterfaceCallsToSwitch))']
# ['kCrashSwitch))']
# ['kLoadEmptyDLLSwitch))']
# ['kResetShortcutsSwitch))']
# ['kElevatedSwitch))']
# ['kCrashSwitch))']
# ['kLoadEmptyDLLSwitch))']
# ['kNoSelfDeleteSwitch)']
# ['kForceSelfDeleteSwitch)']
# []
# ['kUploadLogFileSwitch))']
# ['kElevatedSwitch)']
# ['kUploadLogFileSwitch))']
# ['kTestingSwitch)']
# []
# ['kCrashHandlerSwitch))']
# ['kChromeVersionSwitch))']
# ['kChromeSystemInstallSwitch)']
# ['kChromeExePathSwitch))']
# ['kNoRecoveryComponentSwitch)']
# ['kForceRecoveryComponentSwitch)']
# []
# ['kPostRebootSwitch)']
# []
# ['kTestLoggingURLSwitch))']
# ['kWithCleanupModeLogsSwitch))']
# ['kEnableCrashReportingSwitch))']
# ['kAllowUnsecureDLLsSwitch))']
# ['kInitDoneNotifierSwitch)']
# ['kQuarantineDirSwitch))']
# ['kChromeChannelSwitch))']
# ['kChromePromptSwitch))']
# ['kDumpRawLogsSwitch)']
# ['kAshTouchHud))']
# ['kShowTaps))']
# ['kAshSideVolumeButtonPosition))']
# ['kAshUiMode))']
# ['kAuraLegacyPowerButton)']
# ['kForceTabletPowerButton)']
# ['kAshPowerButtonPosition))']
# ['kFirstExecAfterBoot))']
# ['kFrameThrottleFps))']
# ['kSSLKeyLogFile))']
# ['kRemoteDebuggingPort)']
# ['kRemoteDebuggingPipe))']
# ['kDefaultBackgroundColor))']
# ['kDumpDom))']
# ['kPrintToPDF))']
# ['kRepl))']
# ['kScreenshot))']
# ['kTimeout))']
# ['kVirtualTimeBudget))']
# ['kTimeout))']
# ['kDumpDom))']
# ['kRemoteDebuggingPort)']
# ['kRemoteDebuggingPipe))']
# ['kDeterministicMode))']
# ['kEnableBeginFrameControl))']
# ['kEnableCrashReporter))']
# ['kDisableCrashReporter))']
# ['kCrashDumpsDir))']
# ['kRemoteDebuggingPort))']
# ['kRemoteDebuggingAddress))']
# ['kRemoteDebuggingPipe))']
# ['kProxyServer))']
# ['kProxyBypassList))']
# ['kUseGL))']
# ['kUserDataDir))']
# ['kWindowSize))']
# ['kHideScrollbars))']
# ['kUserAgent))']
# ['kFontRenderHinting))']
# ['kBlockNewWebContents))']
# ['kProcessType))']
# ['kUserAgent))']
# ['kHeadless))']
# ['kUseGL))']
# ['kEnableLogging))']
# ['kLoggingLevel)']
# ['kDisableBreakpad))']
# ['kEnableLogging))']
# ['kNoSystemProxyConfigService))']
# ['kDiskCacheDir))']
# ['kUserAgent))']
# ['kExportTaggedPDF))']
# ['kEnableThreadInstructionCount)']
# ['kNoSandbox))']
# ['kHandleSwitch)']
# ['kTestType)']
# ['kDelete))']
# ['kUninstallSwitch))']
# ['kInstallSwitch))']
# ['kUnregisterSwitch))']
# ['kRegisterSwitch))']
# []
# ['kWebLayerUserDataDir))']
# ['kNoInitialNavigation))']
# ['kStartInIncognito)']
# ['kEnableAutoReload))']
# ['kDisableAutoReload))']
# ['kProxyServer))']
# ['kProxyBypassList))']
# ['kUseMobileUserAgent))']
# []
# []
# []
# []
# ['kV)']
# ['kVModule))']
# []
# []
# ['kForceFieldTrials))']
# ['kEnableThreadInstructionCount))']
# ['kDisableBreakpad))']
# ['kEnableLowEndDeviceMode))']
# ['kDisableLowEndDeviceMode))']
# []
# ['kDumpToFileFlag))']
# ['kEnableReachedCodeProfiler)']
# ['kForceUIDirection))']
# []
# ['kTraceStartupEnablePrivacyFiltering)']
# ['kExplicitlyAllowedPorts))']
# ['kIgnoreCertificateErrorsSPKIList))']
# ['kUseFirstPartySet))']
# []
# ['kIgnoreCertificateErrorsSPKIList))']
# ['kForceEffectiveConnectionType))']
# ['kUnsafelyTreatInsecureOriginAsSecure))']
# ['kWaitForDebugger))']
# ['kServiceSandboxType))']
# []
# ['kUseFakeDeviceForMediaStream))']
# ['kUseFileForFakeVideoCapture))']
# ['kEnableExclusiveAudio))']
# ['kTrySupportedChannelLayouts)']
# ['kForceWaveAudio))']
# ['kEnableExclusiveAudio))']
# ['kEnableExclusiveAudio))']
# ['kUseCras))']

# %%
##File name andn nested Pattern matching

# %%
import os
import glob
import re
import pandas as pd

dead_test_files = glob.glob('/Users/govardhanrathamsetty/Desktop/ToggleSmell-Chromium/All versions/**/chromium 90.0.4390.0/**/*.cc', recursive=True)


emp_dic = {}
s2=[]
file_path = []
s=[]
dead_list=[]
for code_lines in dead_test_files:
    if 'switch' not in code_lines:
        if 'feature' not in code_lines:
            with open(code_lines, 'rb') as file:  
                try:
                    content = file.read().decode('utf-8')  
                    emp_dic[code_lines] = content
                except UnicodeDecodeError:
                    pass
                
                
emp_dic = {key: value for key, value in emp_dic.items() if value is not None and value != ''}

for i,j in emp_dic.items():
    i = i.split('\n')
    s.append((i, j))
    
for i in s:
    i = (i[0][0], i[1])
    s2.append(i)
path_filecontent={}

for i in s2:
    path_filecontent[i[0]] = i[1]

ss=[]
ss2=[]
path_tog_match =[]

for i, j in path_filecontent.items():
        
        parts = i.split('/')

        file_name = parts[-1]
        
        version = '/'.join(parts[7:8])

        j = j.split('\n')
        
        ss.append(j)
        
        for q in ss:
              for kk in q: 
                    matches = re.findall(r'\s*if\s*\(.*\).*\{.*if\(.*\).*\{.*\}', kk)
                    matches = [re.findall(r'\b[k]\w*\b',mat) for mat in matches]
                    if matches:
                                path_tog_match.append((matches[0][0], i, file_name, version))
path_tog_match
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/k5/rt9wsscd1gj3wk2drj8v06880000gn/T/ipykernel_16239/2109765804.py in <module>
#      55         for q in ss:
#      56               for kk in q:
# ---> 57                     matches = re.findall(r'\s*if\s*\(.*\).*\{.*if\(.*\).*\{.*\}', kk)
#      58                     matches = [re.findall(r'\b[k]\w*\b',mat) for mat in matches]
#      59                     if matches:
#
# /opt/anaconda3/lib/python3.9/re.py in findall(pattern, string, flags)
#     239
#     240     Empty matches are included in the result."""
# --> 241     return _compile(pattern, flags).findall(string)
#     242
#     243 def finditer(pattern, string, flags=0):
#
# KeyboardInterrupt:

# %%
#r'\s*if\s*\(.*\).*\{.*if\(.*\).*\{.*\}'
